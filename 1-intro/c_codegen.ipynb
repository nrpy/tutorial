# %% [markdown]
# # C Code Generation
#
# `nrpy.c_codegen.c_codegen` converts SymPy expressions into C assignments. It handles scalar and list output, common subexpression elimination, output controls, optional formatting choices, substitutions, and finite-difference-aware gridfunction reads.

# %% [markdown]
# [Index](../index.ipynb) | Previous: [Gridfunctions and Grid Metadata](grid.ipynb) | Next: [C Function Registration](c_function.ipynb)

# %% [markdown]
# ## Why This Matters
#
# Code generation turns symbolic expressions into C assignments. This is the step that converts algebra written in Python into statements a compiled numerical code can evaluate.

# %% [markdown]
# ## What You Will See
#
# - Complete small scalar and list assignment blocks.
# - A common-subexpression example.
# - A finite-difference-aware gridfunction access example.

# %%
import shutil

import sympy as sp

import nrpy.c_codegen as ccg
import nrpy.grid as grid
import nrpy.indexedexp as ixp
import nrpy.params as par

x, y = sp.symbols("x y", real=True)

# %% [markdown]
# ## Scalar assignments
#
# Set `verbose=False` when the expression is small enough to read directly.

# %%
expr = sp.sin(x) + x**2 + sp.Rational(1, 3)
print(ccg.c_codegen(expr, "result", include_braces=False, verbose=False))
# Out:
# result = ((x)*(x)) + sin(x) + 1.0/3.0;

# %% [markdown]
# ## Lists of assignments
#
# A list of expressions must match a list of output names.

# %%
exprs = [x + y, x * y, x**2 - y**2]
names = ["sum_xy", "prod_xy", "diff_sq"]
print(ccg.c_codegen(exprs, names, include_braces=False, enable_cse=False, verbose=False))
# Out:
# sum_xy = x + y;
# prod_xy = x*y;
# diff_sq = ((x)*(x)) - ((y)*(y));

# %% [markdown]
# ## Common subexpression elimination
#
# With common subexpression elimination enabled, repeated symbolic structure is factored into temporary variables.

# %%
shared = x + y
exprs = [shared**2 + sp.sin(shared), shared**3]
print(
    ccg.c_codegen(
        exprs,
        ["f", "g"],
        include_braces=False,
        verbose=False,
        cse_varprefix="cse_",
    )
)
# Out:
# const REAL cse_tmp0 = x + y;
# f = ((cse_tmp0)*(cse_tmp0)) + sin(cse_tmp0);
# g = ((cse_tmp0)*(cse_tmp0)*(cse_tmp0));

# %% [markdown]
# ## Output controls, formatting, and substitutions
#
# `prestring`, `poststring`, `include_braces`, and floating-point options control the emitted text. When `clang-format` is available, `enable_clang_format=True` runs NRPy's formatting helper. `postproc_substitution_dict` appends suffixes to selected SymPy symbols before C emission.

# %%
controlled = ccg.c_codegen(
    x + y,
    "rhs",
    include_braces=True,
    prestring="/* before */\n",
    poststring="/* after */\n",
    fp_type="float",
    verbose=False,
)
print(controlled)

if shutil.which("clang-format"):
    formatted = ccg.c_codegen(
        [x + y, x * y],
        ["sum_xy", "prod_xy"],
        include_braces=True,
        enable_cse=False,
        verbose=False,
        enable_clang_format=True,
    )
    print(formatted)
else:
    print("clang-format is not available; skipping formatted output.")

renamed = ccg.c_codegen(
    x + y,
    "rhs",
    include_braces=False,
    verbose=False,
    postproc_substitution_dict={"x": "_center"},
)
print(renamed)
# Out:
# {
# /* before */
# rhs = x + y;
# /* after */
# }
#
# {
# sum_xy = x + y;
# prod_xy = x*y;
# }
#
# rhs = x_center + y;

# %% [markdown]
# ## Finite-difference-aware gridfunction reads
#
# When `enable_fd_codegen=True`, derivative symbols such as `u_dD0` trigger finite-difference stencils and the gridfunction reads they require.

# %%
grid.glb_gridfcs_dict.clear()
par.set_parval_from_str("Infrastructure", "BHaH")
par.set_parval_from_str("finite_difference::fd_order", 2)

u = grid.register_gridfunctions("u", group="EVOL")[0]
u_dD = ixp.declarerank1("u_dD")

code = ccg.c_codegen(
    u_dD[0] + u,
    "rhs_u",
    include_braces=False,
    verbose=False,
    enable_fd_codegen=True,
    enable_fd_functions=False,
)
print(code)
# Out:
# /*
#  * NRPy-Generated GF Access/FD Code, Step 1 of 2:
#  * Read gridfunction(s) from main memory and compute FD stencils as needed.
#  */
# const REAL u_i0m1 = in_gfs[IDX4(UGF, i0-1, i1, i2)];
# const REAL u = in_gfs[IDX4(UGF, i0, i1, i2)];
# const REAL u_i0p1 = in_gfs[IDX4(UGF, i0+1, i1, i2)];
# static const REAL FDPart1_Rational_1_2 = 1.0/2.0;
# const REAL u_dD0 = FDPart1_Rational_1_2*invdxx0*(-u_i0m1 + u_i0p1);
#
# /*
#  * NRPy-Generated GF Access/FD Code, Step 2 of 2:
#  * Evaluate SymPy expressions and write to main memory.
#  */
# rhs_u = u + u_dD0;

# %% [markdown]
# ## Where This Leads
#
# - [Gridfunctions and Grid Metadata](grid.ipynb) reviews the prerequisite step.
# - [C Function Registration](c_function.ipynb) continues the tutorial path.
# - [Parameters](params.ipynb) connects this topic to a natural application.
# - [Finite Differences](finite_difference.ipynb) connects this topic to a natural application.
