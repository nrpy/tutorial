# %% [markdown]
# # C Code Generation
#
# Translate SymPy expressions into C assignments, with enough control to expose the optimizations NRPy relies on.
#
# Navigation: [Index](../index.ipynb) | Previous: [Gridfunctions](grid.ipynb) | Next: [C Function Registration](c_function.ipynb)
#
# ## From Expressions to Kernel Statements
#
# This notebook starts with single assignments, then moves to multiple outputs, common subexpression elimination, name substitution, and finite-difference-aware code.

# %% [markdown]
# ## Learning Goals
#
# - Translate symbolic formulas into readable C assignments.
# - See why repeated work should be replaced by a temporary variable.
# - Connect derivative symbols to finite-difference grid reads.
#
# ## Words for This Notebook
#
# - **C assignment:** a line of C code that stores a computed value in a named place.
# - **Common subexpression elimination:** finding repeated pieces of a formula and computing them once.
# - **Temporary variable:** a short-lived name used to store a repeated piece of a formula.
# - **Kernel:** a small generated C routine that performs the main update work.
# - **Stencil:** the nearby grid points used to approximate a derivative.
#
# Use the code cells actively: first predict what should happen, then run the cell, then explain the output in plain language. This predict-run-explain pattern keeps the physics idea connected to the programming details.

# %% [markdown]
# ## NRPy2 Interfaces Used Here
#
# - `nrpy.c_codegen` emits C assignments from SymPy expressions.
# - `nrpy.grid`, `nrpy.indexedexp`, and `nrpy.params` provide the registered fields, derivative symbols, and code-writing-path setting needed by finite-difference-aware code generation.

# %% [markdown]
# ## Import SymPy and NRPy Codegen Tools
#
# The first examples only need SymPy and the C code generator.

# %%
import sympy as sp

import nrpy.c_codegen as ccg

# %% [markdown]
# ## Create Symbols for Scalar Examples
#
# These symbols stand in for mathematical values that will later be evaluated inside C code.

# %%
x, y = sp.symbols("x y", real=True)

# %% [markdown]
# ## Emit One Scalar Assignment
#
# The simplest call maps one symbolic expression to one C assignment target.

# %%
scalar_expr = sp.sin(x) + x**2 + sp.Rational(1, 3)
scalar_code = ccg.c_codegen(
    scalar_expr,
    "result",
    include_braces=False,
    verbose=False,
)
print(scalar_code)
# Out:
# result = ((x)*(x)) + sin(x) + 1.0/3.0;

# %% [markdown]
# ## Emit Several Assignments Together
#
# A list of expressions pairs with a list of target names. Here CSE is disabled so the output is a direct translation of each expression.

# %%
exprs = [x + y, x * y, x**2 - y**2]
targets = ["sum_xy", "prod_xy", "diff_sq"]
list_code = ccg.c_codegen(
    exprs,
    targets,
    include_braces=False,
    enable_cse=False,
    verbose=False,
)
print(list_code)
# Out:
# sum_xy = x + y;
# prod_xy = x*y;
# diff_sq = ((x)*(x)) - ((y)*(y));

# %% [markdown]
# ## Build an Expression with Repeated Work
#
# Repeated algebra and repeated transcendental calls can dominate generated C update cost. The expression below evaluates `sin(2*a)` twice unless code generation introduces a temporary.

# %%
a, b, c = sp.symbols("a b c", real=True)
repeated_expr = b**2 * sp.sin(2 * a) + c / sp.sin(2 * a)
print(sp.ccode(repeated_expr))
# Out:
# pow(b, 2)*sin(2*a) + c/sin(2*a)

# %% [markdown]
# ## Inspect SymPy's Common Subexpression Elimination
#
# CSE identifies repeated pieces and rewrites the final expression in terms of temporary symbols. This is the symbolic optimization that NRPy2 applies before emitting C when `enable_cse=True`.

# %%
replacements, reduced_exprs = sp.cse(repeated_expr)
print("temporary definitions:", replacements)
print("reduced expression:", reduced_exprs[0])
# Out:
# temporary definitions: [(x0, sin(2*a))]
# reduced expression: b**2*x0 + c/x0

# %% [markdown]
# ## Emit the Repeated Expression Without CSE
#
# With CSE disabled, the C code still matches the mathematics, but the expensive sine call appears twice.

# %%
no_cse_code = ccg.c_codegen(
    repeated_expr,
    "result",
    include_braces=False,
    enable_cse=False,
    verbose=False,
)
print(no_cse_code)
# Out:
# result = ((b)*(b))*sin(2*a) + c/sin(2*a);

# %% [markdown]
# ## Emit the Repeated Expression With CSE
#
# With CSE enabled, NRPy2 emits a temporary for the shared sine value and reuses it in the final assignment. This pattern is central to NRPy-generated right-hand-side update routines, where thousands of expressions often share substructure.

# %%
cse_code = ccg.c_codegen(
    repeated_expr,
    "result",
    include_braces=False,
    enable_cse=True,
    cse_varprefix="cse_",
    verbose=False,
)
print(cse_code)
# Out:
# const REAL cse_tmp0 = sin(2*a);
# result = ((b)*(b))*cse_tmp0 + c/cse_tmp0;

# %% [markdown]
# ## Substitute Names at Emission Time
#
# Post-processing substitutions are useful when a symbolic derivation uses compact names but the generated C should refer to a runtime variable or macro.

# %%
substitution_code = ccg.c_codegen(
    x + y,
    "rhs",
    include_braces=False,
    verbose=False,
    postproc_substitution_dict={"x": "x_center"},
)
print(substitution_code)
# Out:
# rhs = xx_center + y;

# %% [markdown]
# ## Register a Gridfunction for Finite-Difference Reads
#
# Finite-difference-aware code generation needs NRPy grid metadata. This small setup registers one evolved field and asks codegen to translate a derivative symbol into grid reads.

# %%
import nrpy.grid as grid
import nrpy.indexedexp as ixp
import nrpy.params as par

grid.glb_gridfcs_dict.pop("uu", None)
par.set_parval_from_str("Infrastructure", "BHaH")
par.set_parval_from_str("finite_difference::fd_order", 2)

uu = grid.register_gridfunctions("uu", group="EVOL")[0]
uu_dD = ixp.declarerank1("uu_dD")

# %% [markdown]
# ## Emit a Finite-Difference-Aware Assignment
#
# The derivative symbol `uu_dD[0]` now expands into the memory reads and stencil arithmetic needed by a C kernel.

# %%
fd_code = ccg.c_codegen(
    uu_dD[0] + uu,
    "uu_rhs",
    include_braces=False,
    verbose=False,
    enable_fd_codegen=True,
    enable_fd_functions=False,
)
print(fd_code)
# Out:
# /*
#  * NRPy-Generated GF Access/FD Code, Step 1 of 2:
#  * Read gridfunction(s) from main memory and compute FD stencils as needed.
#  */
# const REAL uu_i0m1 = in_gfs[IDX4(UUGF, i0-1, i1, i2)];
# const REAL uu = in_gfs[IDX4(UUGF, i0, i1, i2)];
# const REAL uu_i0p1 = in_gfs[IDX4(UUGF, i0+1, i1, i2)];
# static const REAL FDPart1_Rational_1_2 = 1.0/2.0;
# const REAL uu_dD0 = FDPart1_Rational_1_2*invdxx0*(-uu_i0m1 + uu_i0p1);
#
# /*
#  * NRPy-Generated GF Access/FD Code, Step 2 of 2:
#  * Evaluate SymPy expressions and write to main memory.
#  */
# uu_rhs = uu + uu_dD0;

# %% [markdown]
# ## Learning Check
#
# Before the CSE cells, underline the repeated `sin(2*a)` term in the formula. After running, find the temporary variable that stores it once.

# %% [markdown]
# ## Next Codegen Topics
#
# - [Parameters](params.ipynb)
# - [Finite Differences](finite_difference.ipynb)
# - [C Function Registration](c_function.ipynb)
# - [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb)
