# %% [markdown]
# # C Code Generation
#
# ## Author: Zach Etienne
#
# To run the whole notebook, click the `>>` toolbar button and choose
# **Restart Kernel and Run All Cells...**.
#
# This notebook shows how NRPy translates SymPy expressions into C
# assignments, introduces temporary variables for repeated work, and expands a
# finite-difference derivative symbol into grid reads.
#
# ### Required Reading
#
# - [Grid Fields and Grid Metadata](grid.ipynb), for gridfunction context.
# - [Parameters](params.ipynb), for symbolic runtime parameter context.
#
# ### NRPy Source Code
#
# - [nrpy/nrpy/c_codegen.py](../nrpy/nrpy/c_codegen.py): emits C assignments
#   from SymPy and NRPy expressions.
#
# # Table of Contents
#
# 1. [Words for This Notebook](#Words-for-This-Notebook)
# 1. [Step 1](#Step-1:-Trace-symbolic-expressions-to-generated-C-assignments):
#    Trace expressions.
# 1. [Step 2](#Step-2:-Initialize-SymPy-and-C-code-generation-tools):
#    Initialize tools.
# 1. [Step 3](#Step-3:-Emit-scalar-and-list-assignments): Emit assignments.
# 1. [Step 4](#Step-4:-Build-an-expression-with-repeated-work): Build repeat.
# 1. [Step 5](#Step-5:-Inspect-SymPy-common-subexpression-elimination):
#    Inspect CSE.
# 1. [Step 6](#Step-6:-Compare-generated-code-with-and-without-CSE): Compare.
# 1. [Step 7](#Step-7:-Append-name-suffixes-at-emission-time): Append suffixes.
# 1. [Step 8](#Step-8:-Prepare-grid-and-finite-difference-metadata): Prepare FD.
# 1. [Step 9](#Step-9:-Emit-a-finite-difference-aware-assignment): Emit FD C.
# 1. [Validation Check](#Validation-Check): Validate generated artifacts.
# 1. [Learning Check](#Learning-Check): Check understanding.
# 1. [What next?](#What-next?)

# %% [markdown]
# # Words for This Notebook
# ### [Back to [top](#Table-of-Contents)]
#
# - **`c_codegen()`:** NRPy's function for emitting C assignment text from
#   symbolic expressions.
# - **Generated assignment:** C text that stores an expression in a target name.
# - **Common subexpression elimination (CSE):** rewriting repeated pieces of a
#   formula so they are computed once. SymPy documents CSE in its rewriting
#   tools: <https://docs.sympy.org/latest/modules/rewriting.html>.
# - **Temporary variable:** a short-lived C name that stores repeated work.
# - **Finite-difference-aware code generation:** expansion of derivative
#   symbols into stencil-based grid reads.
# - **Derivative symbol:** a symbolic name such as `uu_dD0` that represents a
#   derivative before generated C expands it.
# - **Gridfunction:** a sampled field on the numerical grid.
# - **Memory read:** generated C indexing that reads a gridfunction value.
#
# The first code object is a SymPy expression. Its algorithmic role is to
# provide a small formula for `c_codegen()` to translate, and the first output
# will show the emitted C assignment.

# %% [markdown]
# # Step 1: Trace symbolic expressions to generated C assignments
# ### [Back to [top](#Table-of-Contents)]
#
# This notebook starts with single assignments, then moves to multiple outputs,
# common subexpression elimination, suffix substitution, and finite-difference
# aware code.
#
# | Artifact | Purpose | Where used | Inspect |
# | --- | --- | --- | --- |
# | scalar assignment | smallest generated C example | Step 3 | target name |
# | CSE block | repeated-work reduction | Step 6 | temporary variable |
# | suffix output | name substitution | Step 7 | `x_center` symbol |
# | FD-aware block | derivative-to-grid-read expansion | Step 9 | grid reads |

# %% [markdown]
# # Step 2: Initialize SymPy and C code-generation tools
# ### [Back to [top](#Table-of-Contents)]
#
# The first examples only need SymPy and the C code generator.

# %%
import sympy as sp

import nrpy.c_codegen as ccg

# %% [markdown]
# # Step 3: Emit scalar and list assignments
# ### [Back to [top](#Table-of-Contents)]
#
# The scalar expression is translated to one target. The list of expressions
# is translated to matching target names. Inspect each complete generated block
# for the target names and right-hand-side formulas.

# %%
x, y = sp.symbols("x y", real=True)

scalar_expr = sp.sin(x) + x**2 + sp.Rational(1, 3)
scalar_code = ccg.c_codegen(
    scalar_expr,
    "result",
    include_braces=False,
    verbose=False,
)

exprs = [x + y, x * y, x**2 - y**2]
targets = ["sum_xy", "prod_xy", "diff_sq"]
list_code = ccg.c_codegen(
    exprs,
    targets,
    include_braces=False,
    enable_cse=False,
    verbose=False,
)

print("scalar assignment:")
print(scalar_code)
print("list assignments:")
print(list_code)
# Out:
# scalar assignment:
# result = ((x)*(x)) + sin(x) + 1.0/3.0;
#
# list assignments:
# sum_xy = x + y;
# prod_xy = x*y;
# diff_sq = ((x)*(x)) - ((y)*(y));

# %% [markdown]
# # Step 4: Build an expression with repeated work
# ### [Back to [top](#Table-of-Contents)]
#
# Repeated algebra and repeated transcendental calls can dominate generated C
# update cost. The expression below evaluates `sin(2*a)` twice unless code
# generation introduces a temporary.

# %%
a, b, c = sp.symbols("a b c", real=True)
repeated_expr = b**2 * sp.sin(2 * a) + c / sp.sin(2 * a)
print(sp.ccode(repeated_expr))
# Out:
# pow(b, 2)*sin(2*a) + c/sin(2*a)

# %% [markdown]
# # Step 5: Inspect SymPy common subexpression elimination
# ### [Back to [top](#Table-of-Contents)]
#
# CSE identifies repeated pieces and rewrites the final expression in terms of
# temporary symbols. Inspect the temporary definition and the reduced
# expression.

# %%
replacements, reduced_exprs = sp.cse(repeated_expr)
print("temporary definitions:", replacements)
print("reduced expression:", reduced_exprs[0])
# Out:
# temporary definitions: [(x0, sin(2*a))]
# reduced expression: b**2*x0 + c/x0

# %% [markdown]
# # Step 6: Compare generated code with and without CSE
# ### [Back to [top](#Table-of-Contents)]
#
# Inspect the complete C blocks. The CSE-enabled block should contain a
# temporary definition and a final assignment that uses that temporary.

# %%
no_cse_code = ccg.c_codegen(
    repeated_expr,
    "result",
    include_braces=False,
    enable_cse=False,
    verbose=False,
)
cse_code = ccg.c_codegen(
    repeated_expr,
    "result",
    include_braces=False,
    enable_cse=True,
    cse_varprefix="cse_",
    verbose=False,
)
print("without CSE:")
print(no_cse_code)
print("with CSE:")
print(cse_code)
# Out:
# without CSE:
# result = ((b)*(b))*sin(2*a) + c/sin(2*a);
#
# with CSE:
# const REAL cse_tmp0 = sin(2*a);
# result = ((b)*(b))*cse_tmp0 + c/cse_tmp0;

# %% [markdown]
# # Step 7: Append name suffixes at emission time
# ### [Back to [top](#Table-of-Contents)]
#
# `postproc_substitution_dict` appends suffixes to selected symbolic names.
# Inspect the complete assignment for `x_center`, `y`, and the target `rhs`.

# %%
substitution_code = ccg.c_codegen(
    x + y,
    "rhs",
    include_braces=False,
    verbose=False,
    postproc_substitution_dict={"x": "_center"},
)
print(substitution_code)
# Out:
# rhs = x_center + y;

# %% [markdown]
# # Step 8: Prepare grid and finite-difference metadata
# ### [Back to [top](#Table-of-Contents)]
#
# Finite-difference-aware code generation needs NRPy grid metadata. Here `uu`
# is the sampled scalar gridfunction. The derivative name `uu_dD0` means:
#
# - `uu`: the base gridfunction;
# - `_d`: a derivative variable;
# - `D`: a lower derivative index in NRPy naming;
# - `0`: the `x0` direction.
#
# Higher derivatives repeat `D`, so `uu_dDD01` would mean a second derivative
# in the `x0,x1` directions. The output should show the registered field and
# derivative symbol that the next C block expands.

# %%
import nrpy.grid as gri
import nrpy.indexedexp as ixp
import nrpy.params as par

gri.glb_gridfcs_dict.pop("uu", None)
par.set_parval_from_str("Infrastructure", "BHaH")
par.set_parval_from_str("finite_difference::fd_order", 2)

uu = gri.register_gridfunctions("uu", group="EVOL")[0]
uu_dD = ixp.declarerank1("uu_dD")
print("registered grid field:", uu)
print("derivative symbol:", uu_dD[0])
# Out:
# registered grid field: uu
# derivative symbol: uu_dD0

# %% [markdown]
# # Step 9: Emit a finite-difference-aware assignment
# ### [Back to [top](#Table-of-Contents)]
#
# The full generated block is printed because it teaches the memory-read
# pattern. Inspect the `i0-1` and `i0+1` grid reads, the derivative symbol
# `uu_dD0`, and the final assignment to `uu_rhs`.

# %%
fd_code = ccg.c_codegen(
    uu_dD[0] + uu,
    "uu_rhs",
    include_braces=False,
    verbose=False,
    enable_fd_codegen=True,
    enable_fd_functions=False,
)
print(fd_code)
# Out:
# /*
#  * NRPy-Generated GF Access/FD Code, Step 1 of 2:
#  * Read gridfunction(s) from main memory and compute FD stencils as needed.
#  */
# const REAL uu_i0m1 = in_gfs[IDX4(UUGF, i0-1, i1, i2)];
# const REAL uu = in_gfs[IDX4(UUGF, i0, i1, i2)];
# const REAL uu_i0p1 = in_gfs[IDX4(UUGF, i0+1, i1, i2)];
# static const REAL FDPart1_Rational_1_2 = 1.0/2.0;
# const REAL uu_dD0 = FDPart1_Rational_1_2*invdxx0*(-uu_i0m1 + uu_i0p1);
#
# /*
#  * NRPy-Generated GF Access/FD Code, Step 2 of 2:
#  * Evaluate SymPy expressions and write to main memory.
#  */
# uu_rhs = uu + uu_dD0;

# %% [markdown]
# # Validation Check
# ### [Back to [top](#Table-of-Contents)]
#
# The trusted results are SymPy's CSE replacement and the complete generated C
# artifacts printed above. The newly computed results are this notebook's
# scalar, list, CSE, suffix, and finite-difference code blocks. Passing means
# the printed complete artifacts contain the expected structural features.

# %%
if "result =" not in scalar_code or "sin(x)" not in scalar_code:
    raise RuntimeError(f"Unexpected scalar code: {scalar_code}")
for target in targets:
    if target not in list_code:
        raise RuntimeError(f"Missing target {target} in {list_code}")

if len(replacements) != 1:
    raise RuntimeError(f"Expected one CSE replacement: {replacements}")
cse_symbol, cse_value = replacements[0]
if cse_value != sp.sin(2 * a):
    raise RuntimeError(f"Unexpected CSE value: {cse_value}")
if reduced_exprs != [b**2 * cse_symbol + c / cse_symbol]:
    raise RuntimeError(f"Unexpected reduced expression: {reduced_exprs}")

if "cse_tmp" in no_cse_code:
    raise RuntimeError(f"CSE temporary appeared with CSE disabled: {no_cse_code}")
for expected_piece in ["cse_tmp", "result ="]:
    if expected_piece not in cse_code:
        raise RuntimeError(f"Missing {expected_piece} in CSE code")
for expected_piece in ["rhs", "x_center", "y"]:
    if expected_piece not in substitution_code:
        raise RuntimeError(f"Missing {expected_piece} in substitution output")
for expected_piece in ["uu_i0m1", "uu_i0p1", "uu_dD0", "uu_rhs"]:
    if expected_piece not in fd_code:
        raise RuntimeError(f"Missing {expected_piece} in FD code")

print("trusted result: SymPy CSE and complete generated C artifacts")
print("newly computed result: scalar, list, CSE, suffix, and FD code blocks")
print("validated scalar and list assignments")
print("validated symbolic CSE replacement:", replacements)
print("validated substitution and finite-difference reads")
# Out:
# trusted result: SymPy CSE and complete generated C artifacts
# newly computed result: scalar, list, CSE, suffix, and FD code blocks
# validated scalar and list assignments
# validated symbolic CSE replacement: [(x0, sin(2*a))]
# validated substitution and finite-difference reads

# %% [markdown]
# # Learning Check
# ### [Back to [top](#Table-of-Contents)]
#
# After comparing the CSE-disabled and CSE-enabled outputs, explain why storing
# `sin(2*a)` once matters more for large right-hand-side kernels than for this
# toy expression.

# %% [markdown]
# # What next?
#
# - [C Function Registration](c_function.ipynb)
# - [Parameters](params.ipynb)
# - [Finite Differences](finite_difference.ipynb)
# - [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb)
