# %% [markdown]
# # C Code Generation
#
# `nrpy.c_codegen.c_codegen` converts SymPy expressions into optimized C assignment strings. It supports common subexpression elimination, SIMD-aware output, post-processing substitutions, finite-difference-aware gridfunction reads, and optional formatting through `clang-format`.

# %%
import shutil

import sympy as sp

import nrpy.c_codegen as ccg
import nrpy.grid as grid
import nrpy.params as par

par.set_parval_from_str("Infrastructure", "BHaH")

a, b, c = sp.symbols("a b c")
expr = b**2 * sp.sin(2 * a) + c / sp.sin(2 * a)

# %% [markdown]
# ## Basic Assignments and CSE
#
# The first argument is a SymPy expression, or a list of expressions. The second argument is the output assignment target, or a matching list of targets. CSE is enabled by default.

# %%
code = ccg.c_codegen(expr, "result", include_braces=False, verbose=False)

assert "result" in code
assert "sin" in code
assert "tmp" in code

print(code)

# %%
multi_code = ccg.c_codegen(
    [expr, a**2 + b**2],
    ["first", "second"],
    include_braces=False,
    verbose=False,
    cse_varprefix="shared_",
)

assert "first" in multi_code
assert "second" in multi_code
assert "shared_tmp" in multi_code

print(multi_code)

# %% [markdown]
# ## Output Controls
#
# Common options include `include_braces`, `verbose`, `prestring`, `poststring`, `fp_type`, and `cse_varprefix`. These controls affect only the generated C text.

# %%
custom_code = ccg.c_codegen(
    sp.sin(a) + b,
    "float value",
    include_braces=False,
    verbose=False,
    fp_type="float",
    prestring="// begin calculation\n",
    poststring="// end calculation\n",
)

assert custom_code.startswith("// begin calculation")
assert "float value" in custom_code
assert "sinf" in custom_code
assert custom_code.rstrip().endswith("// end calculation")

print(custom_code)

# %% [markdown]
# ## SIMD-Aware Output
#
# With a supported infrastructure and double precision, `enable_simd=True` emits SIMD helper calls and `REAL_SIMD_ARRAY` temporaries instead of scalar arithmetic.

# %%
par.set_parval_from_str("Infrastructure", "BHaH")
simd_code = ccg.c_codegen(
    a**2 + b**2 + sp.Rational(1, 2),
    "result",
    enable_simd=True,
    include_braces=False,
    verbose=False,
)

assert "REAL_SIMD_ARRAY" in simd_code
assert "AddSIMD" in simd_code or "MulSIMD" in simd_code
assert "result" in simd_code

print(simd_code)

# %% [markdown]
# ## Post-Processing Substitutions
#
# `postproc_substitution_dict` appends replacement text to matching symbol names after symbolic simplification. This is useful when the final C expression should use infrastructure-specific variable names.

# %%
substituted_code = ccg.c_codegen(
    a**2 + b,
    "out",
    include_braces=False,
    verbose=False,
    postproc_substitution_dict={"a": "_center", "b": "_rhs"},
)

assert "a_center" in substituted_code
assert "b_rhs" in substituted_code
assert "out" in substituted_code

print(substituted_code)

# %% [markdown]
# ## CSE Preprocessing
#
# `enable_cse_preprocess=True` performs additional symbolic preprocessing before CSE. This can expose rational constants and repeated factors in expressions with nested products or powers.

# %%
preprocessed_code = ccg.c_codegen(
    (a + b) ** 3 - (a + b) ** 2 + sp.Rational(1, 3) * c,
    "out",
    include_braces=False,
    verbose=False,
    enable_cse_preprocess=True,
    cse_varprefix="prep_",
)

assert "out" in preprocessed_code
assert "prep_" in preprocessed_code or "Rational" in preprocessed_code

print(preprocessed_code)

# %% [markdown]
# ## Finite-Difference-Aware Reads
#
# `automatically_read_gf_data_from_memory=True` reads registered gridfunctions that appear directly in an expression. `enable_fd_codegen=True` also expands derivative symbols into finite-difference stencils. The `mem_alloc_style` option controls the ordering used when generating multi-index stencil reads.

# %%
grid.glb_gridfcs_dict.clear()
par.set_parval_from_str("Infrastructure", "BHaH")
u = grid.register_gridfunctions("u")[0]
u_dDD01 = sp.Symbol("u_dDD01")

auto_read_code = ccg.c_codegen(
    u + 1,
    "rhs",
    automatically_read_gf_data_from_memory=True,
    include_braces=False,
    verbose=False,
)

fd_code = ccg.c_codegen(
    u_dDD01,
    "d2u_dxdy",
    enable_fd_codegen=True,
    mem_alloc_style="012",
    include_braces=False,
    verbose=False,
)

assert "rhs = u + 1" in auto_read_code
assert "const REAL u = in_gfs" in auto_read_code
assert "d2u_dxdy" in fd_code
assert "UGF" in fd_code
assert "IDX4" in fd_code
assert "u_i0m2_i1m1" in fd_code

print(auto_read_code)
print(fd_code)

# %% [markdown]
# ## Optional Formatting
#
# `enable_clang_format=True` asks NRPy to format the generated string using `clang-format`. Formatting is optional; if the tool is unavailable, use the unformatted output.

# %%
format_expr = (a + b) * (a - b)

if shutil.which("clang-format"):
    formatted_code = ccg.c_codegen(
        format_expr,
        "formatted",
        include_braces=True,
        verbose=False,
        enable_clang_format=True,
    )
    assert "formatted" in formatted_code
    print(formatted_code)
else:
    fallback_code = ccg.c_codegen(
        format_expr,
        "formatted",
        include_braces=True,
        verbose=False,
    )
    assert "formatted" in fallback_code
    print("clang-format unavailable; showing unformatted generated C:")
    print(fallback_code)
