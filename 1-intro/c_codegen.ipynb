# %% [markdown]
# # C Code Generation
#
# Translate SymPy expressions into complete C assignments that a compiler can build.
#
# Navigation: [Index](../index.ipynb) | Previous: [Gridfunctions](grid.ipynb) | Next: [C Function Registration](c_function.ipynb)
#
# ## Roadmap
#
# This notebook proceeds through short focused cells, each with one action and one interpretable output.

# %% [markdown]
# ## Modules Used Here
#
# - `nrpy.c_codegen` emits C assignments from SymPy expressions.
# - `nrpy.grid`, `nrpy.indexedexp`, and `nrpy.params` provide the registered fields, derivative symbols, and backend settings needed by finite-difference-aware code generation.

# %% [markdown]
# ## Complete Assignments
# The following cells show scalar, list, common-subexpression, substitution, and finite-difference-aware assignments in full.

# %% [markdown]
# ## Step 1: Import modules
#
# These imports expose the NRPy and Python tools used in the next steps.

# %%
import sympy as sp

# %% [markdown]
# ## Step 2: Import NRPy modules
#
# These imports expose the NRPy registries and infrastructure writers used below.

# %%
import nrpy.c_codegen as ccg
import nrpy.grid as grid
import nrpy.indexedexp as ixp
import nrpy.params as par

# %% [markdown]
# ## Step 3: Generate optimized C assignments
#
# This expression is small enough to show how common subexpression elimination changes emitted C code.

# %%
x, y = sp.symbols("x y", real=True)

# %% [markdown]
# ## Step 4: Generate C code
#
# The output shows how a symbolic expression is emitted as C.

# %%
print("scalar assignment:")
print(ccg.c_codegen(sp.sin(x) + x**2 + sp.Rational(1, 3), "result", include_braces=False, verbose=False))
# Out:
# scalar assignment:
# result = ((x)*(x)) + sin(x) + 1.0/3.0;

# %% [markdown]
# ## Step 5: Generate C code
#
# The output shows how a symbolic expression is emitted as C.

# %%
print("list assignment:")
print(ccg.c_codegen([x + y, x * y, x**2 - y**2], ["sum_xy", "prod_xy", "diff_sq"], include_braces=False, enable_cse=False, verbose=False))
# Out:
# list assignment:
# sum_xy = x + y;
# prod_xy = x*y;
# diff_sq = ((x)*(x)) - ((y)*(y));

# %% [markdown]
# ## Step 6: Generate C code
#
# The output shows how a symbolic expression is emitted as C.

# %%
shared = x + y
print("common-subexpression assignment:")
print(ccg.c_codegen([shared**2 + sp.sin(shared), shared**3], ["f", "g"], include_braces=False, verbose=False, cse_varprefix="cse_"))
# Out:
# common-subexpression assignment:
# const REAL cse_tmp0 = x + y;
# f = ((cse_tmp0)*(cse_tmp0)) + sin(cse_tmp0);
# g = ((cse_tmp0)*(cse_tmp0)*(cse_tmp0));

# %% [markdown]
# ## Step 7: Generate C code
#
# The output shows how a symbolic expression is emitted as C.

# %%
print("substitution assignment:")
print(ccg.c_codegen(x + y, "rhs", include_braces=False, verbose=False, postproc_substitution_dict={"x": "x_center"}))
# Out:
# substitution assignment:
# rhs = xx_center + y;

# %% [markdown]
# ## Step 8: Register gridfunctions
#
# The registry records named grid fields and their roles in generated code.

# %%
grid.glb_gridfcs_dict.pop("uu", None)
par.set_parval_from_str("Infrastructure", "BHaH")
par.set_parval_from_str("finite_difference::fd_order", 2)
uu = grid.register_gridfunctions("uu", group="EVOL")[0]
uu_dD = ixp.declarerank1("uu_dD")
print("finite-difference-aware assignment:")
print(ccg.c_codegen(uu_dD[0] + uu, "uu_rhs", include_braces=False, verbose=False, enable_fd_codegen=True, enable_fd_functions=False))
# Out:
# finite-difference-aware assignment:
# /*
#  * NRPy-Generated GF Access/FD Code, Step 1 of 2:
#  * Read gridfunction(s) from main memory and compute FD stencils as needed.
#  */
# const REAL uu_i0m1 = in_gfs[IDX4(UUGF, i0-1, i1, i2)];
# const REAL uu = in_gfs[IDX4(UUGF, i0, i1, i2)];
# const REAL uu_i0p1 = in_gfs[IDX4(UUGF, i0+1, i1, i2)];
# static const REAL FDPart1_Rational_1_2 = 1.0/2.0;
# const REAL uu_dD0 = FDPart1_Rational_1_2*invdxx0*(-uu_i0m1 + uu_i0p1);
#
# /*
#  * NRPy-Generated GF Access/FD Code, Step 2 of 2:
#  * Evaluate SymPy expressions and write to main memory.
#  */
# uu_rhs = uu + uu_dD0;

# %% [markdown]
# ## Interpreting the Output
# The printed assignments show how symbolic formulas become readable C statements. The finite-difference-aware assignment is the first place where symbolic derivative names turn into grid reads.

# %% [markdown]
# ## Where This Leads
# - [Parameters](params.ipynb)
# - [Finite Differences](finite_difference.ipynb)
# - [C Function Registration](c_function.ipynb)
# - [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb)
