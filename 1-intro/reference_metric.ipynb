# %% [markdown]
# # Reference Metrics
#
# `nrpy.reference_metric` stores coordinate maps and reference-metric quantities used by curvilinear formulations. A `ReferenceMetric` object provides coordinate symbols, Cartesian maps, scale factors, metric components, inverse metric components, and determinant data.

# %% [markdown]
# [Index](../index.ipynb) | Previous: [How NRPy Computes Finite-Difference Coefficients](how_NRPy_computes_finite_difference_coeffs.ipynb) | Next: [Wave Equation with NumPy](../2-numerical_methods/wave_equation_with_numpy.ipynb)

# %% [markdown]
# ## Why This Matters
#
# Curvilinear coordinates introduce scale factors and metric terms. Reference metrics store those geometric factors so generated code can evolve fields in coordinates matched to the physics.

# %% [markdown]
# ## What You Will See
#
# - Supported coordinate systems.
# - Coordinate maps and scale factors.
# - Metric determinant and inverse checks.

# %%
import sympy as sp

import nrpy.reference_metric as rfm

# %% [markdown]
# ## Supported coordinate systems
#
# `supported_CoordSystems` lists systems implemented by the module. `unittest_CoordSystems` is the smaller set exercised by the module's internal validation path.

# %%
print("supported count:", len(rfm.supported_CoordSystems))
print(rfm.supported_CoordSystems)
print("validation subset:", rfm.unittest_CoordSystems)
# Out:
# supported count: 15
# ['Spherical', 'SinhSpherical', 'SinhSphericalv2n2', 'Cartesian', 'SinhCartesian', 'Cylindrical', 'SinhCylindrical', 'SinhCylindricalv2n2', 'SymTP', 'SinhSymTP', 'LWedgeHSinhSph', 'UWedgeHSinhSph', 'RingHoleySinhSpherical', 'HoleySinhSpherical', 'GeneralRFM_fisheyeN2']
# validation subset: ['SinhSymTP', 'HoleySinhSpherical', 'Cartesian', 'SinhCylindricalv2n2']

# %% [markdown]
# ## Direct construction
#
# Build `ReferenceMetric` objects directly when a notebook needs a fresh object. The examples below inspect Cartesian, Spherical, and SinhSpherical systems.

# %%
for coord_system in ["Cartesian", "Spherical", "SinhSpherical"]:
    metric = rfm.ReferenceMetric(coord_system, enable_rfm_precompute=False)
    print(coord_system)
    print("  xx:", metric.xx)
    print("  xx_to_Cart:", metric.xx_to_Cart)
    print("  Cart_to_xx:", metric.Cart_to_xx)
    print("  scale factors:", metric.scalefactor_orthog)
    print("  metric diagonal:", [metric.ghatDD[i][i] for i in range(3)])
    print("  detgammahat:", metric.detgammahat)
# Out:
# Cartesian
#   xx: [xx0, xx1, xx2]
#   xx_to_Cart: [xx0, xx1, xx2]
#   Cart_to_xx: [Cartx, Carty, Cartz]
#   scale factors: [1, 1, 1]
#   metric diagonal: [1, 1, 1]
#   detgammahat: 1
# Spherical
#   xx: [xx0, xx1, xx2]
#   xx_to_Cart: [xx0*sin(xx1)*cos(xx2), xx0*sin(xx1)*sin(xx2), xx0*cos(xx1)]
#   Cart_to_xx: [sqrt(Cartx**2 + Carty**2 + Cartz**2), acos(Cartz/sqrt(Cartx**2 + Carty**2 + Cartz**2)), atan2(Carty, Cartx)]
#   scale factors: [1, xx0, xx0*sin(xx1)]
#   metric diagonal: [1, xx0**2, xx0**2*sin(xx1)**2]
#   detgammahat: xx0**4*sin(xx1)**2
# SinhSpherical
#   xx: [xx0, xx1, xx2]
#   xx_to_Cart: [AMPL*(exp(xx0/SINHW) - exp(-xx0/SINHW))*sin(xx1)*cos(xx2)/(exp(1/SINHW) - exp(-1/SINHW)), AMPL*(exp(xx0/SINHW) - exp(-xx0/SINHW))*sin(xx1)*sin(xx2)/(exp(1/SINHW) - exp(-1/SINHW)), AMPL*(exp(xx0/SINHW) - exp(-xx0/SINHW))*cos(xx1)/(exp(1/SINHW) - exp(-1/SINHW))]
# ...

# %% [markdown]
# ## Cached access through `reference_metric`
#
# `reference_metric` is a dictionary-like cache. Requesting a coordinate system creates and stores the base object and its precompute variant.

# %%
rfm.reference_metric.clear()
spherical = rfm.reference_metric["Spherical"]

print("cache keys:", sorted(rfm.reference_metric))
print("Spherical scale factors:", spherical.scalefactor_orthog)
print("Spherical inverse metric diagonal:", [spherical.ghatUU[i][i] for i in range(3)])
# Out:
# Setting up reference_metric[Spherical]...
# cache keys: ['Spherical', 'Spherical_rfm_precompute']
# Spherical scale factors: [1, xx0, xx0*sin(xx1)]
# Spherical inverse metric diagonal: [1, xx0**(-2), 1/(xx0**2*sin(xx1)**2)]

# %% [markdown]
# ## Handoff to curvilinear equations
#
# Curvilinear notebooks use these objects to map between numerical coordinates and Cartesian coordinates, rescale tensor components with the scale factors, and construct equations with the reference metric and its derivatives.

# %%
metric = rfm.ReferenceMetric("Spherical", enable_rfm_precompute=False)
identity_residual = []
for i in range(3):
    row = []
    for j in range(3):
        value = sum(metric.ghatDD[i][k] * metric.ghatUU[k][j] for k in range(3))
        if i == j:
            value -= 1
        row.append(sp.simplify(value))
    identity_residual.append(row)

print("metric-inverse residual:")
print(identity_residual)
# Out:
# metric-inverse residual:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# ## Where This Leads
#
# - [How NRPy Computes Finite-Difference Coefficients](how_NRPy_computes_finite_difference_coeffs.ipynb) reviews the prerequisite step.
# - [Wave Equation with NumPy](../2-numerical_methods/wave_equation_with_numpy.ipynb) continues the tutorial path.
# - [Reference-Metric Applications](../4-curvilinear/reference_metric_applications.ipynb) connects this topic to a natural application.
# - [Basis Transforms](../4-curvilinear/basis_transforms.ipynb) connects this topic to a natural application.
