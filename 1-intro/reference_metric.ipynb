# %% [markdown]
# # Reference Metrics
#
# Use reference metrics to describe curvilinear coordinate scale factors and metric identities.
#
# Navigation: [Index](../index.ipynb) | Previous: [How NRPy Computes Finite-Difference Coefficients](how_NRPy_computes_finite_difference_coeffs.ipynb) | Next: [Wave Equation with NumPy](../2-numerical_methods/wave_equation_with_numpy.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Connect coordinate choices to metric factors.
# - See why spherical coordinates need scale factors even in flat space.
# - Check metric-inverse identities with residuals.
#
# ## Words for This Notebook
#
# - **Coordinate system:** a way to label points, such as Cartesian or spherical coordinates.
# - **Metric:** a mathematical object that tells how distances are measured.
# - **Scale factor:** a coordinate-dependent multiplier that appears in distances and derivatives.
# - **Identity check:** a test that multiplying a metric by its inverse gives the expected one-or-zero pattern.
#
# Use the code cells actively: first predict what should happen, then run the cell, then explain the output in plain language. This predict-run-explain pattern keeps the physics idea connected to the programming details.

# %% [markdown]
# ## Reference-Metric Interfaces Used Here
#
# - `nrpy.reference_metric` builds coordinate maps, scale factors, metric components, inverse metrics, and determinants for named coordinate systems.

# %% [markdown]
# ## Coordinate Maps and Metric Checks
# The Cartesian metric has unit scale factors. Spherical coordinates introduce radius and sine factors that the wave operator must include.

# %% [markdown]
# ## Import SymPy Simplification Tools
#
# These imports expose the NRPy and Python tools used in the next steps.

# %%
import sympy as sp

# %% [markdown]
# ## Import the Reference-Metric Registry
#
# These imports expose the NRPy registries and infrastructure writers used below.

# %%
import nrpy.reference_metric as rfm

# %% [markdown]
# ## Load Cartesian and Spherical Metrics
#
# The output connects coordinate maps to metric factors.

# %%
for coord_system in ["Cartesian", "Spherical", "SinhSpherical"]:
    metric = rfm.ReferenceMetric(coord_system, enable_rfm_precompute=False)
    print()
    print(coord_system)
    print("xx:", metric.xx)
    print("xx_to_Cart:", metric.xx_to_Cart)
    print("Cart_to_xx:", metric.Cart_to_xx)
    print("scale factors:", metric.scalefactor_orthog)
    print("metric diagonal:", [metric.ghatDD[i][i] for i in range(3)])
    print("inverse metric diagonal:", [metric.ghatUU[i][i] for i in range(3)])
    print("detgammahat:", metric.detgammahat)
# Out:
# Cartesian
# xx: [xx0, xx1, xx2]
# xx_to_Cart: [xx0, xx1, xx2]
# Cart_to_xx: [Cartx, Carty, Cartz]
# scale factors: [1, 1, 1]
# metric diagonal: [1, 1, 1]
# inverse metric diagonal: [1, 1, 1]
# detgammahat: 1
#
# Spherical
# xx: [xx0, xx1, xx2]
# xx_to_Cart: [xx0*sin(xx1)*cos(xx2), xx0*sin(xx1)*sin(xx2), xx0*cos(xx1)]
# Cart_to_xx: [sqrt(Cartx**2 + Carty**2 + Cartz**2), acos(Cartz/sqrt(Cartx**2 + Carty**2 + Cartz**2)), atan2(Carty, Cartx)]
# scale factors: [1, xx0, xx0*sin(xx1)]
# metric diagonal: [1, xx0**2, xx0**2*sin(xx1)**2]
# inverse metric diagonal: [1, xx0**(-2), 1/(xx0**2*sin(xx1)**2)]
# detgammahat: xx0**4*sin(xx1)**2
#
# SinhSpherical
# xx: [xx0, xx1, xx2]
# xx_to_Cart: [AMPL*(exp(xx0/SINHW) - exp(-xx0/SINHW))*sin(xx1)*cos(xx2)/(exp(1/SINHW) - exp(-1/SINHW)), AMPL*(exp(xx0/SINHW) - exp(-xx0/SINHW))*sin(xx1)*sin(xx2)/(exp(1/SINHW) - exp(-1/SINHW)), AMPL*(exp(xx0/SINHW) - exp(-xx0/SINHW))*cos(xx1)/(exp(1/SINHW) - exp(-1/SINHW))]
# ...

# %% [markdown]
# ## Verify the Metric-Inverse Identity
#
# A zero residual confirms that the symbolic expression matches the expected identity.

# %%
spherical = rfm.ReferenceMetric("Spherical", enable_rfm_precompute=False)
identity_residual = [
    [
        sp.trigsimp(
            sp.simplify(
                sum(spherical.ghatDD[i][k] * spherical.ghatUU[k][j] for k in range(3))
                - (1 if i == j else 0)
            )
        )
        for j in range(3)
    ]
    for i in range(3)
]
print()
print("metric-inverse residual:")
print(identity_residual)
if identity_residual != [[0, 0, 0], [0, 0, 0], [0, 0, 0]]:
    raise RuntimeError("Expected the metric-inverse residual to vanish.")
# Out:
# metric-inverse residual:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# The metric and scale-factor output shows why curvilinear coordinates require more than Cartesian derivatives. The residual check confirms that the printed spherical factors match the expected geometry.

# %% [markdown]
# ## Learning Check
#
# Before loading the spherical metric, predict which directions should involve factors of `r` or `sin(theta)`. Then compare with the printed scale factors.

# %% [markdown]
# ## Continue to NumPy Wave Evolution
# - [Reference-Metric Applications](../4-curvilinear/reference_metric_applications.ipynb)
# - [Basis Transforms](../4-curvilinear/basis_transforms.ipynb)
# - [Curvilinear Wave Equation](../3-wave_equation/wave_equation_curvilinear.ipynb)
