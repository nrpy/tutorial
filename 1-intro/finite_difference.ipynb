# %% [markdown]
# # Finite Differences
#
# Turn derivatives of sampled wave fields into stencil weights, grid reads, and generated C assignments.
#
# Navigation: [Index](../index.ipynb) | Previous: [C Function Registration](c_function.ipynb) | Next: [How NRPy Computes Finite-Difference Coefficients](how_NRPy_computes_finite_difference_coeffs.ipynb)
#
# ## Roadmap
#
# This notebook proceeds through short focused cells, each with one action and one interpretable output.

# %% [markdown]
# ## Modules Used Here
#
# - `nrpy.finite_difference` computes stencil coefficients and helper functions.
# - `nrpy.grid` and `nrpy.indexedexp` connect derivative symbols to registered gridfunctions.
# - `nrpy.c_codegen` emits the corresponding C assignment.

# %% [markdown]
# ## Stencil Weights and Grid Reads
# The second derivative in the wave equation is represented by offsets, weights, symbolic derivative variables, and generated C grid reads.

# %% [markdown]
# ## Step 1: Import modules
#
# These imports expose the NRPy and Python tools used in the next steps.

# %%
import sympy as sp

# %% [markdown]
# ## Step 2: Import NRPy modules
#
# These imports expose the NRPy registries and infrastructure writers used below.

# %%
import nrpy.c_codegen as ccg
import nrpy.finite_difference as fd
import nrpy.grid as grid
import nrpy.indexedexp as ixp
import nrpy.params as par

# %% [markdown]
# ## Step 3: Reset finite-difference state
#
# The reset clears tutorial-owned finite-difference helpers and fixes the order used in the next calculation.

# %%
grid.glb_gridfcs_dict.pop("uu", None)
for name in list(fd.FDFunctions_dict):
    if name.startswith("fdD"):
        fd.FDFunctions_dict.pop(name, None)
par.set_parval_from_str("Infrastructure", "BHaH")
par.set_parval_from_str("finite_difference::fd_order", 4)

# %% [markdown]
# ## Step 4: Compute stencil weights
#
# The printed coefficients define the finite-difference stencil.

# %%
coeffs, stencil = fd.compute_fdcoeffs_fdstencl("dDD00", 4)
print("fourth-order second derivative in x0:")
for coeff, point in zip(coeffs, stencil):
    print(coeff, "at", point)
# Out:
# fourth-order second derivative in x0:
# -1/12 at [-2, 0, 0]
# 4/3 at [-1, 0, 0]
# -5/2 at [0, 0, 0]
# 4/3 at [1, 0, 0]
# -1/12 at [2, 0, 0]

# %% [markdown]
# ## Step 5: Register gridfunctions
#
# The registry records named grid fields and their roles in generated code.

# %%
uu = grid.register_gridfunctions("uu", group="EVOL")[0]
uu_dDD = ixp.declarerank2("uu_dDD", symmetry="sym01")
uu_rhs = uu_dDD[0][0]
print("symbolic finite-difference variable:", uu_rhs)
# Out:
# symbolic finite-difference variable: uu_dDD00

# %% [markdown]
# ## Step 6: Generate C code
#
# The output shows how a symbolic expression is emitted as C.

# %%
code = ccg.c_codegen(
    uu_rhs,
    "laplacian_x0",
    include_braces=False,
    verbose=False,
    enable_fd_codegen=True,
    enable_fd_functions=True,
)
print("complete generated assignment:")
print(code)
print("complete finite-difference helper code:")
print(fd.construct_FD_functions_prefunc())
# Out:
# complete generated assignment:
# /*
#  * NRPy-Generated GF Access/FD Code, Step 1 of 2:
#  * Read gridfunction(s) from main memory and compute FD stencils as needed.
#  */
# const REAL uu_i0m2 = in_gfs[IDX4(UUGF, i0-2, i1, i2)];
# const REAL uu_i0m1 = in_gfs[IDX4(UUGF, i0-1, i1, i2)];
# const REAL uu = in_gfs[IDX4(UUGF, i0, i1, i2)];
# const REAL uu_i0p1 = in_gfs[IDX4(UUGF, i0+1, i1, i2)];
# const REAL uu_i0p2 = in_gfs[IDX4(UUGF, i0+2, i1, i2)];
# const REAL uu_dDD00 = fd_function_dDD00_fdorder4(uu,uu_i0m1,uu_i0m2,uu_i0p1,uu_i0p2,invdxx0);
#
# /*
#  * NRPy-Generated GF Access/FD Code, Step 2 of 2:
#  * Evaluate SymPy expressions and write to main memory.
#  */
# laplacian_x0 = uu_dDD00;
#
# complete finite-difference helper code:
# /**
#  * Finite difference function for operator dDD00, with FD accuracy order 4.
#  */
# static NO_INLINE REAL fd_function_dDD00_fdorder4(const REAL FDPROTO, const REAL FDPROTO_i0m1, const REAL FDPROTO_i0m2, const REAL FDPROTO_i0p1,
# ...

# %% [markdown]
# ## Interpreting the Output
# The weights are the numerical stencil, and the generated helper code shows how those weights are applied to grid data. The zero residual confirms the fourth-order stencil differentiates the test polynomial correctly.

# %% [markdown]
# ## Where This Leads
# - [How NRPy Computes Finite-Difference Coefficients](how_NRPy_computes_finite_difference_coeffs.ipynb)
# - [Finite-Difference Playground](../2-numerical_methods/finite_difference_playground.ipynb)
# - [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb)
