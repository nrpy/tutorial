# %% [markdown]
# # Finite Differences
#
# ## Author: Zach Etienne
#
# To run the whole notebook, click the `>>` toolbar button and choose
# **Restart Kernel and Run All Cells...**.
#
# This notebook shows how NRPy turns derivatives of sampled wave fields into
# stencil weights, grid reads, and generated C assignments.
#
# ### Required Reading
#
# - [Grid Fields and Grid Metadata](grid.ipynb), for gridfunction context.
# - [C Code Generation](c_codegen.ipynb), for generated C assignments.
#
# ### NRPy Source Code
#
# - [nrpy-main/nrpy/finite_difference.py](../nrpy-main/nrpy/finite_difference.py):
#   computes stencils and finite-difference helper metadata.
# - [nrpy-main/nrpy/grid.py](../nrpy-main/nrpy/grid.py): stores gridfunction metadata.
# - [nrpy-main/nrpy/c_codegen.py](../nrpy-main/nrpy/c_codegen.py): emits
#   finite-difference-aware C.
#
# # Table of Contents
#
# 1. [Words for This Notebook](#Words-for-This-Notebook)
# 1. [Step 1](#Step-1:-Connect-the-Laplacian-term-to-stencil-weights):
#    Connect stencil weights.
# 1. [Step 2](#Step-2:-Initialize-symbolic-finite-difference-tools):
#    Initialize tools.
# 1. [Step 3](#Step-3:-Reset-tutorial-owned-finite-difference-state): Reset.
# 1. [Step 4](#Step-4:-Derive-centered-second-derivative-weights): Derive.
# 1. [Step 5](#Step-5:-Check-the-polynomial-residual): Check residual.
# 1. [Step 6](#Step-6:-Register-field-symbols-for-grid-reads): Register field.
# 1. [Step 7](#Step-7:-Emit-a-stencil-based-C-assignment): Emit C.
# 1. [Validation Check](#Validation-Check): Validate stencil and helper.
# 1. [Learning Check](#Learning-Check): Check understanding.
# 1. [What next?](#What-next?)

# %% [markdown]
# # Words for This Notebook
# ### [Back to [top](#Table-of-Contents)]
#
# - **Grid spacing:** the distance between neighboring grid points.
# - **Grid point:** one sampled location on the numerical grid.
# - **Stencil:** the pattern of neighboring points used in a derivative.
# - **Stencil width:** the number of grid points used by the stencil.
# - **Finite-difference order:** the formal accuracy order of the derivative
#   approximation.
# - **Centered stencil:** a stencil with offsets balanced around the point.
# - **Derivative notation:** NRPy derivative names encode derivative indices.
# - **`D`:** a lower derivative-index marker in NRPy names.
# - **Residual:** the computed result minus the trusted exact result.
#
# The first code objects are SymPy symbols and NRPy finite-difference helpers.
# Their algorithmic role is to derive stencil weights and later map a
# derivative symbol to BHaH memory reads.

# %% [markdown]
# # Step 1: Connect the Laplacian term to stencil weights
# ### [Back to [top](#Table-of-Contents)]
#
# For a uniform one-dimensional slice, let
#
# $$
# x_{i+s} = x_i + s\Delta x, \qquad u_{i+s} = u(x_i+s\Delta x).
# $$
#
# Taylor expanding each sampled value about `x_i` gives
#
# $$
# u_{i+s} = \sum_{p=0}^{\infty}
# \frac{u^{(p)}(x_i)}{p!}(s\Delta x)^p.
# $$
#
# A finite-difference approximation chooses weights `w_s` so that
#
# $$
# \frac{1}{\Delta x^m}\sum_s w_s u_{i+s}
# $$
#
# keeps the `m`th derivative term and cancels the lower unwanted Taylor moments.
# For the second derivative, the five-point fourth-order centered weights satisfy
#
# $$
# \sum_s w_s\frac{s^p}{p!} =
# \begin{cases}
# 1, & p=2,\\
# 0, & p=0,1,3,4.
# \end{cases}
# $$
#
# For offsets `s = -2,-1,0,1,2`, solving those moment equations yields
#
# $$
# u''(x_i) \approx
# \frac{-u_{i-2} + 16u_{i-1} - 30u_i + 16u_{i+1} - u_{i+2}}
# {12 \Delta x^2}.
# $$
#
# Equivalently, these weights differentiate the unique degree-four polynomial
# through the five sampled points. The Taylor-moment form is useful because it
# shows exactly which terms are kept and which terms are canceled.
#
# The next coefficient-derivation notebook writes these moment equations as a
# matrix system and solves them explicitly. NRPy represents the same idea here
# with offsets, weights, derivative symbols, and generated C grid reads.
#
# | Name | Purpose | Where used | Inspect |
# | --- | --- | --- | --- |
# | `uu` | sampled scalar field | grid registry | generated reads |
# | `uu_dDD00` | second derivative in `x0,x0` | generated C | stencil output |
# | fourth-order centered stencil | derivative approximation | helper metadata | five offsets |
# | BHaH memory read | C grid access | generated C | indexed reads |

# %% [markdown]
# # Step 2: Initialize symbolic finite-difference tools
# ### [Back to [top](#Table-of-Contents)]
#
# SymPy evaluates the polynomial residual exactly.

# %%
import sympy as sp

# %% [markdown]
# Finite-difference, grid, indexed-expression, and code-generation modules
# build stencil coefficients, derivative symbols, and generated C.

# %%
import nrpy.c_codegen as ccg
import nrpy.finite_difference as fd
import nrpy.grid as gri
import nrpy.indexedexp as ixp
import nrpy.params as par

# %% [markdown]
# # Step 3: Reset tutorial-owned finite-difference state
# ### [Back to [top](#Table-of-Contents)]
#
# The reset clears tutorial-owned finite-difference helpers and fixes the
# fourth-order finite-difference setting used in the next calculation.

# %%
gri.glb_gridfcs_dict.pop("uu", None)
for name in list(fd.FDFunctions_dict):
    if name.startswith("fdD"):
        fd.FDFunctions_dict.pop(name, None)
par.set_parval_from_str("Infrastructure", "BHaH")
par.set_parval_from_str("finite_difference::fd_order", 4)

print("infrastructure:", par.parval_from_str("Infrastructure"))
print("finite-difference order:", par.parval_from_str("fd_order"))
# Out:
# infrastructure: BHaH
# finite-difference order: 4

# %% [markdown]
# # Step 4: Derive centered second-derivative weights
# ### [Back to [top](#Table-of-Contents)]
#
# The derivative operator `dDD00` decodes as follows: `d` names a derivative
# operator, `DD` means two lower derivative indices, and `00` means both
# derivative directions are `x0`. Finite-difference order 4 produces the
# five-point centered stencil whose weights solve the Taylor-moment system from
# Step 1. Inspect the complete coefficient/offset list and compare it with the
# mathematical weights in the formula above.

# %%
coeffs, stencil = fd.compute_fdcoeffs_fdstencl("dDD00", 4)
print("fourth-order second derivative in x0:")
for coeff, point in zip(coeffs, stencil):
    print(coeff, "at", point)
# Out:
# fourth-order second derivative in x0:
# -1/12 at [-2, 0, 0]
# 4/3 at [-1, 0, 0]
# -5/2 at [0, 0, 0]
# 4/3 at [1, 0, 0]
# -1/12 at [2, 0, 0]

# %% [markdown]
# # Step 5: Check the polynomial residual
# ### [Back to [top](#Table-of-Contents)]
#
# A fourth-order centered second-derivative stencil should differentiate a
# quartic polynomial exactly on a uniform grid. This check uses unit grid
# spacing; generated C later applies the `invdxx0` scale factor.

# %%
x0 = sp.symbols("x0")
polynomial = x0**4
stencil_value = sum(
    coeff * polynomial.subs(x0, x0 + point[0])
    for coeff, point in zip(coeffs, stencil)
)
exact_second_derivative = sp.diff(polynomial, x0, 2)
polynomial_residual = sp.simplify(stencil_value - exact_second_derivative)

print("stencil value:", sp.expand(stencil_value))
print("exact second derivative:", exact_second_derivative)
print("polynomial residual:", polynomial_residual)
if polynomial_residual != 0:
    raise RuntimeError(f"Expected zero residual, got {polynomial_residual}")
# Out:
# stencil value: 12*x0**2
# exact second derivative: 12*x0**2
# polynomial residual: 0

# %% [markdown]
# # Step 6: Register field symbols for grid reads
# ### [Back to [top](#Table-of-Contents)]
#
# The field `uu` is a scalar `EVOL` gridfunction in 3D. The derivative symbol
# `uu_dDD00` uses repeated `D` letters for a second derivative and directions
# `0,0`. The output prints the base field and the derivative variable that
# generated C will expand.

# %%
uu = gri.register_gridfunctions("uu", group="EVOL")[0]
uu_dDD = ixp.declarerank2("uu_dDD", symmetry="sym01")
uu_rhs = uu_dDD[0][0]
print("registered field:", uu)
print("symbolic finite-difference variable:", uu_rhs)
# Out:
# registered field: uu
# symbolic finite-difference variable: uu_dDD00

# %% [markdown]
# # Step 7: Emit a stencil-based C assignment
# ### [Back to [top](#Table-of-Contents)]
#
# The full assignment and helper code are printed because they teach the
# generated artifact. Inspect the five grid reads, the helper function call,
# and the assignment to `laplacian_x0`.

# %%
code = ccg.c_codegen(
    uu_rhs,
    "laplacian_x0",
    include_braces=False,
    verbose=False,
    enable_fd_codegen=True,
    enable_fd_functions=True,
)
helper_code = fd.construct_FD_functions_prefunc()
print("complete generated assignment:")
print(code)
print("complete finite-difference helper code:")
print(helper_code)
# Out:
# complete generated assignment:
# /*
#  * NRPy-Generated GF Access/FD Code, Step 1 of 2:
#  * Read gridfunction(s) from main memory and compute FD stencils as needed.
#  */
# const REAL uu_i0m2 = in_gfs[IDX4(UUGF, i0-2, i1, i2)];
# const REAL uu_i0m1 = in_gfs[IDX4(UUGF, i0-1, i1, i2)];
# const REAL uu = in_gfs[IDX4(UUGF, i0, i1, i2)];
# const REAL uu_i0p1 = in_gfs[IDX4(UUGF, i0+1, i1, i2)];
# const REAL uu_i0p2 = in_gfs[IDX4(UUGF, i0+2, i1, i2)];
# const REAL uu_dDD00 = fd_function_dDD00_fdorder4(uu,uu_i0m1,uu_i0m2,uu_i0p1,uu_i0p2,invdxx0);
#
# /*
#  * NRPy-Generated GF Access/FD Code, Step 2 of 2:
#  * Evaluate SymPy expressions and write to main memory.
#  */
# laplacian_x0 = uu_dDD00;
#
# complete finite-difference helper code:
# /**
#  * Finite difference function for operator dDD00, with FD accuracy order 4.
#  */
# static NO_INLINE REAL fd_function_dDD00_fdorder4(const REAL FDPROTO, const REAL FDPROTO_i0m1, const REAL FDPROTO_i0m2, const REAL FDPROTO_i0p1,
# ...

# %% [markdown]
# # Validation Check
# ### [Back to [top](#Table-of-Contents)]
#
# The trusted result is the polynomial residual and expected fourth-order
# centered stencil. The newly computed result is NRPy's helper metadata and
# generated C. Passing means coefficients, stencil offsets, residual, helper
# metadata, and complete generated code agree.

# %%
expected_coeffs = [
    sp.Rational(-1, 12),
    sp.Rational(4, 3),
    sp.Rational(-5, 2),
    sp.Rational(4, 3),
    sp.Rational(-1, 12),
]
expected_stencil = [
    [-2, 0, 0],
    [-1, 0, 0],
    [0, 0, 0],
    [1, 0, 0],
    [2, 0, 0],
]
if coeffs != expected_coeffs:
    raise RuntimeError(f"Unexpected coefficients: {coeffs}")
if stencil != expected_stencil:
    raise RuntimeError(f"Unexpected stencil: {stencil}")
if polynomial_residual != 0:
    raise RuntimeError(f"Expected zero residual, got {polynomial_residual}")

fd_function = fd.FDFunctions_dict.get("dDD00")
if fd_function is None:
    raise RuntimeError("Missing dDD00 finite-difference helper metadata")
if fd_function.operator != "dDD00":
    raise RuntimeError(f"Unexpected operator: {fd_function.operator}")
if fd_function.fd_order != 4:
    raise RuntimeError(f"Unexpected helper order: {fd_function.fd_order}")
expected_rational_values = {
    sp.Rational(1, 12),
    sp.Rational(4, 3),
    sp.Rational(5, 2),
}
actual_rational_values = set(fd_function.symbol_to_Rational_dict.values())
if actual_rational_values != expected_rational_values:
    raise RuntimeError(f"Unexpected helper rationals: {actual_rational_values}")

for expected_piece in [
    "fd_function_dDD00_fdorder4",
    "laplacian_x0",
]:
    if expected_piece not in code + helper_code:
        raise RuntimeError(f"Missing {expected_piece} in generated output")

print("validated coefficients:", coeffs)
print("validated polynomial residual:", polynomial_residual)
print("validated helper metadata:", fd_function.operator, fd_function.fd_order)
# Out:
# validated coefficients: [-1/12, 4/3, -5/2, 4/3, -1/12]
# validated polynomial residual: 0
# validated helper metadata: dDD00 4

# %% [markdown]
# # Learning Check
# ### [Back to [top](#Table-of-Contents)]
#
# After running the polynomial check, explain why a zero residual is stronger
# evidence than seeing plausible-looking stencil weights.

# %% [markdown]
# # What next?
#
# - [Coefficient Derivation](how_NRPy_computes_finite_difference_coeffs.ipynb)
# - [Finite-Difference Playground](../2-numerical_methods/finite_difference_playground.ipynb)
# - [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb)
