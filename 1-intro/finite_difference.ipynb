# %% [markdown]
# # Finite Differences
#
# `nrpy.finite_difference` maps derivative symbols to stencils, memory reads, symbolic finite-difference expressions, and optional reusable C helper functions. It is the bridge between symbolic tensor equations and generated grid kernels.

# %% [markdown]
# [Index](../index.ipynb) | Previous: [C Function Registration](c_function.ipynb) | Next: [How NRPy Computes Finite-Difference Coefficients](how_NRPy_computes_finite_difference_coeffs.ipynb)

# %% [markdown]
# ## Why This Matters
#
# Finite differences estimate derivatives from nearby grid samples. Wave-equation right-hand sides and many relativity systems depend on these stencils.

# %% [markdown]
# ## What You Will See
#
# - Finite-difference weights and stencil offsets.
# - Memory reads needed by derivative operators.
# - A compact generated C right-hand-side expression.

# %%
import sympy as sp

import nrpy.c_codegen as ccg
import nrpy.finite_difference as fd
import nrpy.grid as grid
import nrpy.indexedexp as ixp
import nrpy.params as par


def reset_fd_state():
    grid.glb_gridfcs_dict.clear()
    fd.FDFunctions_dict.clear()
    par.set_parval_from_str("Infrastructure", "BHaH")


def coefficient_table(operator, order):
    coeffs, stencil = fd.compute_fdcoeffs_fdstencl(operator, order)
    return list(zip(coeffs, stencil))


reset_fd_state()

# %% [markdown]
# ## Stencil matrices and derivative notation
#
# `setup_FD_matrix__return_inverse(width, shift)` constructs the inverse Taylor matrix. Derivative strings encode the operator and coordinate direction:
#
# - `dD0`: first derivative in direction 0.
# - `dupD0` and `ddnD0`: one-point upwinded and downwinded first derivatives.
# - `dDD02`: mixed second derivative in directions 0 and 2.
# - `dKOD0`: Kreiss-Oliger dissipation derivative in direction 0.

# %%
print("3-point centered inverse:")
print(fd.setup_FD_matrix__return_inverse(3, 0))

for operator in ["dD0", "dupD0", "ddnD0", "dDD02", "dKOD0"]:
    print(operator)
    for coeff, point in coefficient_table(operator, 4):
        print(f"  {str(coeff):>6} at {point}")
# Out:
# 3-point centered inverse:
# Matrix([[0, -1/2, 1/2], [1, 0, -1], [0, 1/2, 1/2]])
# dD0
#     1/12 at [-2, 0, 0]
#     -2/3 at [-1, 0, 0]
#      2/3 at [1, 0, 0]
#    -1/12 at [2, 0, 0]
# dupD0
#     -1/4 at [-1, 0, 0]
#     -5/6 at [0, 0, 0]
#      3/2 at [1, 0, 0]
#     -1/2 at [2, 0, 0]
#     1/12 at [3, 0, 0]
# ddnD0
#    -1/12 at [-3, 0, 0]
#      1/2 at [-2, 0, 0]
#     -3/2 at [-1, 0, 0]
#      5/6 at [0, 0, 0]
#      1/4 at [1, 0, 0]
# dDD02
#    1/144 at [-2, 0, -2]
#    -1/18 at [-1, 0, -2]
#     1/18 at [1, 0, -2]
#   -1/144 at [2, 0, -2]
#    -1/18 at [-2, 0, -1]
#      4/9 at [-1, 0, -1]
#     -4/9 at [1, 0, -1]
#     1/18 at [2, 0, -1]
#     1/18 at [-2, 0, 1]
#     -4/9 at [-1, 0, 1]
#      4/9 at [1, 0, 1]
#    -1/18 at [2, 0, 1]
#   -1/144 at [-2, 0, 2]
#     1/18 at [-1, 0, 2]
#    -1/18 at [1, 0, 2]
#    1/144 at [2, 0, 2]
# dKOD0
#     1/64 at [-3, 0, 0]
#    -3/32 at [-2, 0, 0]
#    15/64 at [-1, 0, 0]
#    -5/16 at [0, 0, 0]
#    15/64 at [1, 0, 0]
# ...

# %% [markdown]
# ## Discovering derivative symbols
#
# Derivative symbols are ordinary SymPy symbols whose names contain derivative suffixes. NRPy separates base gridfunction names from derivative operators.

# %%
reset_fd_state()
hDD = grid.register_gridfunctions_for_single_rank2("hDD", group="EVOL", symmetry="sym01")
vU = grid.register_gridfunctions_for_single_rank1("vU", group="EVOL")
hDD_dD = ixp.declarerank3("hDD_dD", symmetry="sym01")
hDD_dupD = ixp.declarerank3("hDD_dupD", symmetry="sym01")

exprs = [
    hDD_dD[0][1][2] + vU[0],
    hDD_dupD[0][2][0] + hDD[0][2],
]
free_symbols = []
for expr in exprs:
    free_symbols.extend(expr.free_symbols)

deriv_vars = fd.extract_list_of_deriv_var_strings_from_sympyexpr_list(
    free_symbols,
    sp.Symbol("upwind_control"),
)
base_gfs, deriv_ops = fd.extract_base_gfs_and_deriv_ops_lists__from_list_of_deriv_vars(
    deriv_vars
)

print("derivative symbols:", deriv_vars)
print("base gridfunctions:", base_gfs)
print("operators:", deriv_ops)
# Out:
# derivative symbols: [hDD_dD012, hDD_ddnD020, hDD_dupD020]
# base gridfunctions: ['hDD01', 'hDD02', 'hDD02']
# operators: ['dD2', 'ddnD0', 'dupD0']

# %% [markdown]
# ## Reading required gridfunction data
#
# `read_gfs_from_memory` uses the derivative operators and the free symbols in the expressions to emit only the gridfunction reads required by the stencil.

# %%
fdcoeffs = [[] for _ in deriv_ops]
fdstencl = [[[] for _ in range(4)] for __ in deriv_ops]
for i, operator in enumerate(deriv_ops):
    fdcoeffs[i], fdstencl[i] = fd.compute_fdcoeffs_fdstencl(operator, 2)

read_code = fd.read_gfs_from_memory(
    base_gfs,
    fdstencl,
    free_symbols,
    mem_alloc_style="210",
    enable_simd=False,
)
print(read_code)
# Out:
# const REAL hDD01_i2m1 = in_gfs[IDX4(HDD01GF, i0, i1, i2-1)];
# const REAL hDD01_i2p1 = in_gfs[IDX4(HDD01GF, i0, i1, i2+1)];
# const REAL hDD02_i0m2 = in_gfs[IDX4(HDD02GF, i0-2, i1, i2)];
# const REAL hDD02_i0m1 = in_gfs[IDX4(HDD02GF, i0-1, i1, i2)];
# const REAL hDD02 = in_gfs[IDX4(HDD02GF, i0, i1, i2)];
# const REAL hDD02_i0p1 = in_gfs[IDX4(HDD02GF, i0+1, i1, i2)];
# const REAL hDD02_i0p2 = in_gfs[IDX4(HDD02GF, i0+2, i1, i2)];
# const REAL vU0 = in_gfs[IDX4(VU0GF, i0, i1, i2)];

# %% [markdown]
# ## Prototype operators as SymPy expressions
#
# `proto_FD_operators_to_sympy_expressions` builds symbolic finite-difference expressions for a prototype gridfunction. It also populates `FDFunctions_dict` with operator metadata.

# %%
reset_fd_state()
FDPROTO = grid.register_gridfunctions("FDPROTO", group="EVOL")[0]
FDPROTO_dD = ixp.declarerank1("FDPROTO_dD")
FDPROTO_dDD = ixp.declarerank2("FDPROTO_dDD", symmetry="sym01")
FDPROTO_dKOD = ixp.declarerank1("FDPROTO_dKOD")

proto_exprs = [FDPROTO_dD[0] + FDPROTO_dDD[0][2] + FDPROTO_dKOD[1]]
proto_free_symbols = []
for expr in proto_exprs:
    proto_free_symbols.extend(expr.free_symbols)

proto_derivs = fd.extract_list_of_deriv_var_strings_from_sympyexpr_list(
    proto_free_symbols,
    sp.Symbol("unset"),
)
proto_ops = [str(item).split("_")[1] for item in proto_derivs]
proto_coeffs = []
proto_stencils = []
for operator in proto_ops:
    coeffs, stencil = fd.compute_fdcoeffs_fdstencl(operator, 2)
    proto_coeffs.append(coeffs)
    proto_stencils.append(stencil)

fd_exprs, fd_lhs_names, rational_symbols = fd.proto_FD_operators_to_sympy_expressions(
    proto_derivs,
    2,
    proto_coeffs,
    proto_stencils,
)

for lhs, expr in zip(fd_lhs_names, fd_exprs):
    print(lhs, "=", expr)
print("function dictionary keys:", sorted(fd.FDFunctions_dict))
print("rational substitutions:", rational_symbols)
# Out:
# const REAL FDPROTO_dD0 = FDPart1_Rational_1_2*invdxx0*(-FDPROTO_i0m1 + FDPROTO_i0p1)
# const REAL FDPROTO_dDD02 = FDPart1_Rational_1_4*invdxx0*invdxx2*(FDPROTO_i0m1_i2m1 - FDPROTO_i0m1_i2p1 - FDPROTO_i0p1_i2m1 + FDPROTO_i0p1_i2p1)
# const REAL FDPROTO_dKOD1 = invdxx1*(-FDPROTO*FDPart1_Rational_3_8 + FDPart1_Rational_1_16*(-FDPROTO_i1m2 - FDPROTO_i1p2) + FDPart1_Rational_1_4*(FDPROTO_i1m1 + FDPROTO_i1p1))
# function dictionary keys: ['dD0', 'dDD02', 'dKOD1']
# rational substitutions: {FDPart1_Rational_1_2: 1/2, FDPart1_Rational_1_4: 1/4, FDPart1_Rational_3_8: 3/8, FDPart1_Rational_1_16: 1/16}

# %% [markdown]
# ## Reusable finite-difference helper functions
#
# `c_codegen` can request reusable finite-difference helper functions. After code generation, `construct_FD_functions_prefunc` collects their C text from `FDFunctions_dict`.

# %%
reset_fd_state()
par.set_parval_from_str("finite_difference::fd_order", 2)
u = grid.register_gridfunctions("u", group="EVOL")[0]
u_dD = ixp.declarerank1("u_dD")

kernel_code = ccg.c_codegen(
    u_dD[0] + u,
    "rhs_u",
    include_braces=False,
    verbose=False,
    enable_fd_codegen=True,
    enable_fd_functions=True,
)
prefunc = fd.construct_FD_functions_prefunc()

print("complete kernel code:")
print(kernel_code)
print("helper keys:", sorted(fd.FDFunctions_dict))
print("complete helper code:")
print(prefunc)
# Out:
# complete kernel code:
# /*
#  * NRPy-Generated GF Access/FD Code, Step 1 of 2:
#  * Read gridfunction(s) from main memory and compute FD stencils as needed.
#  */
# const REAL u_i0m1 = in_gfs[IDX4(UGF, i0-1, i1, i2)];
# const REAL u = in_gfs[IDX4(UGF, i0, i1, i2)];
# const REAL u_i0p1 = in_gfs[IDX4(UGF, i0+1, i1, i2)];
# const REAL u_dD0 = fd_function_dD0_fdorder2(u_i0m1,u_i0p1,invdxx0);
#
# /*
#  * NRPy-Generated GF Access/FD Code, Step 2 of 2:
#  * Evaluate SymPy expressions and write to main memory.
#  */
# rhs_u = u + u_dD0;
#
# helper keys: ['dD0']
# complete helper code:
# /**
#  * Finite difference function for operator dD0, with FD accuracy order 2.
#  */
# static NO_INLINE REAL fd_function_dD0_fdorder2(const REAL FDPROTO_i0m1, const REAL FDPROTO_i0p1, const REAL invdxx0) {
#   static const REAL FDPart1_Rational_1_2 = 1.0 / 2.0;
#   const REAL FD_result = FDPart1_Rational_1_2 * invdxx0 * (-FDPROTO_i0m1 + FDPROTO_i0p1);
#
#   return FD_result;
# ...

# %% [markdown]
# ## Where This Leads
#
# - [C Function Registration](c_function.ipynb) reviews the prerequisite step.
# - [How NRPy Computes Finite-Difference Coefficients](how_NRPy_computes_finite_difference_coeffs.ipynb) continues the tutorial path.
# - [Wave Equation with NumPy](../2-numerical_methods/wave_equation_with_numpy.ipynb) connects this topic to a natural application.
# - [Finite-Difference Playground](../2-numerical_methods/finite_difference_playground.ipynb) connects this topic to a natural application.
