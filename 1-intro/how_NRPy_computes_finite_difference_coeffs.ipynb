# %% [markdown]
# # How NRPy Computes Finite-Difference Coefficients
#
# ## Author: Zach Etienne
#
# To run the whole notebook, click the `>>` toolbar button and choose
# **Restart Kernel and Run All Cells...**.
#
# This notebook derives the five-point fourth-order centered second-derivative
# stencil by matching Taylor moments, then compares the hand-derived weights to
# NRPy's finite-difference coefficient routine.
#
# ### Required Reading
#
# - [Finite Differences](finite_difference.ipynb), for derivative-name and
#   stencil context.
#
# ### NRPy Source Code
#
# - [nrpy-main/nrpy/finite_difference.py](../nrpy-main/nrpy/finite_difference.py):
#   computes finite-difference coefficients and stencil offsets.
#
# # Table of Contents
#
# 1. [Words for This Notebook](#Words-for-This-Notebook)
# 1. [Step 1](#Step-1:-Derive-one-stencil-from-Taylor-matching): Derive.
# 1. [Step 2](#Step-2:-Initialize-Taylor-algebra-and-NRPy-stencil-tools):
#    Initialize tools.
# 1. [Step 3](#Step-3:-Solve-Taylor-matching-weights-by-hand): Solve by hand.
# 1. [Step 4](#Step-4:-Ask-NRPy-for-the-same-stencil): Ask NRPy.
# 1. [Step 5](#Step-5:-Verify-Taylor-moment-residuals): Verify residuals.
# 1. [Learning Check](#Learning-Check): Check understanding.
# 1. [What next?](#What-next?)

# %% [markdown]
# # Words for This Notebook
# ### [Back to [top](#Table-of-Contents)]
#
# - **Derivative order:** which derivative the stencil approximates.
# - **Finite-difference order:** the formal accuracy order of the approximation.
# - **Stencil offset:** a grid displacement such as `-2`, `-1`, `0`, `+1`, or
#   `+2`.
# - **Taylor moment:** one equation that keeps or cancels a Taylor-series term.
# - **Taylor matrix:** the linear system whose columns are stencil offsets and
#   whose rows are Taylor powers.
# - **Moment residual:** the amount left after checking one Taylor moment.
# - **Leading error coefficient:** the first nonzero uncanceled Taylor moment,
#   which determines the dominant truncation error.
# - **`dDD00`:** NRPy's name for a second derivative in the `x0,x0` directions.
#
# The first code objects are the Taylor matrix and right-hand side. Their
# mathematical role is to solve for weights that keep the desired derivative
# term, cancel the unwanted moments, and expose the leading error term.

# %% [markdown]
# # Step 1: Derive one stencil from Taylor matching
# ### [Back to [top](#Table-of-Contents)]
#
# Following the legacy NRPy tutorial derivation, consider a smooth function `u(x)`
# sampled on a uniform grid,
#
# $$
# x_{i+s} = x_i + s\Delta x, \qquad u_{i+s}=u(x_i+s\Delta x).
# $$
#
# Taylor expand each sampled value about the point `x_i` where the derivative is
# wanted:
#
# $$
# u_{i+s} = \sum_{p=0}^{\infty}
# \frac{u^{(p)}(x_i)}{p!}(s\Delta x)^p.
# $$
#
# Now choose stencil weights `w_s` and form the weighted sum
#
# $$
# \sum_s w_s u_{i+s}
# = \sum_{p=0}^{\infty}
# \left(\sum_s w_s\frac{s^p}{p!}\right)
# (\Delta x)^p u^{(p)}(x_i).
# $$
#
# For the second derivative, divide the final weighted sum by $\Delta x^2$. The
# weights must therefore keep the `p=2` Taylor moment and cancel the moments that
# would contaminate the derivative:
#
# $$
# \sum_s w_s\frac{s^p}{p!} =
# \begin{cases}
# 1, & p = 2,\\
# 0, & p = 0,1,3,4.
# \end{cases}
# $$
#
# For the five-point centered stencil `s = -2,-1,0,1,2`, these equations become
#
# $$
# \begin{pmatrix}
# 1 & 1 & 1 & 1 & 1\\
# -2 & -1 & 0 & 1 & 2\\
# (-2)^2/2! & (-1)^2/2! & 0 & 1/2! & 2^2/2!\\
# (-2)^3/3! & (-1)^3/3! & 0 & 1/3! & 2^3/3!\\
# (-2)^4/4! & (-1)^4/4! & 0 & 1/4! & 2^4/4!
# \end{pmatrix}
# \begin{pmatrix}
# w_{-2}\\w_{-1}\\w_0\\w_1\\w_2
# \end{pmatrix}
# =
# \begin{pmatrix}
# 0\\0\\1\\0\\0
# \end{pmatrix}.
# $$
#
# Solving this system gives the weights that appear in the fourth-order centered
# second derivative,
#
# $$
# u''(x_i) \approx \frac{1}{\Delta x^2}
# \left[-\frac{1}{12}u_{i-2}+\frac{4}{3}u_{i-1}
# -\frac{5}{2}u_i+\frac{4}{3}u_{i+1}-\frac{1}{12}u_{i+2}\right].
# $$
#
# This is equivalent to differentiating twice the unique degree-four polynomial
# through the five sampled points. The Taylor-matching system is the form NRPy
# uses because the matrix rows make each kept or canceled term explicit.
#
# The first uncanceled term is the `p=6` moment, so after division by
# $\Delta x^2$ the dominant error scales as $\Delta x^4$.
#
# | Name | Purpose | Where used | Inspect |
# | --- | --- | --- | --- |
# | offsets `-2,-1,0,+1,+2` | stencil locations | matrix columns | centered order |
# | derivative order `2` | target derivative | RHS vector | kept moment |
# | Taylor powers `0..4` | enforced moments | matrix rows | cancellation |
# | `p=6` moment | leading error | validation | $\Delta x^4$ scaling |

# %% [markdown]
# # Step 2: Initialize Taylor algebra and NRPy stencil tools
# ### [Back to [top](#Table-of-Contents)]
#
# SymPy solves the small Taylor-matching linear system exactly.

# %%
import sympy as sp

# %% [markdown]
# NRPy's finite-difference helper computes the same weights from the
# derivative name and finite-difference order.

# %%
import nrpy.finite_difference as fd

# %% [markdown]
# # Step 3: Solve Taylor-matching weights by hand
# ### [Back to [top](#Table-of-Contents)]
#
# The complete Taylor matrix, right-hand side, solution weights, and leading error
# coefficient show the algebra behind the stencil. Rows are Taylor powers and
# columns are stencil offsets.

# %%
offsets = [-2, -1, 0, 1, 2]
derivative_order = 2
A = sp.Matrix(
    [
        [
            sp.Rational(offset) ** power / sp.factorial(power)
            for offset in offsets
        ]
        for power in range(len(offsets))
    ]
)
b = sp.Matrix(
    [1 if power == derivative_order else 0 for power in range(len(offsets))]
)
weights = A.LUsolve(b)
leading_error_power = 6
leading_error_coefficient = sp.simplify(
    sum(
        weights[i] * offsets[i] ** leading_error_power
        / sp.factorial(leading_error_power)
        for i in range(len(offsets))
    )
)

print("Taylor system matrix:")
print(A)
print("right-hand side:")
print(b)
print("hand-derived weights:")
print(list(weights))
print("operator:")
print("u_xx ~= (sum_s w_s u_{i+s}) / Delta_x^2")
print("leading p=6 moment coefficient:", leading_error_coefficient)
# Out:
# Taylor system matrix:
# Matrix([[1, 1, 1, 1, 1], [-2, -1, 0, 1, 2], [2, 1/2, 0, 1/2, 2], [-4/3, -1/6, 0, 1/6, 4/3], [2/3, 1/24, 0, 1/24, 2/3]])
# right-hand side:
# Matrix([[0], [0], [1], [0], [0]])
# hand-derived weights:
# [-1/12, 4/3, -5/2, 4/3, -1/12]
# operator:
# u_xx ~= (sum_s w_s u_{i+s}) / Delta_x^2
# leading p=6 moment coefficient: -1/90

# %% [markdown]
# # Step 4: Ask NRPy for the same stencil
# ### [Back to [top](#Table-of-Contents)]
#
# The operator `dDD00` means a second derivative in the `x0,x0` directions;
# [Finite Differences](finite_difference.ipynb) gives the fuller naming
# convention. Requesting finite-difference order 4 should return the same
# five-point centered weights and offsets derived above.

# %%
coeffs, stencil = fd.compute_fdcoeffs_fdstencl("dDD00", 4)
print("NRPy weights and offsets:")
for coeff, point in zip(coeffs, stencil):
    print(coeff, "at", point)
# Out:
# NRPy weights and offsets:
# -1/12 at [-2, 0, 0]
# 4/3 at [-1, 0, 0]
# -5/2 at [0, 0, 0]
# 4/3 at [1, 0, 0]
# -1/12 at [2, 0, 0]

# %% [markdown]
# # Step 5: Verify Taylor moment residuals
# ### [Back to [top](#Table-of-Contents)]
#
# The trusted result is the hand-solved Taylor system. The newly computed result
# is NRPy's coefficient and offset list. Passing means NRPy returns the same
# weights and offsets, the enforced moments through `p=4` vanish as required, the
# symmetric `p=5` moment also cancels, and the first nonzero residual is the
# `p=6` leading-error coefficient.

# %%
moment_residuals = [
    sp.simplify(
        sum(
            weights[i] * offsets[i] ** power / sp.factorial(power)
            for i in range(len(offsets))
        )
        - (1 if power == derivative_order else 0)
    )
    for power in range(leading_error_power + 1)
]

expected_stencil = [
    [-2, 0, 0],
    [-1, 0, 0],
    [0, 0, 0],
    [1, 0, 0],
    [2, 0, 0],
]
expected_weights = [
    sp.Rational(-1, 12),
    sp.Rational(4, 3),
    sp.Rational(-5, 2),
    sp.Rational(4, 3),
    sp.Rational(-1, 12),
]
expected_residuals = [0, 0, 0, 0, 0, 0, sp.Rational(-1, 90)]
if list(weights) != expected_weights:
    raise RuntimeError(f"Hand weights {list(weights)} != expected {expected_weights}")
if coeffs != expected_weights:
    raise RuntimeError(f"NRPy weights {coeffs} != expected {expected_weights}")
if stencil != expected_stencil:
    raise RuntimeError(f"Unexpected stencil: {stencil}")
if moment_residuals != expected_residuals:
    raise RuntimeError(f"Unexpected Taylor residuals: {moment_residuals}")

print("trusted result: hand-solved Taylor system")
print("newly computed result: NRPy-computed coefficients and stencil")
print("Taylor residuals p=0..6:", moment_residuals)
print("validated NRPy weights:", coeffs)
print("validated NRPy stencil:", stencil)
print("dominant error term: -Delta_x^4*u^(6)(x_i)/90")
# Out:
# trusted result: hand-solved Taylor system
# newly computed result: NRPy-computed coefficients and stencil
# Taylor residuals p=0..6: [0, 0, 0, 0, 0, 0, -1/90]
# validated NRPy weights: [-1/12, 4/3, -5/2, 4/3, -1/12]
# validated NRPy stencil: [[-2, 0, 0], [-1, 0, 0], [0, 0, 0], [1, 0, 0], [2, 0, 0]]
# dominant error term: -Delta_x^4*u^(6)(x_i)/90

# %% [markdown]
# # Learning Check
# ### [Back to [top](#Table-of-Contents)]
#
# After solving the system, explain why five unknown weights require five Taylor
# moment equations, and why symmetry cancels the odd `p=5` moment even though it
# was not one of the matrix rows.

# %% [markdown]
# # What next?
#
# - [Reference Metrics](reference_metric.ipynb)
# - [Finite Differences](finite_difference.ipynb)
# - [Finite-Difference Playground](../2-numerical_methods/finite_difference_playground.ipynb)
