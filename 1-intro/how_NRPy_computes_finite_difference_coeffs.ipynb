# %% [markdown]
# # How NRPy Computes Finite-Difference Coefficients
#
# Derive finite-difference coefficients by enforcing Taylor-series cancellation conditions.
#
# Navigation: [Index](../index.ipynb) | Previous: [Finite Differences](finite_difference.ipynb) | Next: [Reference Metrics](reference_metric.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Derive finite-difference weights from Taylor series matching.
# - Compare the hand-derived weights to NRPy's computed weights.
# - Understand why residual checks prove the stencil cancels unwanted terms.
#
# ## Words for This Notebook
#
# - **Taylor series:** a way to approximate a function near a point using derivatives.
# - **Linear system:** a set of equations solved together for unknown numbers.
# - **Moment condition:** one equation that forces the stencil to keep or cancel a Taylor-series term.
# - **Residual:** the leftover value after checking a condition.
#
# Use the code cells actively: first predict what should happen, then run the cell, then explain the output in plain language. This predict-run-explain pattern keeps the physics idea connected to the programming details.

# %% [markdown]
# ## Derive One Stencil by Hand
# For offsets -1, 0, and 1, the weights must cancel the constant and first-derivative Taylor terms while keeping the second derivative.

# %% [markdown]
# ## Import SymPy Linear Algebra Tools
#
# These imports expose the NRPy and Python tools used in the next steps.

# %%
import sympy as sp

# %% [markdown]
# ## Import NRPy Stencil Coefficients
#
# These imports expose the NRPy registries and infrastructure writers used below.

# %%
import nrpy.finite_difference as fd

# %% [markdown]
# ## Solve Taylor-Matching Weights by Hand
#
# The Taylor system determines the stencil coefficients for the requested derivative.

# %%
offsets = [-1, 0, 1]
derivative_order = 2
A = sp.Matrix(
    [
        [sp.Rational(offset) ** power / sp.factorial(power) for offset in offsets]
        for power in range(len(offsets))
    ]
)
b = sp.Matrix([1 if power == derivative_order else 0 for power in range(len(offsets))])
weights = A.LUsolve(b)

# %% [markdown]
# ## Inspect the Taylor Matrix
#
# The matrix, right-hand side, and solution weights show the algebra behind the stencil.

# %%
print("Taylor system matrix:")
print(A)
print("right-hand side:")
print(b)
print("solution weights:")
print(list(weights))
# Out:
# Taylor system matrix:
# Matrix([[1, 1, 1], [-1, 0, 1], [1/2, 0, 1/2]])
# right-hand side:
# Matrix([[0], [0], [1]])
# solution weights:
# [1, -2, 1]

# %% [markdown]
# ## Ask NRPy for the Same Stencil
#
# The printed coefficients define the finite-difference stencil.

# %%
coeffs, stencil = fd.compute_fdcoeffs_fdstencl("dDD00", 2)
print("NRPy weights and offsets:")
for coeff, point in zip(coeffs, stencil):
    print(coeff, "at", point)
# Out:
# NRPy weights and offsets:
# 1 at [-1, 0, 0]
# -2 at [0, 0, 0]
# 1 at [1, 0, 0]

# %% [markdown]
# ## Verify the Taylor Moment Residuals
#
# A zero residual confirms that the symbolic expression matches the expected identity.

# %%
residuals = [
    sp.simplify(
        sum(
            weights[i] * offsets[i] ** power / sp.factorial(power)
            for i in range(len(offsets))
        )
        - (1 if power == derivative_order else 0)
    )
    for power in range(len(offsets))
]
print("Taylor residuals:", residuals)
if residuals != [0, 0, 0]:
    raise RuntimeError("Expected all Taylor residuals to vanish.")
# Out:
# Taylor residuals: [0, 0, 0]

# %% [markdown]
# The Vandermonde solve explains where the stencil weights come from. The residual checks show that the weights reproduce the intended derivative order and cancel lower-order terms.

# %% [markdown]
# ## Learning Check
#
# Before solving the system, count how many unknown weights there are and how many equations are needed. The numbers should match.

# %% [markdown]
# ## Continue to Reference Metrics
# - [Finite Differences](finite_difference.ipynb)
# - [Finite-Difference Playground](../2-numerical_methods/finite_difference_playground.ipynb)
