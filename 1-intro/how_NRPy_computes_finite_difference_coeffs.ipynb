# %% [markdown]
# # How NRPy Computes Finite-Difference Coefficients
#
# Derive finite-difference coefficients by enforcing Taylor-series
# cancellation conditions.
#
# Navigation: [Index](../index.ipynb) |
# Previous: [Finite Differences](finite_difference.ipynb) |
# Next: [Reference Metrics](reference_metric.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Derive finite-difference weights from Taylor series matching.
# - Compare the hand-derived weights to NRPy2's computed weights.
# - Understand why residual checks prove the stencil cancels unwanted terms.
#
# ## Problem Statement
#
# The finite-difference notebook used stencil weights as facts. This notebook
# shows where those weights come from: solve a small linear system so unwanted
# Taylor-series terms cancel and the desired derivative term remains.
#
# ## Words for This Notebook
#
# - **Taylor series:** a way to approximate a function near a point using
#   derivatives.
# - **Linear system:** a set of equations solved together for unknown numbers.
# - **Moment condition:** one equation that forces the stencil to keep or cancel a
#   Taylor-series term.
# - **Residual:** the leftover value after checking a condition.

# %% [markdown]
# ## Step 1: Derive One Stencil by Hand
#
# For offsets -1, 0, and 1, the weights must cancel the constant and
# first-derivative Taylor terms while keeping the second derivative.
#
# The moment condition is
#
# $$
# \sum_i w_i \frac{s_i^p}{p!} =
# \begin{cases}
# 1, & p = 2,\\
# 0, & p \ne 2.
# \end{cases}
# $$

# %% [markdown]
# ## Setup: Import SymPy Linear Algebra Tools
#
# SymPy solves the small Taylor-matching linear system exactly.

# %%
import sympy as sp

# %% [markdown]
# ## Setup: Import NRPy2 Stencil Coefficients
#
# NRPy2's finite-difference helper computes the same weights from the derivative
# name and finite-difference order.

# %%
import nrpy.finite_difference as fd

# %% [markdown]
# ## Step 2: Solve Taylor-Matching Weights by Hand
#
# The Taylor matrix, right-hand side, and solution weights show the algebra behind
# the stencil.

# %%
offsets = [-1, 0, 1]
derivative_order = 2
A = sp.Matrix(
    [
        [
            sp.Rational(offset) ** power / sp.factorial(power)
            for offset in offsets
        ]
        for power in range(len(offsets))
    ]
)
b = sp.Matrix(
    [1 if power == derivative_order else 0 for power in range(len(offsets))]
)
weights = A.LUsolve(b)

print("Taylor system matrix:")
print(A)
print("right-hand side:")
print(b)
print("hand-derived weights:")
print(list(weights))
# Out:
# Taylor system matrix:
# Matrix([[1, 1, 1], [-1, 0, 1], [1/2, 0, 1/2]])
# right-hand side:
# Matrix([[0], [0], [1]])
# hand-derived weights:
# [1, -2, 1]

# %% [markdown]
# ## Step 3: Ask NRPy2 for the Same Stencil
#
# The printed coefficients should match the hand-derived weights.

# %%
coeffs, stencil = fd.compute_fdcoeffs_fdstencl("dDD00", 2)
print("NRPy weights and offsets:")
for coeff, point in zip(coeffs, stencil):
    print(coeff, "at", point)
# Out:
# NRPy weights and offsets:
# 1 at [-1, 0, 0]
# -2 at [0, 0, 0]
# 1 at [1, 0, 0]

# %% [markdown]
# ## Step 4: Verify the Taylor Moment Residuals
#
# A zero residual means each Taylor moment condition was satisfied.

# %%
residuals = [
    sp.simplify(
        sum(
            weights[i] * offsets[i] ** power / sp.factorial(power)
            for i in range(len(offsets))
        )
        - (1 if power == derivative_order else 0)
    )
    for power in range(len(offsets))
]

expected_stencil = [[-1, 0, 0], [0, 0, 0], [1, 0, 0]]
if list(weights) != coeffs:
    raise RuntimeError(f"Hand weights {list(weights)} != NRPy {coeffs}")
if stencil != expected_stencil:
    raise RuntimeError(f"Unexpected stencil: {stencil}")
if residuals != [0, 0, 0]:
    raise RuntimeError(f"Expected all Taylor residuals to vanish: {residuals}")

print("Taylor residuals:", residuals)
print("validated NRPy weights:", coeffs)
print("validated NRPy stencil:", stencil)
# Out:
# Taylor residuals: [0, 0, 0]
# validated NRPy weights: [1, -2, 1]
# validated NRPy stencil: [[-1, 0, 0], [0, 0, 0], [1, 0, 0]]

# %% [markdown]
# ## Learning Check
#
# After solving the system, explain why three unknown weights require three
# Taylor moment equations for this centered stencil.

# %% [markdown]
# ## Continue to Reference Metrics
#
# - [Reference Metrics](reference_metric.ipynb)
# - [Finite Differences](finite_difference.ipynb)
# - [Finite-Difference Playground](../2-numerical_methods/finite_difference_playground.ipynb)
