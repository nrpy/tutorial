# %% [markdown]
# # Gridfunctions and Grid Metadata
#
# `nrpy.grid` registers symbolic gridfunctions and stores metadata used by generated infrastructure code: group, rank, dimension, parity, memory layout, value at infinity, and characteristic wave speed.

# %% [markdown]
# [Index](../index.ipynb) | Previous: [Indexed Expressions](indexedexp.ipynb) | Next: [C Code Generation](c_codegen.ipynb)

# %% [markdown]
# ## Why This Matters
#
# A gridfunction is a field sampled on grid points. Registering gridfunctions tells generated code which arrays store evolved fields, auxiliary fields, right-hand sides, and diagnostics.

# %% [markdown]
# ## What You Will See
#
# - Registered gridfunction names and groups.
# - Metadata such as parity and memory access.
# - A short validation error and corrected gridfunction name.

# %%
import nrpy.grid as grid
import nrpy.params as par


def reset_grid(infrastructure="BHaH"):
    grid.glb_gridfcs_dict.clear()
    par.set_parval_from_str("Infrastructure", infrastructure)


reset_grid()

# %% [markdown]
# ## Scalar, vector, tensor, and higher-rank registration
#
# The BHaH groups used most often in generated projects are `EVOL`, `AUXEVOL`, `DIAG`, and `AUX`.

# %%
u = grid.register_gridfunctions("u", group="EVOL", f_infinity=0.0, wavespeed=1.0)[0]
vU = grid.register_gridfunctions_for_single_rank1("vU", group="AUXEVOL")
gDD = grid.register_gridfunctions_for_single_rank2("gDD", symmetry="sym01", group="DIAG")
TDDD = grid.register_gridfunctions_for_single_rankN(
    "TDDD",
    rank=3,
    symmetry="sym12",
    group="AUX",
)

print("scalar:", u)
print("vector:", vU)
print("symmetric tensor row 0:", gDD[0])
print("rank-3 sample:", TDDD[0][1][2], TDDD[0][2][1])
print("registered names:", sorted(grid.glb_gridfcs_dict))
# Out:
# scalar: u
# vector: [vU0, vU1, vU2]
# symmetric tensor row 0: [gDD00, gDD01, gDD02]
# rank-3 sample: TDDD012 TDDD012
# registered names: ['TDDD000', 'TDDD001', 'TDDD002', 'TDDD011', 'TDDD012', 'TDDD022', 'TDDD100', 'TDDD101', 'TDDD102', 'TDDD111', 'TDDD112', 'TDDD122', 'TDDD200', 'TDDD201', 'TDDD202', 'TDDD211', 'TDDD212', 'TDDD222', 'gDD00', 'gDD01', 'gDD02', 'gDD11', 'gDD12', 'gDD22', 'u', 'vU0', 'vU1', 'vU2']

# %% [markdown]
# ## Group lists and metadata
#
# Each registration creates a `GridFunction` object in `glb_gridfcs_dict`.

# %%
evol, auxevol, diag, aux = grid.GridFunction.gridfunction_lists()
print("EVOL:", evol)
print("AUXEVOL:", auxevol)
print("DIAG:", diag)
print("AUX:", aux)

for name in ["u", "vU0", "gDD01", "TDDD012"]:
    item = grid.glb_gridfcs_dict[name]
    print(name, item.group, item.rank, item.dimension, item.gf_type)
# Out:
# EVOL: ['u']
# AUXEVOL: ['vU0', 'vU1', 'vU2']
# DIAG: ['gDD00', 'gDD01', 'gDD02', 'gDD11', 'gDD12', 'gDD22']
# AUX: ['TDDD000', 'TDDD001', 'TDDD002', 'TDDD011', 'TDDD012', 'TDDD022', 'TDDD100', 'TDDD101', 'TDDD102', 'TDDD111', 'TDDD112', 'TDDD122', 'TDDD200', 'TDDD201', 'TDDD202', 'TDDD211', 'TDDD212', 'TDDD222']
# u EVOL 0 3 REAL
# vU0 AUXEVOL 1 3 REAL
# gDD01 DIAG 2 3 REAL
# TDDD012 AUX 3 3 REAL

# %% [markdown]
# ## Parity metadata
#
# Parity types encode scalar, vector, and tensor behavior under spatial inversion. They are derived from the registered rank and component indices.

# %%
parity_names = ["u", "vU0", "vU1", "gDD00", "gDD12"]
print(dict(zip(parity_names, grid.GridFunction.set_parity_types(parity_names))))
# Out:
# {'u': 0, 'vU0': 1, 'vU1': 2, 'gDD00': 4, 'gDD12': 8}

# %% [markdown]
# ## Infrastructure-aware memory access
#
# The same symbolic gridfunction can produce different one-point C memory reads depending on the selected infrastructure.

# %%
for infrastructure in ["BHaH", "ETLegacy", "CarpetX"]:
    reset_grid(infrastructure)
    q = grid.register_gridfunctions("q", group="EVOL")[0]
    access = grid.glb_gridfcs_dict[str(q)].read_gf_from_memory_Ccode_onept(1, 0, -1)
    print(infrastructure, access)
# Out:
# BHaH in_gfs[IDX4(QGF, i0+1, i1, i2-1)]
# ETLegacy qGF[CCTK_GFINDEX3D(cctkGH, i0+1, i1, i2-1)]
# CarpetX qGF(p.I + 1*p.DI[0] - 1*p.DI[2])

# %% [markdown]
# ## Valid base names
#
# Scalar base names must not end in a digit. That rule keeps component suffixes unambiguous for tensor gridfunctions and finite-difference derivatives.

# %%
reset_grid()
try:
    grid.register_gridfunctions("bad1")
except ValueError as err:
    print(str(err).splitlines()[0])

good = grid.register_gridfunctions("bad_one")[0]
print("valid replacement:", good)
# Out:
# Tried to register gridfunction with base name: bad1
# valid replacement: bad_one

# %% [markdown]
# ## Where This Leads
#
# - [Indexed Expressions](indexedexp.ipynb) reviews the prerequisite step.
# - [C Code Generation](c_codegen.ipynb) continues the tutorial path.
# - [Finite Differences](finite_difference.ipynb) connects this topic to a natural application.
# - [BHaH Project Anatomy](../5-infrastructures/bhah_project_anatomy.ipynb) connects this topic to a natural application.
