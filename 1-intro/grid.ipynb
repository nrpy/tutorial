# %% [markdown]
# # Gridfunctions and Grid Metadata
#
# `nrpy.grid` registers symbolic gridfunctions and records the metadata needed to generate infrastructure-specific C access strings. This notebook demonstrates scalar, vector, tensor, and higher-rank registration; groups; parity metadata; valid base names; BHaH defines; and generated access strings for BHaH, ETLegacy, and CarpetX.

# %%
import nrpy.grid as grid
import nrpy.params as par


def reset_grid(infrastructure="BHaH"):
    """Reset tutorial state so cells are repeatable in any kernel."""
    grid.glb_gridfcs_dict.clear()
    par.set_parval_from_str("Infrastructure", infrastructure)


reset_grid()
print("Infrastructure:", par.parval_from_str("Infrastructure"))

# %% [markdown]
# ## Scalar Registration and Valid Names
#
# `register_gridfunctions` returns SymPy symbols and stores one `GridFunction` object per component in `grid.glb_gridfcs_dict`. Current NRPy gridfunction base names must not end in a digit; a scalar such as `u2` is rejected because digit suffixes encode tensor components in registered vectors and tensors.

# %%
reset_grid()

u = grid.register_gridfunctions("u")[0]
rho, pressure = grid.register_gridfunctions(["rho", "pressure"], group="AUX")
metadata = grid.glb_gridfcs_dict["u"]

assert str(u) == "u"
assert metadata.name == "u"
assert metadata.group == "EVOL"
assert sorted(grid.glb_gridfcs_dict) == ["pressure", "rho", "u"]

try:
    grid.register_gridfunctions("u2")
except ValueError as err:
    invalid_name_message = str(err).splitlines()[0]
else:
    raise AssertionError("A scalar gridfunction base name ending in a digit should fail.")

print("Registered symbols:", u, rho, pressure)
print("Metadata for u:", metadata.__dict__)
print("Invalid-name check:", invalid_name_message)

# %% [markdown]
# ## Vector, Tensor, and Higher-Rank Registration
#
# Rank-aware helpers create indexed SymPy objects and register each unique component:
#
# - `register_gridfunctions_for_single_rank1("betU")` creates `betU0`, `betU1`, and `betU2`.
# - `register_gridfunctions_for_single_rank2("gDD", symmetry="sym01")` creates the six unique components of a symmetric 3D tensor.
# - `register_gridfunctions_for_single_rankN` generalizes the pattern to rank `N`.

# %%
reset_grid()

u = grid.register_gridfunctions("u")[0]
betU = grid.register_gridfunctions_for_single_rank1("betU")
gDD = grid.register_gridfunctions_for_single_rank2("gDD", symmetry="sym01")
RDDD = grid.register_gridfunctions_for_single_rankN("R", rank=3, symmetry="sym01")

assert len(betU) == 3
assert [str(component) for component in betU] == ["betU0", "betU1", "betU2"]
assert gDD[0][1] == gDD[1][0]
assert RDDD[0][1][2] == RDDD[1][0][2]
assert "gDD01" in grid.glb_gridfcs_dict
assert "R012" in grid.glb_gridfcs_dict

print("Vector components:", betU)
print("Symmetric tensor first row:", gDD[0])
print("Example rank-3 mirrored pair:", RDDD[0][1][2], RDDD[1][0][2])

# %% [markdown]
# ## Groups and Parity Metadata
#
# `GridFunction.gridfunction_lists()` returns registered names sorted into the `EVOL`, `AUXEVOL`, `DIAG`, and `AUX` groups. `GridFunction.set_parity_types()` computes BHaH parity codes from registered names, ranks, and dimensions.

# %%
reset_grid()

u = grid.register_gridfunctions("u")[0]
chi = grid.register_gridfunctions("chi", group="AUXEVOL")[0]
diagnostic = grid.register_gridfunctions("diagnostic", group="DIAG")[0]
aux = grid.register_gridfunctions("aux", group="AUX")[0]
betU = grid.register_gridfunctions_for_single_rank1("betU")
gDD = grid.register_gridfunctions_for_single_rank2("gDD", symmetry="sym01")

evol, auxevol, diag, aux_group = grid.GridFunction.gridfunction_lists()
parity = grid.GridFunction.set_parity_types(["u", "betU0", "gDD01"])

assert "u" in evol and "betU0" in evol and "gDD01" in evol
assert auxevol == ["chi"]
assert diag == ["diagnostic"]
assert aux_group == ["aux"]
assert parity == [0, 1, 5]

print("EVOL:", evol)
print("AUXEVOL:", auxevol)
print("DIAG:", diag)
print("AUX:", aux_group)
print("Parity for u, betU0, gDD01:", parity)

# %% [markdown]
# ## Infrastructure-Specific Access Strings
#
# The registered object type depends on `Infrastructure`. The examples below generate C access strings only; they do not require external infrastructure builds.

# %%
access_examples = {}
for infrastructure, expected_text in [
    ("BHaH", "IDX4"),
    ("ETLegacy", "CCTK_GFINDEX3D"),
    ("CarpetX", "p.I"),
]:
    reset_grid(infrastructure)
    q = grid.register_gridfunctions("q")[0]
    gf = grid.glb_gridfcs_dict[str(q)]
    access = gf.read_gf_from_memory_Ccode_onept(1, 0, -1)
    access_examples[infrastructure] = access
    assert expected_text in access

for infrastructure, access in access_examples.items():
    print(f"{infrastructure}: {access}")

# %% [markdown]
# ## BHaH Gridfunction Defines
#
# BHaH registration can generate C preprocessor definitions for gridfunction indices, asymptotic values, characteristic speeds, and grouped arrays. These strings are generated from the current registry.

# %%
reset_grid("BHaH")

u = grid.register_gridfunctions("u", f_infinity=0.0, wavespeed=1.0)[0]
v = grid.register_gridfunctions("v", f_infinity=1.0, wavespeed=2.0)[0]
aux = grid.register_gridfunctions("aux", group="AUX")[0]
defines = grid.BHaHGridFunction.gridfunction_defines()

assert "NUM_EVOL_GFS" in defines
assert "UGF" in defines
assert "VGF" in defines
assert "AUXGF" in defines
assert "gridfunctions_wavespeed" in defines

print(defines)

# %% [markdown]
# ## Summary Checks
#
# The grid registry links symbolic components to metadata used by generated code. The key stateful rule is that tutorial examples should reset `grid.glb_gridfcs_dict` before registering names, so cells remain repeatable in a reused Python kernel.

# %%
reset_grid("BHaH")
u = grid.register_gridfunctions("u")[0]
betU = grid.register_gridfunctions_for_single_rank1("betU")
gDD = grid.register_gridfunctions_for_single_rank2("gDD", symmetry="sym01")

assert str(u) in grid.glb_gridfcs_dict
assert all(str(component) in grid.glb_gridfcs_dict for component in betU)
assert gDD[0][1] == gDD[1][0]
assert grid.glb_gridfcs_dict["u"].read_gf_from_memory_Ccode_onept(1, 0, -1).startswith("in_gfs[IDX4")

print("Registered names:", sorted(grid.glb_gridfcs_dict))
