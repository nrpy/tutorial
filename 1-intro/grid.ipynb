# %% [markdown]
# # Gridfunctions and Grid Metadata
#
# Register sampled wave fields and right-hand-side storage so generated C update routines know how to access memory.
#
# Navigation: [Index](../index.ipynb) | Previous: [Indexed Expressions](indexedexp.ipynb) | Next: [C Code Generation](c_codegen.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Name fields that live on a numerical grid.
# - Separate fields that evolve from fields used for right-hand sides or diagnostics.
# - Preview how a symbolic field name becomes a C memory access.
#
# ## Words for This Notebook
#
# - **Gridfunction:** NRPy's name for a field stored at every grid point.
# - **Evolved field:** a grid field whose value changes in time.
# - **Right-hand side:** the formula for the time change of an evolved field.
# - **Diagnostic:** a field or number used to measure what the simulation is doing.
# - **Code-writing path:** the choice that tells NRPy what style of C project to write.
#
# Use the code cells actively: first predict what should happen, then run the cell, then explain the output in plain language. This predict-run-explain pattern keeps the physics idea connected to the programming details.

# %% [markdown]
# ## Grid Metadata Interfaces Used Here
#
# - `nrpy.grid` registers gridfunctions and reports their groups and memory-access expressions.
# - `nrpy.params` selects the generated-code path used for the memory-access example.

# %% [markdown]
# ## Register Wave Fields
# The scalar wave equation uses `uu` for the field, `vv` for its time derivative, and matching right-hand-side fields for time updates.

# %% [markdown]
# ## Import Grid and Codegen Registries
#
# These imports expose the NRPy registries and infrastructure writers used below.

# %%
import nrpy.grid as grid
import nrpy.params as par

# %% [markdown]
# ## Clear Tutorial Gridfunction Entries
#
# The reset removes only tutorial-owned gridfunctions before the notebook registers them again.

# %%
for name in ["uu", "vv", "uu_rhs", "vv_rhs", "energy"]:
    grid.glb_gridfcs_dict.pop(name, None)
par.set_parval_from_str("Infrastructure", "BHaH")

# %% [markdown]
# ## Register Evolved and Right-Hand-Side Wave Fields
#
# The registry records named grid fields and their roles in generated code.

# %%
uu, vv = grid.register_gridfunctions(
    ["uu", "vv"], group="EVOL", f_infinity=[2.0, 0.0], wavespeed=[1.0, 1.0]
)
uu_rhs, vv_rhs = grid.register_gridfunctions(["uu_rhs", "vv_rhs"], group="AUXEVOL")
energy = grid.register_gridfunctions("energy", group="AUX")[0]

# %% [markdown]
# ## Inspect Gridfunction Records
#
# The registry stores the evolved, auxiliary, and diagnostic fields by name.

# %%
print("evolved fields:", uu, vv)
print("right-hand-side storage:", uu_rhs, vv_rhs)
print("diagnostic field:", energy)
print("registered names:", sorted(grid.glb_gridfcs_dict))
# Out:
# evolved fields: uu vv
# right-hand-side storage: uu_rhs vv_rhs
# diagnostic field: energy
# registered names: ['energy', 'uu', 'uu_rhs', 'vv', 'vv_rhs']

# %% [markdown]
# ## Group Registered Fields by Role
#
# The grouped lists separate evolved fields, right-hand-side storage, diagnostics, and auxiliary quantities.

# %%
evol, auxevol, diag, aux = grid.GridFunction.gridfunction_lists()
print("EVOL:", evol)
print("AUXEVOL:", auxevol)
print("DIAG:", diag)
print("AUX:", aux)
# Out:
# EVOL: ['uu', 'vv']
# AUXEVOL: ['uu_rhs', 'vv_rhs']
# DIAG: []
# AUX: ['energy']

# %% [markdown]
# ## Read Boundary Metadata
#
# Each record stores the group, tensor rank, dimension, and gridfunction type used by code generation.

# %%
for name in ["uu", "vv", "uu_rhs", "vv_rhs", "energy"]:
    item = grid.glb_gridfcs_dict[name]
    print(name, item.group, item.rank, item.dimension, item.gf_type)
# Out:
# uu EVOL 0 3 REAL
# vv EVOL 0 3 REAL
# uu_rhs AUXEVOL 0 3 REAL
# vv_rhs AUXEVOL 0 3 REAL
# energy AUX 0 3 REAL

# %% [markdown]
# ## Preview Parity and Memory Access
#
# The output connects gridfunction metadata to boundary parity and generated C memory reads.

# %%
print(
    "parity types:",
    dict(zip(["uu", "vv"], grid.GridFunction.set_parity_types(["uu", "vv"]))),
)
print(
    "one memory read:",
    grid.glb_gridfcs_dict["uu"].read_gf_from_memory_Ccode_onept(1, 0, -1),
)
# Out:
# parity types: {'uu': 0, 'vv': 0}
# one memory read: in_gfs[IDX4(UUGF, i0+1, i1, i2-1)]

# %% [markdown]
# The registry output identifies which fields evolve, which store right-hand sides, and which are diagnostics. The memory-access string is the bridge from a symbolic gridfunction name to generated C array indexing.

# %% [markdown]
# ## Learning Check
#
# Before grouping the fields, decide which fields are physical wave variables and which are bookkeeping fields. After running, compare your grouping to NRPy's grouping.

# %% [markdown]
# ## Continue to C Code Generation
# - [Finite Differences](finite_difference.ipynb)
# - [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb)
