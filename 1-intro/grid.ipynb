# %% [markdown]
# # Grid Fields and Grid Metadata
#
# Register sampled wave fields and right-hand-side storage so generated C
# update routines know how to access memory.
#
# Navigation: [Index](../index.ipynb) |
# Previous: [Indexed Expressions](indexedexp.ipynb) |
# Next: [C Code Generation](c_codegen.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Name fields that live on a numerical grid.
# - Separate evolved fields from right-hand-side storage and diagnostics.
# - Preview how a symbolic field name becomes a C memory access.
#
# ## Problem Statement
#
# A Method-of-Lines wave solve keeps a state vector, computes right-hand sides for
# that state, and records diagnostics. NRPy2 grid metadata tells generated code
# which names are evolved fields, which names store update terms, and which names
# are auxiliary quantities.
#
# ## Words for This Notebook
#
# - **Grid field:** a quantity stored at every grid point.
# - **Evolved field:** a grid field whose value changes in time.
# - **Right-hand side:** the formula for the time change of an evolved field.
# - **Diagnostic:** a field or number used to measure what the simulation is doing.
# - **Code-writing path:** the choice that tells NRPy2 what style of C project to
#   write.

# %% [markdown]
# ## Step 1: Compare Field Roles in a Wave Update
#
# The scalar wave equation uses `uu` for the field, `vv` for its time derivative,
# and matching right-hand-side fields for time updates.

# %% [markdown]
# ## Setup: Import Grid Metadata Tools
#
# The grid module registers fields, and the parameter module selects the generated
# C code-writing path used for the memory-access example.

# %%
import nrpy.grid as grid
import nrpy.params as par

# %% [markdown]
# ## Setup: Clear Tutorial Grid Fields
#
# The reset removes only tutorial-owned grid fields before the notebook registers
# them again.

# %%
removed_grid_fields = []
for name in ["uu", "vv", "uu_rhs", "vv_rhs", "energy"]:
    if grid.glb_gridfcs_dict.pop(name, None) is not None:
        removed_grid_fields.append(name)
par.set_parval_from_str("Infrastructure", "BHaH")

print("cleared grid fields:", removed_grid_fields)
print("infrastructure:", par.parval_from_str("Infrastructure"))
# Out:
# cleared grid fields: []
# infrastructure: BHaH

# %% [markdown]
# ## Step 2: Register Evolved and Right-Hand-Side Wave Fields
#
# The printed names show the symbols that later formulas can use.

# %%
uu, vv = grid.register_gridfunctions(
    ["uu", "vv"],
    group="EVOL",
    f_infinity=[2.0, 0.0],
    wavespeed=[1.0, 1.0],
)
uu_rhs, vv_rhs = grid.register_gridfunctions(
    ["uu_rhs", "vv_rhs"],
    group="AUXEVOL",
)
energy = grid.register_gridfunctions("energy", group="AUX")[0]

print("evolved fields:", uu, vv)
print("right-hand-side storage:", uu_rhs, vv_rhs)
print("diagnostic field:", energy)
print("registered names:", sorted(grid.glb_gridfcs_dict))
# Out:
# evolved fields: uu vv
# right-hand-side storage: uu_rhs vv_rhs
# diagnostic field: energy
# registered names: ['energy', 'uu', 'uu_rhs', 'vv', 'vv_rhs']

# %% [markdown]
# ## Step 3: Inspect Groups and Boundary Metadata
#
# Group lists answer which fields evolve, which store right-hand sides, and which
# are auxiliary diagnostics.

# %%
evol, auxevol, diag, aux = grid.GridFunction.gridfunction_lists()
print("EVOL:", evol)
print("AUXEVOL:", auxevol)
print("DIAG:", diag)
print("AUX:", aux)

for name in ["uu", "vv", "uu_rhs", "vv_rhs", "energy"]:
    item = grid.glb_gridfcs_dict[name]
    print(name, item.group, item.rank, item.dimension, item.gf_type)
# Out:
# EVOL: ['uu', 'vv']
# AUXEVOL: ['uu_rhs', 'vv_rhs']
# DIAG: []
# AUX: ['energy']
# uu EVOL 0 3 REAL
# vv EVOL 0 3 REAL
# uu_rhs AUXEVOL 0 3 REAL
# vv_rhs AUXEVOL 0 3 REAL
# energy AUX 0 3 REAL

# %% [markdown]
# ## Step 4: Preview Parity and Memory Access
#
# The memory-access string is the bridge from a symbolic grid field name to
# generated C array indexing.

# %%
parity_types = grid.GridFunction.set_parity_types(["uu", "vv"])
memory_read = grid.glb_gridfcs_dict["uu"].read_gf_from_memory_Ccode_onept(
    1,
    0,
    -1,
)
print("parity types:", dict(zip(["uu", "vv"], parity_types)))
print("one memory read:", memory_read)
# Out:
# parity types: {'uu': 0, 'vv': 0}
# one memory read: in_gfs[IDX4(UUGF, i0+1, i1, i2-1)]

# %% [markdown]
# ## Validation Check
#
# The registered groups, parity types, and C memory read should match the
# table and the requested point offset.

# %%
expected_groups = {
    "uu": "EVOL",
    "vv": "EVOL",
    "uu_rhs": "AUXEVOL",
    "vv_rhs": "AUXEVOL",
    "energy": "AUX",
}
actual_groups = {
    name: grid.glb_gridfcs_dict[name].group
    for name in expected_groups
}
if actual_groups != expected_groups:
    raise RuntimeError(f"Unexpected grid field groups: {actual_groups}")
if parity_types != [0, 0]:
    raise RuntimeError(f"Unexpected parity types: {parity_types}")
for expected_piece in ["IDX4(UUGF", "i0+1", "i2-1"]:
    if expected_piece not in memory_read:
        raise RuntimeError(f"Missing {expected_piece} in {memory_read}")

print("validated groups:", actual_groups)
print("validated parity types:", parity_types)
print("validated memory read:", memory_read)
# Out:
# validated groups: {'uu': 'EVOL', 'vv': 'EVOL', 'uu_rhs': 'AUXEVOL', 'vv_rhs': 'AUXEVOL', 'energy': 'AUX'}
# validated parity types: [0, 0]
# validated memory read: in_gfs[IDX4(UUGF, i0+1, i1, i2-1)]

# %% [markdown]
# ## Learning Check
#
# After grouping the fields, identify which names represent physical wave
# variables and which names store update or diagnostic data.

# %% [markdown]
# ## Continue to C Code Generation
#
# - [C Code Generation](c_codegen.ipynb)
# - [Finite Differences](finite_difference.ipynb)
# - [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb)
