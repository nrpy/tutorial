# %% [markdown]
# # Grid Fields and Grid Metadata
#
# ## Author: Zach Etienne
#
# To run the whole notebook, click the `>>` toolbar button and choose
# **Restart Kernel and Run All Cells...**.
#
# This notebook shows how NRPy registers gridfunctions, groups them by role,
# and maps symbolic field names to BHaH-style C memory reads.
#
# ### Required Reading
#
# - [Indexed Expressions](indexedexp.ipynb), for NRPy naming and list
#   conventions.
#
# ### NRPy Source Code
#
# - [nrpy/nrpy/grid.py](../nrpy/nrpy/grid.py): registers gridfunctions,
#   groups, parity, and memory-access metadata.
#
# # Table of Contents
#
# 1. [Words for This Notebook](#Words-for-This-Notebook)
# 1. [Step 1](#Step-1:-Compare-field-roles-in-a-wave-update): Compare roles.
# 1. [Step 2](#Step-2:-Initialize-grid-metadata-tools): Initialize tools.
# 1. [Step 3](#Step-3:-Reset-tutorial-owned-grid-fields): Reset fields.
# 1. [Step 4](#Step-4:-Register-cataloged-wave-fields): Register fields.
# 1. [Step 5](#Step-5:-Inspect-groups-and-boundary-metadata): Inspect groups.
# 1. [Step 6](#Step-6:-Preview-parity-and-BHaH-memory-access): Preview memory.
# 1. [Validation Check](#Validation-Check): Validate registry state.
# 1. [Learning Check](#Learning-Check): Check understanding.
# 1. [What next?](#What-next?)

# %% [markdown]
# # Words for This Notebook
# ### [Back to [top](#Table-of-Contents)]
#
# - **Gridfunction:** a quantity stored at every grid point.
# - **Group:** a role label such as evolved field, RHS storage, or auxiliary
#   diagnostic.
# - **Rank:** the number of tensor indices on the stored field; these examples
#   are scalar rank-0 fields.
# - **Dimension:** the spatial index range used by tensor gridfunctions; these
#   scalar examples live on a 3D grid.
# - **Evolved field:** a gridfunction advanced in time.
# - **RHS storage:** a gridfunction that stores a time-update formula.
# - **Diagnostic field:** a gridfunction used to measure simulation behavior.
# - **Parity type:** metadata used by curvilinear parity and boundary logic.
# - **`f_infinity`:** asymptotic field value used by boundary metadata.
# - **`wavespeed`:** characteristic speed used by boundary metadata.
# - **Memory-access string:** generated C indexing for reading a gridfunction.
#
# The first code object is the grid registry. Its infrastructure role is to
# remember which symbolic names correspond to grid arrays, and the first
# output confirms the tutorial-owned entries were cleared.

# %% [markdown]
# # Step 1: Compare field roles in a wave update
# ### [Back to [top](#Table-of-Contents)]
#
# A Method-of-Lines wave update keeps evolved fields, RHS storage, and
# diagnostics separate.
#
# | Name | Purpose | Group | Rank | Dimension | Inspect |
# | --- | --- | --- | --- | --- | --- |
# | `uu` | wave amplitude | `EVOL` | 0 | 3 | boundary metadata |
# | `vv` | time derivative | `EVOL` | 0 | 3 | parity metadata |
# | `uu_rhs` | RHS for `uu` | `AUXEVOL` | 0 | 3 | group list |
# | `vv_rhs` | RHS for `vv` | `AUXEVOL` | 0 | 3 | group list |
# | `energy` | diagnostic | `AUX` | 0 | 3 | auxiliary group |

# %% [markdown]
# # Step 2: Initialize grid metadata tools
# ### [Back to [top](#Table-of-Contents)]
#
# The grid module registers fields, and the parameter module selects the BHaH
# code-writing path used for the memory-access example.

# %%
import nrpy.grid as gri
import nrpy.params as par

# %% [markdown]
# # Step 3: Reset tutorial-owned grid fields
# ### [Back to [top](#Table-of-Contents)]
#
# The reset removes only tutorial-owned grid fields before the notebook
# registers them again.

# %%
removed_grid_fields = []
for name in ["uu", "vv", "uu_rhs", "vv_rhs", "energy"]:
    if gri.glb_gridfcs_dict.pop(name, None) is not None:
        removed_grid_fields.append(name)
par.set_parval_from_str("Infrastructure", "BHaH")

print("cleared grid fields:", removed_grid_fields)
print("infrastructure:", par.parval_from_str("Infrastructure"))
# Out:
# cleared grid fields: []
# infrastructure: BHaH

# %% [markdown]
# # Step 4: Register cataloged wave fields
# ### [Back to [top](#Table-of-Contents)]
#
# The printed names show the symbols that later formulas can use.
# `f_infinity` and `wavespeed` are defined before registration because they
# become boundary metadata for the evolved fields.

# %%
wave_f_infinity = [2.0, 0.0]
wave_speeds = [1.0, 1.0]

uu, vv = gri.register_gridfunctions(
    ["uu", "vv"],
    group="EVOL",
    f_infinity=wave_f_infinity,
    wavespeed=wave_speeds,
)
uu_rhs, vv_rhs = gri.register_gridfunctions(
    ["uu_rhs", "vv_rhs"],
    group="AUXEVOL",
)
energy = gri.register_gridfunctions("energy", group="AUX")[0]

print("evolved fields:", uu, vv)
print("right-hand-side storage:", uu_rhs, vv_rhs)
print("diagnostic field:", energy)
print("f_infinity:", dict(zip(["uu", "vv"], wave_f_infinity)))
print("wavespeed:", dict(zip(["uu", "vv"], wave_speeds)))
print("registered names:", sorted(gri.glb_gridfcs_dict))
# Out:
# evolved fields: uu vv
# right-hand-side storage: uu_rhs vv_rhs
# diagnostic field: energy
# f_infinity: {'uu': 2.0, 'vv': 0.0}
# wavespeed: {'uu': 1.0, 'vv': 1.0}
# registered names: ['energy', 'uu', 'uu_rhs', 'vv', 'vv_rhs']

# %% [markdown]
# # Step 5: Inspect groups and boundary metadata
# ### [Back to [top](#Table-of-Contents)]
#
# Group lists answer which fields evolve, which store right-hand sides, and
# which are auxiliary diagnostics.

# %%
evol, auxevol, diag, aux = gri.GridFunction.gridfunction_lists()
print("EVOL:", evol)
print("AUXEVOL:", auxevol)
print("DIAG:", diag)
print("AUX:", aux)

for name in ["uu", "vv", "uu_rhs", "vv_rhs", "energy"]:
    item = gri.glb_gridfcs_dict[name]
    print(name, item.group, item.rank, item.dimension, item.gf_type)
# Out:
# EVOL: ['uu', 'vv']
# AUXEVOL: ['uu_rhs', 'vv_rhs']
# DIAG: []
# AUX: ['energy']
# uu EVOL 0 3 REAL
# vv EVOL 0 3 REAL
# uu_rhs AUXEVOL 0 3 REAL
# vv_rhs AUXEVOL 0 3 REAL
# energy AUX 0 3 REAL

# %% [markdown]
# # Step 6: Preview parity and BHaH memory access
# ### [Back to [top](#Table-of-Contents)]
#
# The memory-access string is the bridge from a symbolic gridfunction name to
# generated C array indexing. The call requests `uu` at offsets `i0+1`, `i1`,
# and `i2-1`, so those offsets should appear in the printed BHaH string.

# %%
parity_types = gri.GridFunction.set_parity_types(["uu", "vv"])
memory_read = gri.glb_gridfcs_dict["uu"].read_gf_from_memory_Ccode_onept(
    1,
    0,
    -1,
)
print("parity types:", dict(zip(["uu", "vv"], parity_types)))
print("one memory read:", memory_read)
# Out:
# parity types: {'uu': 0, 'vv': 0}
# one memory read: in_gfs[IDX4(UUGF, i0+1, i1, i2-1)]

# %% [markdown]
# # Validation Check
# ### [Back to [top](#Table-of-Contents)]
#
# The trusted result is the cataloged group and offset request. The newly
# computed result is NRPy's grid registry state and generated memory-read
# string. Passing means groups, parity types, and offsets match the catalog.

# %%
expected_groups = {
    "uu": "EVOL",
    "vv": "EVOL",
    "uu_rhs": "AUXEVOL",
    "vv_rhs": "AUXEVOL",
    "energy": "AUX",
}
actual_groups = {
    name: gri.glb_gridfcs_dict[name].group
    for name in expected_groups
}
if actual_groups != expected_groups:
    raise RuntimeError(f"Unexpected grid field groups: {actual_groups}")
if parity_types != [0, 0]:
    raise RuntimeError(f"Unexpected parity types: {parity_types}")
for expected_piece in ["IDX4(UUGF", "i0+1", "i2-1"]:
    if expected_piece not in memory_read:
        raise RuntimeError(f"Missing {expected_piece} in {memory_read}")

print("trusted result: requested gridfunction catalog")
print("newly computed result: NRPy grid registry and BHaH memory read")
print("validated groups:", actual_groups)
print("validated parity types:", parity_types)
print("validated memory read:", memory_read)
# Out:
# trusted result: requested gridfunction catalog
# newly computed result: NRPy grid registry and BHaH memory read
# validated groups: {'uu': 'EVOL', 'vv': 'EVOL', 'uu_rhs': 'AUXEVOL', 'vv_rhs': 'AUXEVOL', 'energy': 'AUX'}
# validated parity types: [0, 0]
# validated memory read: in_gfs[IDX4(UUGF, i0+1, i1, i2-1)]

# %% [markdown]
# # Learning Check
# ### [Back to [top](#Table-of-Contents)]
#
# After grouping the fields, identify which names represent physical wave
# variables and which names store update or diagnostic data.

# %% [markdown]
# # What next?
#
# - [C Code Generation](c_codegen.ipynb)
# - [Finite Differences](finite_difference.ipynb)
# - [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb)
