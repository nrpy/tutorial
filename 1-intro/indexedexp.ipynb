# %% [markdown]
# # Indexed Expressions
#
# Represent vectors, symmetric tensors, and metric-like matrices without hand-writing every repeated component.
#
# Navigation: [Index](../index.ipynb) | Previous: [Parameters](params.ipynb) | Next: [Gridfunctions](grid.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Represent vectors, matrices, and higher-rank objects as indexed lists.
# - Use symmetry to avoid writing duplicate components.
# - Check inverse-matrix identities with residuals.
#
# ## Words for This Notebook
#
# - **Component:** one entry of a vector or tensor, such as the x-component of a vector.
# - **Rank:** the number of indices an object has: a vector has rank 1, a matrix has rank 2.
# - **Symmetry:** a rule that two components are equal or related.
# - **Residual:** what is left after subtracting the expected answer; zero means the check passed.
#
# Use the code cells actively: first predict what should happen, then run the cell, then explain the output in plain language. This predict-run-explain pattern keeps the physics idea connected to the programming details.

# %% [markdown]
# ## Indexed Expression Interfaces Used Here
#
# - `nrpy.indexedexp` creates vectors and tensors with declared rank and symmetry.
# - `nrpy.params` sets indexed-expression options used by the symbolic helpers.

# %% [markdown]
# ## Vectors, Symmetric Tensors, and Inverses
# A rank is the number of indices on an object. Symmetry tells NRPy which components are repeated or related.

# %% [markdown]
# ## Import SymPy for Tensor Checks
#
# These imports expose the NRPy and Python tools used in the next steps.

# %%
import sympy as sp

# %% [markdown]
# ## Import Indexed Expression Helpers
#
# These imports expose the NRPy registries and infrastructure writers used below.

# %%
import nrpy.indexedexp as ixp
import nrpy.params as par

# %% [markdown]
# ## Reset Symmetry-Axis Assumptions
#
# This clears optional symmetry-axis settings before declaring new symbolic arrays.

# %%
par.set_parval_from_str("indexedexp::symmetry_axes", "")

# %% [markdown]
# ## Declare Ranked Symbolic Arrays
#
# The constructors create indexed component lists and apply the requested symmetry rules.

# %%
vector = ixp.declarerank1("vU")
metric = ixp.declarerank2("gDD", symmetry="sym01")
connection = ixp.declarerank3("GammaUDD", symmetry="sym12")
antisymmetric = ixp.declare_indexedexp("A", rank=2, dimension=3, symmetry="anti01")

# %% [markdown]
# ## Verify Declared Symmetries
#
# The printed components show which entries are independent and which are related by symmetry.

# %%
print("vector:", vector)
print("symmetric metric row 0:", metric[0])
print("Gamma symmetry check:", connection[0][1][2], connection[0][2][1])
print("A01 + A10:", sp.simplify(antisymmetric[0][1] + antisymmetric[1][0]))
print("antisymmetric diagonal:", [antisymmetric[i][i] for i in range(3)])
# Out:
# vector: [vU0, vU1, vU2]
# symmetric metric row 0: [gDD00, gDD01, gDD02]
# Gamma symmetry check: GammaUDD012 GammaUDD012
# A01 + A10: 0
# antisymmetric diagonal: [0, 0, 0]

# %% [markdown]
# ## Verify the 2 by 2 Matrix Inverse
#
# A zero residual confirms that the symbolic expression matches the expected identity.

# %%
p, q, r = sp.symbols("p q r", nonzero=True)
matrix2 = [[p, q], [q, r]]
inverse2, determinant2 = ixp.symm_matrix_inverter2x2(matrix2)
residual2 = [
    [
        sp.simplify(
            sum(inverse2[i][k] * matrix2[k][j] for k in range(2)) - (1 if i == j else 0)
        )
        for j in range(2)
    ]
    for i in range(2)
]

# %% [markdown]
# ## Verify the 3 by 3 Matrix Inverse
#
# A zero residual confirms that the symbolic expression matches the expected identity.

# %%
a, b, c = sp.symbols("a b c", nonzero=True)
matrix3 = [[a, 0, 0], [0, b, 0], [0, 0, c]]
inverse3, determinant3 = ixp.symm_matrix_inverter3x3(matrix3)
residual3 = [
    [
        sp.simplify(
            sum(inverse3[i][k] * matrix3[k][j] for k in range(3)) - (1 if i == j else 0)
        )
        for j in range(3)
    ]
    for i in range(3)
]

# %% [markdown]
# ## Summarize Determinants and Inverses
#
# A zero residual confirms that the symbolic expression matches the expected identity.

# %%
print("2 by 2 determinant:", determinant2)
print("2 by 2 residual:", residual2)
print("3 by 3 determinant:", determinant3)
print("3 by 3 inverse diagonal:", [inverse3[i][i] for i in range(3)])
print("3 by 3 residual:", residual3)
# Out:
# 2 by 2 determinant: p*r - q**2
# 2 by 2 residual: [[0, 0], [0, 0]]
# 3 by 3 determinant: a*b*c
# 3 by 3 inverse diagonal: [1/a, 1/b, 1/c]
# 3 by 3 residual: [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# The tensor output shows how symmetry reduces storage while preserving component meaning. Those indexed objects become the metric-like arrays used by coordinate transforms and ADM/BSSN variables.

# %% [markdown]
# ## Learning Check
#
# Before running the symmetry check, predict whether `gDD[0][1]` and `gDD[1][0]` should be the same object. Explain why symmetry matters for large tensor formulas.

# %% [markdown]
# ## Continue to Gridfunctions
# - [Gridfunctions and Grid Metadata](grid.ipynb)
# - [Basis Transforms](../4-curvilinear/basis_transforms.ipynb)
# - [ADM and BSSN Conversions](../6-numerical_relativity/adm_bssn_conversions.ipynb)
