# %% [markdown]
# # Indexed Expressions
#
# ## Author: Zach Etienne
#
# To run the whole notebook, click the `>>` toolbar button and choose
# **Restart Kernel and Run All Cells...**.
#
# This notebook shows how NRPy represents vectors, symmetric tensors, and
# matrix-like objects as indexed Python lists, then validates symmetry and
# inverse-matrix identities with symbolic residuals.
#
# ### Required Reading
#
# - [Parameters](params.ipynb), for ordered tutorial continuity.
#
# ### NRPy Source Code
#
# - [nrpy/nrpy/indexedexp.py](../nrpy/nrpy/indexedexp.py): declares indexed
#   symbolic arrays, symmetries, and matrix-inversion helpers.
#
# # Table of Contents
#
# 1. [Words for This Notebook](#Words-for-This-Notebook)
# 1. [Step 1](#Step-1:-Review-index-notation-and-symmetry): Review notation.
# 1. [Step 2](#Step-2:-Initialize-symbolic-and-indexed-expression-tools):
#    Initialize tools.
# 1. [Step 3](#Step-3:-Reset-tutorial-owned-symmetry-axis-assumptions): Reset.
# 1. [Step 4](#Step-4:-Declare-ranked-symbolic-arrays): Declare arrays.
# 1. [Step 5](#Step-5:-Verify-declared-symmetries): Verify symmetries.
# 1. [Step 6](#Step-6:-Verify-matrix-inverse-identities): Verify inverses.
# 1. [Learning Check](#Learning-Check): Check understanding.
# 1. [What next?](#What-next?)

# %% [markdown]
# # Words for This Notebook
# ### [Back to [top](#Table-of-Contents)]
#
# - **Index position:** whether an index is written upstairs or downstairs in
#   tensor notation.
# - **`U`:** NRPy's name marker for an up, or contravariant, index.
# - **`D`:** NRPy's name marker for a down, or covariant, index.
# - **Rank:** the number of indices an object has.
# - **Dimension:** the number of values each index can take; these examples
#   use three spatial dimensions.
# - **Symmetry:** a rule that components are equal, opposite, or zero.
# - **Component ordering:** the nested-list layout NRPy uses for indexed
#   components.
# - **Residual:** what remains after subtracting the expected identity; zero
#   means the symbolic check passed.
#
# The first code object created below is a vector list. Its mathematical role
# is a tensor-like object with one index, its data structure is a Python
# list, and the first output shows the component names NRPy generated.

# %% [markdown]
# # Step 1: Review index notation and symmetry
# ### [Back to [top](#Table-of-Contents)]
#
# NRPy names encode index structure. A name ending in `U`, such as `vU`,
# represents a vector `v^i`. A name ending in `DD`, such as `gDD`, represents
# a two-index object `g_{ij}`. Repeated `U` and `D` letters encode higher-rank
# index structure, so `TUDD` represents `T^i{}_{jk}`.
#
# | NRPy name | Mathematical role | Index pattern | Symmetry | Inspect |
# | --- | --- | --- | --- | --- |
# | `vU` | vector `v^i` | one upper | none | component list |
# | `gDD` | tensor `g_{ij}` | two lower | symmetric in `i,j` | off-diagonal entries |
# | `TUDD` | tensor `T^i{}_{jk}` | one upper, two lower | symmetric in `j,k` | matching lower pair |
# | `A` | tensor `A_{ij}` | two lower | antisymmetric | sign flip and zero diagonal |
#
# In 3D, `vU` has 3 components. A symmetric rank-2 tensor has 9 displayed
# positions but 6 independent components. A rank-3 tensor symmetric in the
# last two indices has 27 displayed positions but 18 independent components.
# An antisymmetric rank-2 tensor has 9 displayed positions, 3 independent
# off-diagonal components, and a zero diagonal.
#
# The inverse check later uses
#
# $$
# g^{ik} g_{kj} - \delta^i{}_j = 0.
# $$
#
# The nested loops map `i`, `k`, and `j` to Python list indices.

# %% [markdown]
# # Step 2: Initialize symbolic and indexed-expression tools
# ### [Back to [top](#Table-of-Contents)]
#
# SymPy simplifies residuals, and NRPy's indexed-expression helpers create
# component arrays with declared rank and symmetry.

# %%
import sympy as sp

# %%
import nrpy.indexedexp as ixp
import nrpy.params as par

# %% [markdown]
# # Step 3: Reset tutorial-owned symmetry-axis assumptions
# ### [Back to [top](#Table-of-Contents)]
#
# This clears optional symmetry-axis settings before declaring new symbolic
# arrays. The printed empty value confirms that no prior setting affects the
# examples.

# %%
par.set_parval_from_str("indexedexp::symmetry_axes", "")
print("symmetry axes:", par.parval_from_str("indexedexp::symmetry_axes"))
# Out:
# symmetry axes:

# %% [markdown]
# # Step 4: Declare ranked symbolic arrays
# ### [Back to [top](#Table-of-Contents)]
#
# The printed samples show the component lists and the repeated component
# names created by the requested symmetries.

# %%
vector = ixp.declarerank1("vU")
metric = ixp.declarerank2("gDD", symmetry="sym01")
rank3_tensor = ixp.declarerank3("TUDD", symmetry="sym12")
antisymmetric = ixp.declare_indexedexp(
    "A",
    rank=2,
    dimension=3,
    symmetry="anti01",
)
print("vector:", vector)
print("symmetric metric row 0:", metric[0])
print("rank-3 sample:", rank3_tensor[0][1][2], rank3_tensor[0][2][1])
print("antisymmetric sample:", antisymmetric[0][1], antisymmetric[1][0])
# Out:
# vector: [vU0, vU1, vU2]
# symmetric metric row 0: [gDD00, gDD01, gDD02]
# rank-3 sample: TUDD012 TUDD012
# antisymmetric sample: A01 -A01

# %% [markdown]
# # Step 5: Verify declared symmetries
# ### [Back to [top](#Table-of-Contents)]
#
# The trusted result is the declared symmetry pattern. The newly computed
# result is the component residual. Passing means symmetric differences and
# antisymmetric sums reduce to zero.

# %%
symmetry_residual = sp.simplify(metric[0][1] - metric[1][0])
rank3_residual = sp.simplify(rank3_tensor[0][1][2] - rank3_tensor[0][2][1])
antisymmetry_residual = sp.simplify(
    antisymmetric[0][1] + antisymmetric[1][0]
)
antisymmetric_diagonal = [antisymmetric[i][i] for i in range(3)]

if symmetry_residual != 0:
    raise RuntimeError(f"Metric symmetry failed: {symmetry_residual}")
if rank3_residual != 0:
    raise RuntimeError(f"Rank-3 symmetry failed: {rank3_residual}")
if antisymmetry_residual != 0:
    raise RuntimeError(f"Antisymmetry failed: {antisymmetry_residual}")
if antisymmetric_diagonal != [0, 0, 0]:
    raise RuntimeError(f"Unexpected diagonal: {antisymmetric_diagonal}")

print("metric symmetry residual:", symmetry_residual)
print("rank-3 symmetry residual:", rank3_residual)
print("antisymmetry residual:", antisymmetry_residual)
print("antisymmetric diagonal:", antisymmetric_diagonal)
# Out:
# metric symmetry residual: 0
# rank-3 symmetry residual: 0
# antisymmetry residual: 0
# antisymmetric diagonal: [0, 0, 0]

# %% [markdown]
# # Step 6: Verify matrix-inverse identities
# ### [Back to [top](#Table-of-Contents)]
#
# The trusted result is the identity matrix produced by multiplying an inverse
# by its matrix. The newly computed result is the full residual matrix.
# Passing means every printed residual component is zero.

# %%
p, q, r = sp.symbols("p q r", nonzero=True)
matrix2 = [[p, q], [q, r]]
inverse2, determinant2 = ixp.symm_matrix_inverter2x2(matrix2)
residual2 = [
    [
        sp.simplify(
            sum(inverse2[i][k] * matrix2[k][j] for k in range(2))
            - (1 if i == j else 0)
        )
        for j in range(2)
    ]
    for i in range(2)
]

a, b, c = sp.symbols("a b c", nonzero=True)
matrix3 = [[a, 0, 0], [0, b, 0], [0, 0, c]]
inverse3, determinant3 = ixp.symm_matrix_inverter3x3(matrix3)
residual3 = [
    [
        sp.simplify(
            sum(inverse3[i][k] * matrix3[k][j] for k in range(3))
            - (1 if i == j else 0)
        )
        for j in range(3)
    ]
    for i in range(3)
]

if residual2 != [[0, 0], [0, 0]]:
    raise RuntimeError(f"2 by 2 inverse residual failed: {residual2}")
if residual3 != [[0, 0, 0], [0, 0, 0], [0, 0, 0]]:
    raise RuntimeError(f"3 by 3 inverse residual failed: {residual3}")

print("2 by 2 determinant:", determinant2)
print("2 by 2 residual:", residual2)
print("3 by 3 determinant:", determinant3)
print("3 by 3 inverse diagonal:", [inverse3[i][i] for i in range(3)])
print("3 by 3 residual:", residual3)
# Out:
# 2 by 2 determinant: p*r - q**2
# 2 by 2 residual: [[0, 0], [0, 0]]
# 3 by 3 determinant: a*b*c
# 3 by 3 inverse diagonal: [1/a, 1/b, 1/c]
# 3 by 3 residual: [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# # Learning Check
# ### [Back to [top](#Table-of-Contents)]
#
# After running the symmetry checks, explain why removing duplicate tensor
# components matters for large symbolic formulas.

# %% [markdown]
# # What next?
#
# - [Grid Fields and Grid Metadata](grid.ipynb)
# - [Basis Transforms](../4-curvilinear/basis_transforms.ipynb)
# - [Numerical-Relativity Conversions](../6-numerical_relativity/adm_bssn_conversions.ipynb)
