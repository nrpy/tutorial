# %% [markdown]
# # Indexed Expressions
#
# `nrpy.indexedexp` builds symbolic vectors, matrices, tensors, zero-valued tensor containers, symmetry-reduced components, matrix inverses, and Levi-Civita objects. These utilities provide the symbolic tensor layer used by gridfunction registration, finite differences, and generated kernels.

# %%
import sympy as sp

import nrpy.helpers.functional as func
import nrpy.indexedexp as ixp


def flatten_rank(tensor, rank):
    """Flatten a rank-N nested list into a one-dimensional list."""
    return list(func.repeat(func.flatten, tensor, rank - 1))

# %% [markdown]
# ## Symbolic Tensor Construction
#
# `create_tensor_symbolic(shape, symbol)` creates nested lists of SymPy symbols. A scalar shape such as `3` gives a rank-1 object, while a list such as `[3, 3]` gives a rank-2 object. `declare_indexedexp` adds rank, dimension, and symmetry handling; `declarerank1` through `declarerank4` are concise wrappers for the common ranks.

# %%
vU = ixp.create_tensor_symbolic(3, "vU")
ADD = ixp.create_tensor_symbolic([2, 2], "A")
lettered = ixp.create_tensor_symbolic([2, 2], "M", character_zero_index="x")


print("Vector:", vU)
print("Matrix row:", ADD[1])
print("Letter-indexed matrix row:", lettered[0])

# %%
rank1 = ixp.declarerank1("vU", dimension=3)
rank2 = ixp.declarerank2("gDD", dimension=3, symmetry="sym01")
rank3 = ixp.declarerank3("TDDD", dimension=3, symmetry="sym01")
rank4 = ixp.declarerank4("RDDDD", dimension=3, symmetry="sym01_sym23")
direct = ixp.declare_indexedexp("hDD", rank=2, dimension=3, symmetry="sym01")


for name, tensor in [("rank1", rank1), ("rank2", rank2), ("rank3", rank3), ("rank4", rank4)]:
    print(f"{name}: detected rank {ixp.get_rank(tensor)}")

# %% [markdown]
# ## Symmetry Reduction
#
# Symmetry strings identify related indices. For example, `sym01` makes a rank-2 tensor symmetric across its first two indices, and `sym01_sym23` applies two independent symmetry blocks to a rank-4 tensor. Antisymmetric strings such as `anti01` set diagonal components to zero and mirror off-diagonal components with a sign change.

# %%
TDD = ixp.declarerank2("TDD", dimension=3, symmetry="sym01")
unique_symmetric_components = set(flatten_rank(TDD, 2))


anti = ixp.declarerank2("ADD", dimension=3, symmetry="anti01")

print("Unique symmetric 3D rank-2 components:", sorted(map(str, unique_symmetric_components)))
print("Antisymmetric off-diagonal pair:", anti[0][1], anti[1][0])

# %%
a, b, c, d, e, f, g, h, q = sp.symbols("a b c d e f g h q")

rank2_raw = [[a, b], [c, d]]
rank2_sym = ixp.symmetrize_rank2(rank2_raw, "sym01", 2)

rank3_raw = [[[sp.Symbol(f"A{i}{j}{k}") for k in range(3)] for j in range(3)] for i in range(3)]
rank3_sym = ixp.symmetrize_rank3(rank3_raw, "sym12", 3)

rank4_raw = [
    [[[sp.Symbol(f"R{i}{j}{k}{l}") for l in range(3)] for k in range(3)] for j in range(3)]
    for i in range(3)
]
rank4_sym = ixp.symmetrize_rank4(rank4_raw, "sym01_sym23", 3)

print("rank-2 symmetry:", rank2_sym)
print("rank-3 mirrored component:", rank3_sym[0][2][1])
print("rank-4 mirrored component:", rank4_sym[2][0][2][1])

# %% [markdown]
# ## Zero Tensors and Rank Detection
#
# `zerorank1` through `zerorank4` allocate nested lists filled with exact SymPy zeroes. `get_rank` reports the list nesting depth and is useful when validating helper output.

# %%
zero1 = ixp.zerorank1(dimension=3)
zero2 = ixp.zerorank2(dimension=3)
zero3 = ixp.zerorank3(dimension=2)
zero4 = ixp.zerorank4(dimension=2)


print("zero tensor ranks:", [ixp.get_rank(obj) for obj in [zero1, zero2, zero3, zero4]])

# %% [markdown]
# ## Matrix Inversion Helpers
#
# NRPy provides explicit symbolic inverses for symmetric and generic 2x2, 3x3, and 4x4 matrices. Each inverter returns `(inverse, determinant)`. The inverse can be checked by multiplying it into the original matrix and simplifying to the identity.

# %%
def inverse_summary(helper, matrix):
    inverse, determinant = helper(matrix)
    size = len(matrix)
    identity_error = sp.simplify(sp.Matrix(matrix) * sp.Matrix(inverse) - sp.eye(size))
    return determinant, identity_error


symmetric_matrices = {
    "symm_matrix_inverter2x2": (
        ixp.symm_matrix_inverter2x2,
        [[sp.Integer(2), sp.Integer(1)], [sp.Integer(1), sp.Integer(3)]],
        sp.Integer(5),
    ),
    "symm_matrix_inverter3x3": (
        ixp.symm_matrix_inverter3x3,
        [
            [sp.Integer(4), sp.Integer(1), sp.Integer(0)],
            [sp.Integer(1), sp.Integer(3), sp.Integer(1)],
            [sp.Integer(0), sp.Integer(1), sp.Integer(2)],
        ],
        sp.Integer(18),
    ),
    "symm_matrix_inverter4x4": (
        ixp.symm_matrix_inverter4x4,
        [
            [sp.Integer(5), sp.Integer(1), sp.Integer(0), sp.Integer(0)],
            [sp.Integer(1), sp.Integer(4), sp.Integer(1), sp.Integer(0)],
            [sp.Integer(0), sp.Integer(1), sp.Integer(3), sp.Integer(1)],
            [sp.Integer(0), sp.Integer(0), sp.Integer(1), sp.Integer(2)],
        ],
        sp.Integer(85),
    ),
}

generic_matrices = {
    "generic_matrix_inverter2x2": (
        ixp.generic_matrix_inverter2x2,
        [[sp.Integer(2), sp.Integer(1)], [sp.Integer(3), sp.Integer(4)]],
        sp.Integer(5),
    ),
    "generic_matrix_inverter3x3": (
        ixp.generic_matrix_inverter3x3,
        [
            [sp.Integer(2), sp.Integer(1), sp.Integer(0)],
            [sp.Integer(0), sp.Integer(3), sp.Integer(1)],
            [sp.Integer(1), sp.Integer(0), sp.Integer(2)],
        ],
        sp.Integer(13),
    ),
    "generic_matrix_inverter4x4": (
        ixp.generic_matrix_inverter4x4,
        [
            [sp.Integer(2), sp.Integer(1), sp.Integer(0), sp.Integer(0)],
            [sp.Integer(0), sp.Integer(3), sp.Integer(1), sp.Integer(0)],
            [sp.Integer(1), sp.Integer(0), sp.Integer(2), sp.Integer(1)],
            [sp.Integer(0), sp.Integer(1), sp.Integer(0), sp.Integer(2)],
        ],
        sp.Integer(28),
    ),
}

for helper_name, (helper, matrix, reference_det) in {
    **symmetric_matrices,
    **generic_matrices,
}.items():
    determinant, identity_error = inverse_summary(helper, matrix)
    print(
        f"{helper_name}: determinant = {determinant} "
        f"(reference {reference_det}); inverse residual = {identity_error}"
    )

# %% [markdown]
# ## Levi-Civita Symbol and Tensors
#
# `LeviCivitaSymbol_dim3_rank3()` returns the orientation symbol in three dimensions. The tensor helpers scale that symbol by `sqrtgammaDET`: upper-index components divide by it, and lower-index components multiply by it.

# %%
epsilon = ixp.LeviCivitaSymbol_dim3_rank3()
sqrtgammaDET = sp.Symbol("sqrtgammaDET", positive=True)
epsilonUUU = ixp.LeviCivitaTensorUUU_dim3_rank3(sqrtgammaDET)
epsilonDDD = ixp.LeviCivitaTensorDDD_dim3_rank3(sqrtgammaDET)


print("epsilon[0][1][2] =", epsilon[0][1][2])
print("epsilon[0][2][1] =", epsilon[0][2][1])
print("epsilonUUU[0][1][2] =", epsilonUUU[0][1][2])
