# %% [markdown]
# # C Function Registration
#
# `nrpy.c_function` stores generated or hand-written C functions in a common registry. Infrastructure writers can then collect prototypes, full function text, coordinate-specific wrappers, and metadata.

# %%
from nrpy.c_function import (
    CFunction,
    CFunction_dict,
    function_name_and_subdir_with_CoordSystem,
    register_CFunction,
)

CFunction_dict.clear()

# %% [markdown]
# ## A standalone `CFunction`
#
# A `CFunction` requires a name, description, and body. It builds a prototype, raw function text, and formatted full function text.

# %%
demo = CFunction(
    desc="Return one plus the input integer.",
    cfunc_type="int",
    name="add_one",
    params="const int x",
    body="return x + 1;",
)

print("prototype:")
print(demo.function_prototype)
print("raw function first lines:")
print("\n".join(demo.raw_function.splitlines()[:5]))
print("full function first lines:")
print("\n".join(demo.full_function.splitlines()[:5]))

# %% [markdown]
# ## Registry entries
#
# `register_CFunction` constructs a `CFunction` and stores it in `CFunction_dict`.

# %%
register_CFunction(
    name="square_density",
    desc="Store rho squared in the output pointer.",
    params="const double rho, double *out",
    body="*out = rho*rho;\nreturn;",
)

print("registered keys:", sorted(CFunction_dict))
print(CFunction_dict["square_density"].function_prototype)

# %% [markdown]
# ## Intentional error handling
#
# Duplicate names and missing required fields are reported immediately.

# %%
try:
    register_CFunction(
        name="square_density",
        desc="Duplicate demonstration.",
        params="void",
        body="return;",
    )
except ValueError as err:
    print(str(err))

try:
    CFunction(name="missing_body", desc="Missing body demonstration.")
except ValueError as err:
    print(str(err))

# %% [markdown]
# ## Coordinate wrappers
#
# Coordinate-specific generated functions use a modified subdirectory and name.

# %%
wrapped = function_name_and_subdir_with_CoordSystem("rhs", "eval", "Spherical")
print(wrapped)

register_CFunction(
    subdirectory="rhs",
    name="eval",
    CoordSystem_for_wrapper_func="Spherical",
    desc="Coordinate-specific RHS demonstration.",
    params="void",
    body="return;",
)
print("coordinate-specific key:", wrapped[1])
print("stored subdirectory:", CFunction_dict["eval__rfm__Spherical"].subdirectory)

# %% [markdown]
# ## Metadata fields
#
# Einstein Toolkit metadata, when needed, is stored as fields on the `CFunction`. The fields below are metadata only; no external build step is part of this notebook.

# %%
metadata_demo = CFunction(
    desc="Metadata demonstration.",
    name="metadata_demo",
    params="void",
    body="return;",
    ET_thorn_name="DemoThorn",
    ET_schedule_bins_entries=[("MoL_PostStep", "STORAGE: demo")],
    ET_current_thorn_CodeParams_used=["tutorial_cfl"],
)

print(metadata_demo.ET_thorn_name)
print(metadata_demo.ET_schedule_bins_entries)
print(metadata_demo.ET_current_thorn_CodeParams_used)
