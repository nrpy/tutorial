# %% [markdown]
# # C Function Registration
#
# Wrap generated C assignments in complete C functions and register them for
# generated projects.
#
# Navigation: [Index](../index.ipynb) |
# Previous: [C Code Generation](c_codegen.ipynb) |
# Next: [Finite Differences](finite_difference.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Wrap generated C assignments inside a callable C function.
# - Read a prototype as the short promise of what a function accepts and
#   returns.
# - See how NRPy stores a function before writing it to a file.
#
# ## Words for This Notebook
#
# - **Function:** a named block of instructions.
# - **Prototype:** a one-line description of a C function's name, inputs, and
#   output type.
# - **Function body:** the actual instructions inside the function.
# - **Stored function list:** NRPy's in-memory list of functions that can later
#   be written to source files.

# %% [markdown]
# ## Build and Register Complete C Functions
#
# A C prototype declares the function. The full function includes comments,
# includes, and formatted body text. The raw function is the bare C definition.

# %% [markdown]
# ## Import C Function Utilities
#
# These utilities register generated functions and derive names for
# coordinate-specialized wrappers.

# %%
from nrpy.c_function import (
    CFunction_dict,
    function_name_and_subdir_with_CoordSystem,
    register_CFunction,
)

# %% [markdown]
# ## Clear Tutorial Function Entries
#
# The reset removes tutorial-owned C functions before registering fresh
# examples.

# %%
removed_functions = []
for name in ["wave_energy_density", "wave_rhs_point"]:
    if CFunction_dict.pop(name, None) is not None:
        removed_functions.append(name)
print("cleared functions:", removed_functions)
# Out:
# cleared functions: []

# %% [markdown]
# ## Register the Energy-Density Function
#
# The full function is printed because it is the concept-bearing artifact. On a
# first pass, look for:
#
# - the description comment;
# - the function interface;
# - the body assignment;
# - the closing function marker.

# %%
register_CFunction(
    desc="Compute a compact wave-energy diagnostic.",
    cfunc_type="void",
    name="wave_energy_density",
    params="const double uu, const double vv, double *energy",
    body="*energy = 0.5*(vv*vv + uu*uu);\nreturn;",
)
registered = CFunction_dict["wave_energy_density"]
print("registered keys:", sorted(CFunction_dict))
print("prototype:")
print(registered.function_prototype)
print("full function:")
print(registered.full_function)
print("raw function:")
print(registered.raw_function)
# Out:
# registered keys: ['wave_energy_density']
# prototype:
# void wave_energy_density(const double uu, const double vv, double *energy);
# full function:
# /**
#  * Compute a compact wave-energy diagnostic.
#  */
# void wave_energy_density(const double uu, const double vv, double *energy) {
#   *energy = 0.5 * (vv * vv + uu * uu);
#   return;
# } // END FUNCTION: wave_energy_density
#
# raw function:
# /**
#  * Compute a compact wave-energy diagnostic.
# */
# void wave_energy_density(const double uu, const double vv, double *energy) {
# *energy = 0.5*(vv*vv + uu*uu);
# return;
# } // END FUNCTION: wave_energy_density

# %% [markdown]
# ## Register a Coordinate-Specialized Function
#
# The second function shows another registered name, then asks NRPy how it
# would name a coordinate-specialized variant.

# %%
register_CFunction(
    desc="Advance one point of a toy wave system.",
    cfunc_type="void",
    name="wave_rhs_point",
    params=(
        "const double uu, const double vv, "
        "double *uu_rhs, double *vv_rhs"
    ),
    body="*uu_rhs = vv;\n*vv_rhs = -uu;\nreturn;",
)
wrapper_name, wrapper_subdir = function_name_and_subdir_with_CoordSystem(
    "",
    "wave_energy_density",
    "Spherical",
)
print("second registered key:", "wave_rhs_point" in CFunction_dict)
print("coordinate-specialized name:", wrapper_name)
print("coordinate-specialized subdirectory:", wrapper_subdir)
# Out:
# second registered key: True
# coordinate-specialized name: Spherical
# coordinate-specialized subdirectory: wave_energy_density__rfm__Spherical

# %% [markdown]
# ## Validation Check
#
# The stored function should expose the expected prototype, source text, raw C
# body, and coordinate-specialized naming convention.

# %%
if registered.name != "wave_energy_density":
    raise RuntimeError(f"Unexpected function name: {registered.name}")
if registered.cfunc_type != "void":
    raise RuntimeError(f"Unexpected function type: {registered.cfunc_type}")
if registered.params != "const double uu, const double vv, double *energy":
    raise RuntimeError(f"Unexpected parameters: {registered.params}")
if registered.body != "*energy = 0.5*(vv*vv + uu*uu);\nreturn;":
    raise RuntimeError(f"Unexpected function body: {registered.body}")
if "wave_energy_density" not in CFunction_dict:
    raise RuntimeError("wave_energy_density is missing from CFunction_dict")
if "wave_rhs_point" not in CFunction_dict:
    raise RuntimeError("wave_rhs_point is missing from CFunction_dict")

for expected_piece in [
    "Compute a compact wave-energy diagnostic.",
    "wave_energy_density",
    "END FUNCTION: wave_energy_density",
]:
    if expected_piece not in registered.full_function:
        raise RuntimeError(f"Missing {expected_piece} in full function")
if wrapper_name != "Spherical":
    raise RuntimeError(f"Unexpected wrapper name: {wrapper_name}")
if wrapper_subdir != "wave_energy_density__rfm__Spherical":
    raise RuntimeError(f"Unexpected wrapper subdir: {wrapper_subdir}")

print("validated function object:", registered.name)
print("validated stored functions:", sorted(CFunction_dict))
print("validated coordinate-specialized subdirectory:", wrapper_subdir)
# Out:
# validated function object: wave_energy_density
# validated stored functions: ['wave_energy_density', 'wave_rhs_point']
# validated coordinate-specialized subdirectory: wave_energy_density__rfm__Spherical

# %% [markdown]
# ## Learning Check
#
# After inspecting the stored function, point to the same function name in the
# printed interface, full source, and stored-function list.

# %% [markdown]
# ## Continue to Finite Differences
#
# - [Finite Differences](finite_difference.ipynb)
# - [Start-to-Finish Cartesian Wave Project](../3-wave_equation/start_to_finish_wave_cartesian.ipynb)
# - [ETLegacy Core Infrastructure](../5-infrastructures/etlegacy_core_infrastructure.ipynb)
