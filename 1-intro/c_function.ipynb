# %% [markdown]
# # C Function Registration
#
# Wrap generated C assignments in complete C functions and register them for generated projects.
#
# Navigation: [Index](../index.ipynb) | Previous: [C Code Generation](c_codegen.ipynb) | Next: [Finite Differences](finite_difference.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Wrap generated C assignments inside a callable C function.
# - Read a prototype as the short promise of what a function accepts and returns.
# - See how NRPy stores a function before writing it to a file.
#
# ## Words for This Notebook
#
# - **Function:** a named block of instructions.
# - **Prototype:** a one-line description of a C function's name, inputs, and output type.
# - **Function body:** the actual instructions inside the function.
# - **Registry:** NRPy's in-memory list of functions that can later be written to source files.
#
# Use the code cells actively: first predict what should happen, then run the cell, then explain the output in plain language. This predict-run-explain pattern keeps the physics idea connected to the programming details.

# %% [markdown]
# ## Build and Register a Complete C Function
# A C function prototype declares the function. The full function includes comments, includes, and the body. The raw function is the bare C definition.

# %% [markdown]
# ## Import C Function Utilities
#
# These imports expose the NRPy and Python tools used in the next steps.

# %%
from nrpy.c_function import (
    CFunction_dict,
    function_name_and_subdir_with_CoordSystem,
    register_CFunction,
)

# %% [markdown]
# ## Clear Tutorial Function Entries
#
# The reset removes tutorial-owned C functions before registering fresh examples.

# %%
for name in ["wave_energy_density", "wave_rhs_point"]:
    CFunction_dict.pop(name, None)

# %% [markdown]
# ## Register the Energy-Density Function
#
# NRPy's stored function list holds a complete C function or workflow hook for later file generation.

# %%
register_CFunction(
    desc="Compute a compact wave-energy diagnostic.",
    cfunc_type="void",
    name="wave_energy_density",
    params="const double uu, const double vv, double *energy",
    body="*energy = 0.5*(vv*vv + uu*uu);\nreturn;",
)
registered = CFunction_dict["wave_energy_density"]
print("registered keys:", sorted(CFunction_dict))
print("prototype:")
print(registered.function_prototype)
print("full function:")
print(registered.full_function)
print("raw function:")
print(registered.raw_function)
# Out:
# registered keys: ['wave_energy_density']
# prototype:
# void wave_energy_density(const double uu, const double vv, double *energy);
# full function:
# /**
#  * Compute a compact wave-energy diagnostic.
#  */
# void wave_energy_density(const double uu, const double vv, double *energy) {
#   *energy = 0.5 * (vv * vv + uu * uu);
#   return;
# } // END FUNCTION: wave_energy_density
#
# raw function:
# /**
#  * Compute a compact wave-energy diagnostic.
# */
# void wave_energy_density(const double uu, const double vv, double *energy) {
# *energy = 0.5*(vv*vv + uu*uu);
# return;
# } // END FUNCTION: wave_energy_density

# %% [markdown]
# ## Register a Coordinate-Specialized Function
#
# NRPy's stored function list holds a complete C function or workflow hook for later file generation.

# %%
register_CFunction(
    desc="Advance one point of a toy wave system.",
    cfunc_type="void",
    name="wave_rhs_point",
    params="const double uu, const double vv, double *uu_rhs, double *vv_rhs",
    body="*uu_rhs = vv;\n*vv_rhs = -uu;\nreturn;",
)
print("second registered key:", "wave_rhs_point" in CFunction_dict)
wrapper_name, wrapper_subdir = function_name_and_subdir_with_CoordSystem(
    "", "wave_energy_density", "Spherical"
)
print("coordinate-specialized name:", wrapper_name)
print("coordinate-specialized subdirectory:", wrapper_subdir)
# Out:
# second registered key: True
# coordinate-specialized name: Spherical
# coordinate-specialized subdirectory: wave_energy_density__rfm__Spherical

# %% [markdown]
# The output shows the same registered function at three levels: prototype, full generated source, and raw C definition. The stored-function name is what later file-writing steps use when writing source files.

# %% [markdown]
# ## Learning Check
#
# Before inspecting the prototype, predict which function name should appear. Then find the same name in the prototype and in the full source.

# %% [markdown]
# ## Continue to Finite Differences
# - [Finite Differences](finite_difference.ipynb)
# - [Start-to-Finish Cartesian Wave Project](../3-wave_equation/start_to_finish_wave_cartesian.ipynb)
# - [ETLegacy Core Infrastructure](../5-infrastructures/etlegacy_core_infrastructure.ipynb)
