# %% [markdown]
# # C Function Registration
#
# `nrpy.c_function` turns assignment text into complete C functions and stores them in a registry. A **C function prototype** is the declaration other C files can see. A **registry** is a named collection NRPy later walks over when it writes generated source files.

# %% [markdown]
# [Index](../index.ipynb) | Previous: [C Code Generation](c_codegen.ipynb) | Next: [Finite Differences](finite_difference.ipynb)

# %% [markdown]
# ## Why This Matters
#
# Generated projects need complete C functions, not isolated assignments. The C-function registry is the named collection NRPy walks over when it writes prototypes and source files.

# %% [markdown]
# ## What You Will See
#
# - Current function-registration signatures.
# - A complete C prototype and full generated function.
# - A registry entry and short safety checks.

# %%
import inspect

from nrpy.c_function import (
    CFunction,
    CFunction_dict,
    function_name_and_subdir_with_CoordSystem,
    register_CFunction,
)

CFunction_dict.clear()
print("CFunction signature:")
print(inspect.signature(CFunction))
print("register_CFunction signature:")
print(inspect.signature(register_CFunction))
# Out:
# CFunction signature:
# (subdirectory: str = '.', enable_simd: bool = False, includes: Optional[List[str]] = None, prefunc: str = '', desc: str = '', cfunc_decorators: str = '', cfunc_type: str = 'void', name: str = '', params: str = '', include_CodeParameters_h: bool = False, body: str = '', postfunc: str = '', CoordSystem_for_wrapper_func: str = '', ET_thorn_name: str = '', ET_schedule_bins_entries: Optional[List[Tuple[str, str]]] = None, ET_current_thorn_CodeParams_used: Optional[List[str]] = None, ET_other_thorn_CodeParams_used: Optional[List[str]] = None) -> None
# register_CFunction signature:
# ...

# %% [markdown]
# ## A Standalone `CFunction`
#
# A `CFunction` needs a name, description, parameter list, and body. The **prototype** is the C declaration; the **full function** is the documented C function text NRPy can write to a source file.

# %%
demo = CFunction(
    desc="Return one plus the input integer.",
    cfunc_type="int",
    name="add_one",
    params="const int x",
    body="return x + 1;",
)

print("prototype:")
print(demo.function_prototype)
print("full function:")
print(demo.full_function)
print("raw function:")
print(demo.raw_function)
# Out:
# prototype:
# int add_one(const int x);
# full function:
# /**
#  * Return one plus the input integer.
#  */
# int add_one(const int x) { return x + 1; } // END FUNCTION: add_one
#
# raw function:
# /**
#  * Return one plus the input integer.
# */
# int add_one(const int x) {
# return x + 1;
# } // END FUNCTION: add_one

# %% [markdown]
# ## Registry Entries
#
# `register_CFunction` constructs a `CFunction` and stores it in `CFunction_dict`. Generated projects collect named registry entries when writing files.

# %%
register_CFunction(
    name="square_density",
    desc="Store rho squared in the output pointer.",
    params="const double rho, double *out",
    body="*out = rho*rho;\nreturn;",
)

registered = CFunction_dict["square_density"]
print("registered keys:", sorted(CFunction_dict))
print("prototype:")
print(registered.function_prototype)
print("full function:")
print(registered.full_function)
# Out:
# registered keys: ['square_density']
# prototype:
# void square_density(const double rho, double *out);
# full function:
# /**
#  * Store rho squared in the output pointer.
#  */
# void square_density(const double rho, double *out) {
#   *out = rho * rho;
#   return;
# } // END FUNCTION: square_density

# %% [markdown]
# ## Intentional error handling
#
# Duplicate names and missing required fields are reported immediately.

# %%
try:
    register_CFunction(
        name="square_density",
        desc="Duplicate demonstration.",
        params="void",
        body="return;",
    )
except ValueError as err:
    print(str(err))

try:
    CFunction(name="missing_body", desc="Missing body demonstration.")
except ValueError as err:
    print(str(err))
# Out:
# Error: already registered square_density in CFunction_dict.
# Error in CFunction: 'body' attribute must be set.

# %% [markdown]
# ## Advanced Preview: Coordinate Wrappers
#
# Coordinate-specific generated functions use a modified subdirectory and name. The infrastructure notebooks return to this idea when generated projects collect many registered functions.

# %%
wrapped = function_name_and_subdir_with_CoordSystem("rhs", "eval", "Spherical")
print(wrapped)

register_CFunction(
    subdirectory="rhs",
    name="eval",
    CoordSystem_for_wrapper_func="Spherical",
    desc="Coordinate-specific RHS demonstration.",
    params="void",
    body="return;",
)
print("coordinate-specific key:", wrapped[1])
print("stored subdirectory:", CFunction_dict["eval__rfm__Spherical"].subdirectory)
# Out:
# ('rhs/Spherical', 'eval__rfm__Spherical')
# coordinate-specific key: eval__rfm__Spherical
# stored subdirectory: rhs/Spherical

# %% [markdown]
# ## Advanced Preview: Einstein Toolkit Metadata
#
# Einstein Toolkit metadata, when needed, is stored as fields on the `CFunction`. The fields below are metadata only; no external build step is part of this notebook. See [ETLegacy core infrastructure](../5-infrastructures/etlegacy_core_infrastructure.ipynb) for the generated files that use these fields.

# %%
metadata_demo = CFunction(
    desc="Metadata demonstration.",
    name="metadata_demo",
    params="void",
    body="return;",
    ET_thorn_name="DemoThorn",
    ET_schedule_bins_entries=[("MoL_PostStep", "STORAGE: demo")],
    ET_current_thorn_CodeParams_used=["tutorial_cfl"],
)

print(metadata_demo.ET_thorn_name)
print(metadata_demo.ET_schedule_bins_entries)
print(metadata_demo.ET_current_thorn_CodeParams_used)
# Out:
# DemoThorn
# [('MoL_PostStep', 'STORAGE: demo')]
# ['tutorial_cfl']

# %% [markdown]
# ## Where This Leads
#
# - [C Code Generation](c_codegen.ipynb) reviews the prerequisite step.
# - [Finite Differences](finite_difference.ipynb) continues the tutorial path.
# - [Generated Project Anatomy](../0-getting_started/generated_projects.ipynb) connects this topic to a natural application.
# - [BHaH Project Anatomy](../5-infrastructures/bhah_project_anatomy.ipynb) connects this topic to a natural application.
