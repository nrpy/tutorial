# %% [markdown]
# # C Function Registration
#
# ## Author: Zach Etienne
#
# To run the whole notebook, click the `>>` toolbar button and choose
# **Restart Kernel and Run All Cells...**.
#
# This notebook shows how NRPy wraps generated C assignments in complete C
# functions and stores them in a registration dictionary for generated
# projects.
#
# ### Required Reading
#
# - [C Code Generation](c_codegen.ipynb), because CFunction registration wraps
#   generated C assignments.
#
# ### NRPy Source Code
#
# - [nrpy/nrpy/c_function.py](../nrpy/nrpy/c_function.py): stores registered C
#   functions for generated projects.
#
# # Table of Contents
#
# 1. [Words for This Notebook](#Words-for-This-Notebook)
# 1. [Step 1](#Step-1:-Read-the-shape-of-a-complete-C-function): Read C shape.
# 1. [Step 2](#Step-2:-Map-C-function-pieces-to-NRPy-registration-arguments):
#    Map pieces.
# 1. [Step 3](#Step-3:-Initialize-CFunction-registration-tools): Initialize.
# 1. [Step 4](#Step-4:-Reset-tutorial-owned-registered-functions): Reset.
# 1. [Step 5](#Step-5:-Define-and-register-a-toy-quadratic-diagnostic):
#    Register diagnostic.
# 1. [Step 6](#Step-6:-Inspect-the-complete-registered-diagnostic-function):
#    Inspect diagnostic.
# 1. [Step 7](#Step-7:-Register-a-right-hand-side-function): Register RHS.
# 1. [Validation Check](#Validation-Check): Validate registered functions.
# 1. [Learning Check](#Learning-Check): Check understanding.
# 1. [What next?](#What-next?)

# %% [markdown]
# # Words for This Notebook
# ### [Back to [top](#Table-of-Contents)]
#
# - **C function:** a named C block with a return type, parameter list, and
#   body.
# - **Prototype:** the one-line C interface stating return type, name, and
#   parameters.
# - **Parameter list:** the C inputs and output pointers accepted by the
#   function.
# - **Return type:** the C type returned by the function, such as `void`.
# - **Function body:** the statements inside the braces.
# - **Include:** a header dependency needed before compiling a function.
# - **Registration:** storing a complete C function object in NRPy's function
#   dictionary.
# - **Stored-function registry:** `cfc.CFunction_dict`, the in-memory mapping
#   from function names to registered CFunction objects.
#
# The first code object is the stored-function registry. Its infrastructure
# role is to hold complete C functions until project writers emit source
# files, and the first output confirms tutorial-owned entries were cleared.

# %% [markdown]
# # Step 1: Read the shape of a complete C function
# ### [Back to [top](#Table-of-Contents)]
#
# A complete C function has a description, return type, name, parameter list,
# local declarations when needed, and assignments or algorithm statements.
#
# ```c
# /*
#  * Description of what the function computes.
#  */
# return_type function_name(parameter_list) {
#     local_declarations;
#     assignments_or_algorithm;
# }
# ```

# %% [markdown]
# # Step 2: Map C-function pieces to NRPy registration arguments
# ### [Back to [top](#Table-of-Contents)]
#
# | C-function piece | NRPy argument |
# | --- | --- |
# | description comment | `desc` |
# | return type | `cfunc_type` |
# | function name | `name` |
# | parameter list | `params` |
# | header dependencies | `includes` |
# | code before the function | `prefunc` |
# | function body | `body` |
# | code after the function | `postfunc` |
# | output subdirectory | `subdirectory` |
# | coordinate wrapper | `CoordSystem_for_wrapper_func` |
# | CodeParameter header | `include_CodeParameters_h` |
# | SIMD or intrinsics choice | `enable_simd` |
#
# The registered functions in this notebook are:
#
# | Name | Purpose | Where used | Inspect |
# | --- | --- | --- | --- |
# | `wave_quadratic_diagnostic` | toy pointwise diagnostic | registry | full source |
# | `wave_rhs_point` | toy pointwise RHS update | registry | prototype/body |

# %% [markdown]
# # Step 3: Initialize CFunction registration tools
# ### [Back to [top](#Table-of-Contents)]
#
# The CFunction module provides the registry and the registration function.

# %%
import nrpy.c_function as cfc

# %% [markdown]
# # Step 4: Reset tutorial-owned registered functions
# ### [Back to [top](#Table-of-Contents)]
#
# The reset removes only the tutorial-owned function names before registering
# fresh examples.

# %%
removed_functions = []
for name in ["wave_quadratic_diagnostic", "wave_rhs_point"]:
    if cfc.CFunction_dict.pop(name, None) is not None:
        removed_functions.append(name)
print("cleared functions:", removed_functions)
# Out:
# cleared functions: []

# %% [markdown]
# # Step 5: Define and register a toy quadratic diagnostic
# ### [Back to [top](#Table-of-Contents)]
#
# In this toy wave state, `uu` is the wave amplitude and `vv` is its auxiliary
# time derivative. The expression `0.5*(vv*vv + uu*uu)` is a compact
# quadratic diagnostic for the CFunction lesson, not a physically normalized
# wave energy density.
#
# The code defines each registration component as a Python variable, assembles
# the function body, then calls `cfc.register_CFunction()`.

# %%
diagnostic_desc = "Compute a compact quadratic diagnostic for a toy wave state."
diagnostic_cfunc_type = "void"
diagnostic_name = "wave_quadratic_diagnostic"
diagnostic_params = "const double uu, const double vv, double *diagnostic"
diagnostic_body = "*diagnostic = 0.5*(vv*vv + uu*uu);\nreturn;"

cfc.register_CFunction(
    desc=diagnostic_desc,
    cfunc_type=diagnostic_cfunc_type,
    name=diagnostic_name,
    params=diagnostic_params,
    body=diagnostic_body,
)
print("registered diagnostic:", diagnostic_name in cfc.CFunction_dict)
print("registration pieces:", diagnostic_cfunc_type, diagnostic_name)
# Out:
# registered diagnostic: True
# registration pieces: void wave_quadratic_diagnostic

# %% [markdown]
# # Step 6: Inspect the complete registered diagnostic function
# ### [Back to [top](#Table-of-Contents)]
#
# The full function is printed because it is the concept-bearing artifact.
# Inspect the description, prototype, parameter list, full source, and raw C
# function.

# %%
registered = cfc.CFunction_dict[diagnostic_name]
print("registered function catalog entry:")
print("name:", registered.name)
print("purpose:", diagnostic_desc)
print("where used: CFunction_dict")
print("inspect: description, prototype, params, full source")
print("function declaration:")
print(registered.function_prototype)
print("complete function:")
print(registered.full_function)
print("raw function:")
print(registered.raw_function)
# Out:
# registered function catalog entry:
# name: wave_quadratic_diagnostic
# purpose: Compute a compact quadratic diagnostic for a toy wave state.
# where used: CFunction_dict
# inspect: description, prototype, params, full source
# function declaration:
# void wave_quadratic_diagnostic(const double uu, const double vv, double *diagnostic);
# complete function:
# /**
#  * Compute a compact quadratic diagnostic for a toy wave state.
#  */
# void wave_quadratic_diagnostic(const double uu, const double vv, double *diagnostic) {
#   *diagnostic = 0.5 * (vv * vv + uu * uu);
#   return;
# } // END FUNCTION: wave_quadratic_diagnostic
#
# raw function:
# /**
#  * Compute a compact quadratic diagnostic for a toy wave state.
# */
# void wave_quadratic_diagnostic(const double uu, const double vv, double *diagnostic) {
# *diagnostic = 0.5*(vv*vv + uu*uu);
# return;
# } // END FUNCTION: wave_quadratic_diagnostic

# %% [markdown]
# # Step 7: Register a right-hand-side function
# ### [Back to [top](#Table-of-Contents)]
#
# A generated project normally stores many functions. This second toy function
# represents one pointwise RHS update: it writes `vv` to `uu_rhs` and `-uu` to
# `vv_rhs`.

# %%
cfc.register_CFunction(
    desc="Advance one point of a toy wave system.",
    cfunc_type="void",
    name="wave_rhs_point",
    params=(
        "const double uu, const double vv, "
        "double *uu_rhs, double *vv_rhs"
    ),
    body="*uu_rhs = vv;\n*vv_rhs = -uu;\nreturn;",
)
second_function = cfc.CFunction_dict["wave_rhs_point"]
print("second registered key:", "wave_rhs_point" in cfc.CFunction_dict)
print("second function declaration:")
print(second_function.function_prototype)
# Out:
# second registered key: True
# second function declaration:
# void wave_rhs_point(const double uu, const double vv, double *uu_rhs, double *vv_rhs);

# %% [markdown]
# # Validation Check
# ### [Back to [top](#Table-of-Contents)]
#
# The trusted result is the explicitly defined registration variables and the
# CFunction metadata produced by NRPy. The newly computed result is the pair
# of registered tutorial functions. Passing means metadata, body text, and
# complete registered source match the registration components.

# %%
if registered.name != diagnostic_name:
    raise RuntimeError(f"Unexpected function name: {registered.name}")
if registered.cfunc_type != diagnostic_cfunc_type:
    raise RuntimeError(f"Unexpected function type: {registered.cfunc_type}")
if registered.params != diagnostic_params:
    raise RuntimeError(f"Unexpected parameters: {registered.params}")
if registered.body != diagnostic_body:
    raise RuntimeError(f"Unexpected function body: {registered.body}")
if diagnostic_name not in cfc.CFunction_dict:
    raise RuntimeError(f"{diagnostic_name} is missing from CFunction_dict")
if "wave_rhs_point" not in cfc.CFunction_dict:
    raise RuntimeError("wave_rhs_point is missing from CFunction_dict")

second_function = cfc.CFunction_dict["wave_rhs_point"]
if second_function.params != (
    "const double uu, const double vv, "
    "double *uu_rhs, double *vv_rhs"
):
    raise RuntimeError(f"Unexpected RHS parameters: {second_function.params}")
if second_function.body != "*uu_rhs = vv;\n*vv_rhs = -uu;\nreturn;":
    raise RuntimeError(f"Unexpected RHS function body: {second_function.body}")

for expected_piece in [
    diagnostic_desc,
    diagnostic_name,
    f"END FUNCTION: {diagnostic_name}",
]:
    if expected_piece not in registered.full_function:
        raise RuntimeError(f"Missing {expected_piece} in full function")

print("trusted result: defined registration variables and CFunction metadata")
print("newly computed result: registered diagnostic and RHS functions")
print("validated function object:", registered.name)
print("validated second function:", second_function.name)
print("validated stored functions:", sorted(cfc.CFunction_dict))
# Out:
# trusted result: defined registration variables and CFunction metadata
# newly computed result: registered diagnostic and RHS functions
# validated function object: wave_quadratic_diagnostic
# validated second function: wave_rhs_point
# validated stored functions: ['wave_quadratic_diagnostic', 'wave_rhs_point']

# %% [markdown]
# # Learning Check
# ### [Back to [top](#Table-of-Contents)]
#
# After inspecting the stored function, point to the same function name in the
# printed prototype, full source, and stored-function registry.

# %% [markdown]
# # What next?
#
# - [Finite Differences](finite_difference.ipynb)
# - [Start-to-Finish Cartesian Wave Project](../3-wave_equation/start_to_finish_wave_cartesian.ipynb)
# - [ETLegacy Core Infrastructure](../5-infrastructures/etlegacy_core_infrastructure.ipynb)
