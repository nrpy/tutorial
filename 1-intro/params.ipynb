# %% [markdown]
# # Parameters
#
# `nrpy.params` stores two kinds of state:
#
# - Python-side parameters, read and changed while Python builds symbolic expressions.
# - Generated-code parameters, represented by SymPy symbols and carried into generated C projects.
#
# Use short, project-specific names and clean up tutorial names when re-running exploratory cells.

# %% [markdown]
# [Index](../index.ipynb) | Previous: [NRPy in Ten Minutes](ten_minute_overview.ipynb) | Next: [Indexed Expressions](indexedexp.ipynb)

# %% [markdown]
# ## Why This Matters
#
# Parameters are named knobs in a calculation. They let a notebook or generated executable change choices such as wave speed, grid size, finite-difference order, and output cadence.

# %% [markdown]
# ## What You Will See
#
# - Python-side setup parameters and generated-code parameters.
# - Parameter values that behave like named calculation knobs.
# - A generated C assignment that uses code parameters.

# %%
import sympy as sp

import nrpy.c_codegen as ccg
import nrpy.params as par

tutorial_param_names = ["tutorial_steps", "tutorial_method"]
tutorial_code_param_names = [
    "tutorial_cfl",
    "tutorial_wave_speed",
    "tutorial_damping",
]

for name in tutorial_param_names:
    par.glb_params_dict.pop(name, None)
for name in tutorial_code_param_names:
    par.glb_code_params_dict.pop(name, None)

# %% [markdown]
# ## Python-side parameters
#
# `register_param` records a Python value. `parval_from_str` reads it, and `set_parval_from_str` changes it. A `module::name` lookup is accepted, but the stored key is the final name.

# %%
par.register_param(
    int,
    "tutorial_params",
    "tutorial_steps",
    5,
    "Number of demonstration time steps.",
)
par.register_param(
    str,
    "tutorial_params",
    "tutorial_method",
    "RK4",
    "Name of the demonstration time integrator.",
)

print("initial steps:", par.parval_from_str("tutorial_params::tutorial_steps"))
par.set_parval_from_str("tutorial_steps", 8)
print("updated steps:", par.parval_from_str("tutorial_steps"))
print("method:", par.parval_from_str("tutorial_method"))
# Out:
# initial steps: 5
# updated steps: 8
# method: RK4

# %% [markdown]
# ## Generated-code parameters
#
# `register_CodeParameter` and `register_CodeParameters` return SymPy symbols. Their metadata stays in `glb_code_params_dict`, where project-generation tools can find C type, default value, and parameter-file behavior.

# %%
tutorial_cfl = par.register_CodeParameter(
    "REAL",
    "tutorial_params",
    "tutorial_cfl",
    defaultvalue=0.5,
    assumption="RealPositive",
    description="Courant factor for the demonstration.",
)

tutorial_wave_speed, tutorial_damping = par.register_CodeParameters(
    "REAL",
    "tutorial_params",
    ["tutorial_wave_speed", "tutorial_damping"],
    defaultvalues=[1.0, 0.1],
    descriptions=[
        "Wave speed used by the demonstration.",
        "Linear damping coefficient used by the demonstration.",
    ],
)

print("symbols:", tutorial_cfl, tutorial_wave_speed, tutorial_damping)
for name in tutorial_code_param_names:
    item = par.glb_code_params_dict[name]
    print(name, item.cparam_type, item.defaultvalue, item.assumption)
# Out:
# symbols: tutorial_cfl tutorial_wave_speed tutorial_damping
# tutorial_cfl REAL 0.5 RealPositive
# tutorial_wave_speed REAL 1.0 Real
# tutorial_damping REAL 0.1 Real

# %% [markdown]
# ## Parameters inside generated assignments
#
# Generated-code parameters are ordinary SymPy symbols in expressions. Code generation preserves those names so project infrastructure can provide their values at runtime.

# %%
u, v = sp.symbols("u v", real=True)
rhs = tutorial_wave_speed * v - tutorial_damping * u

print(ccg.c_codegen(rhs, "rhs_u", include_braces=False, verbose=False))
# Out:
# rhs_u = -tutorial_damping*u + tutorial_wave_speed*v;

# %% [markdown]
# ## Local cleanup
#
# Removing only the names introduced here keeps this notebook repeatable without disturbing parameters registered by NRPy itself.

# %%
for name in tutorial_param_names:
    par.glb_params_dict.pop(name, None)
for name in tutorial_code_param_names:
    par.glb_code_params_dict.pop(name, None)

print("tutorial parameter names removed")
# Out:
# tutorial parameter names removed

# %% [markdown]
# ## Where This Leads
#
# - [NRPy in Ten Minutes](ten_minute_overview.ipynb) reviews the prerequisite step.
# - [Indexed Expressions](indexedexp.ipynb) continues the tutorial path.
# - [Generated Project Anatomy](../0-getting_started/generated_projects.ipynb) connects this topic to a natural application.
# - [C Code Generation](c_codegen.ipynb) connects this topic to a natural application.
