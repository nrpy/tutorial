# %% [markdown]
# # Parameters
#
# Represent model and numerical choices as named parameters that later appear in generated code and parameter files.
#
# Navigation: [Index](../index.ipynb) | Previous: [NRPy in Ten Minutes](ten_minute_overview.ipynb) | Next: [Indexed Expressions](indexedexp.ipynb)

# %% [markdown]
# ## Learning Goals
#
# - Use parameters as named knobs for a calculation.
# - Distinguish Python-side values from C-side values used by generated code.
# - Generate a C assignment that contains a parameter symbol.
#
# ## Words for This Notebook
#
# - **Parameter:** a named value that controls a calculation, such as resolution or wave speed.
# - **Default value:** the value used unless a later step changes it.
# - **Code parameter:** a parameter that appears in generated C code and can be set when the C program runs.
#
# Use the code cells actively: first predict what should happen, then run the cell, then explain the output in plain language. This predict-run-explain pattern keeps the physics idea connected to the programming details.

# %% [markdown]
# ## Parameter Interfaces Used Here
#
# - `nrpy.params` registers Python-side tutorial choices and typed C code parameters.
# - `nrpy.c_codegen` turns a symbolic parameter expression into a C assignment.

# %% [markdown]
# ## Register Model and Numerical Knobs
# A parameter can be a Python-side setting or a C-side value that appears in generated code and parameter files.

# %% [markdown]
# ## Import SymPy for Parameterized Expressions
#
# These imports expose the NRPy and Python tools used in the next steps.

# %%
import sympy as sp

# %% [markdown]
# ## Import Parameter and Codegen Tools
#
# These imports expose the NRPy registries and infrastructure writers used below.

# %%
import nrpy.c_codegen as ccg
import nrpy.params as par

# %% [markdown]
# ## Register Python-Side Tutorial Parameters
#
# Named parameters keep numerical choices separate from symbolic formulas.

# %%
par.register_param(
    int, "tutorial_params", "tutorial_resolution", 64, "Number of grid points."
)
par.register_param(
    str, "tutorial_params", "tutorial_time_method", "RK4", "Time integration method."
)

# %% [markdown]
# ## Update a Runtime-Style Parameter Value
#
# The output compares the original value with the value read after changing it by name.

# %%
print("initial resolution:", par.parval_from_str("tutorial_resolution"))
par.set_parval_from_str("tutorial_resolution", 128)
print("updated resolution:", par.parval_from_str("tutorial_resolution"))
print("time method:", par.parval_from_str("tutorial_time_method"))
# Out:
# initial resolution: 64
# updated resolution: 128
# time method: RK4

# %% [markdown]
# ## Register C-Side Code Parameters
#
# Named parameters keep numerical choices separate from symbolic formulas.

# %%
wave_speed = par.register_CodeParameter(
    "REAL", "tutorial_params", "tutorial_wave_speed", 1.0
)
final_time = par.register_CodeParameter(
    "REAL", "tutorial_params", "tutorial_final_time", 0.2
)
output_cadence = par.register_CodeParameter(
    "int", "tutorial_params", "tutorial_output_cadence", 4
)

# %% [markdown]
# ## Inspect Code Parameter Metadata
#
# C parameters carry types and defaults that generated source and parameter files can use later.

# %%
print("C parameter symbols:", wave_speed, final_time, output_cadence)
for name in ["tutorial_wave_speed", "tutorial_final_time", "tutorial_output_cadence"]:
    item = par.glb_code_params_dict[name]
    print(name, item.cparam_type, item.defaultvalue)
# Out:
# C parameter symbols: tutorial_wave_speed tutorial_final_time tutorial_output_cadence
# tutorial_wave_speed REAL 1.0
# tutorial_final_time REAL 0.2
# tutorial_output_cadence int 4

# %% [markdown]
# ## Emit C Code That Uses a Parameter
#
# The output shows how a symbolic expression is emitted as C.

# %%
u, v = sp.symbols("u v", real=True)
rhs = wave_speed * v
print(ccg.c_codegen(rhs, "u_rhs", include_braces=False, verbose=False))
# Out:
# u_rhs = tutorial_wave_speed*v;

# %% [markdown]
# The parameter output shows how named values separate physics choices from formulas. Generated projects use the same idea when a parameter file changes resolution, final time, or wave speed without changing source code.

# %% [markdown]
# ## Learning Check
#
# Before changing `tutorial_resolution`, predict whether the printed value should change permanently inside this notebook session. Then rerun the read cell and explain what happened.

# %% [markdown]
# ## Continue to Indexed Expressions
# - [C Code Generation](c_codegen.ipynb)
# - [Start-to-Finish Cartesian Wave Project](../3-wave_equation/start_to_finish_wave_cartesian.ipynb)
