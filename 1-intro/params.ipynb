# %% [markdown]
# # Parameter Interfaces in NRPy
#
# ## Author: Zach Etienne
#
# This notebook introduces `nrpy.params`, the NRPy interface for values that steer Python-side logic and generated C code.
#
# Prerequisites: Python, basic SymPy, and an importable NRPy installation.
#
# Relevant module: `nrpy.params`.

# %% [markdown]
# # Table of Contents
#
# 1. [Step 1](#Step-1:-Import-modules-and-reset-tutorial-state): Import modules and reset tutorial state
# 2. [Step 2](#Step-2:-Register-Python-level-parameters): Register Python-level parameters
# 3. [Step 3](#Step-3:-Look-up-and-mutate-values-by-name): Look up and mutate values by name
# 4. [Step 4](#Step-4:-Inspect-tutorial-owned-parameter-state): Inspect tutorial-owned parameter state
# 5. [Step 5](#Step-5:-Register-scalar-CodeParameters): Register scalar `CodeParameter`s
# 6. [Step 6](#Step-6:-Register-groups-of-CodeParameters): Register groups of `CodeParameter`s
# 7. [Step 7](#Step-7:-Register-array-valued-CodeParameters): Register array-valued `CodeParameter`s
# 8. [Step 8](#Step-8:-Adjust-CodeParameter-defaults): Adjust `CodeParameter` defaults
# 9. [Step 9](#Step-9:-Use-CodeParameters-symbolically-and-emit-C-code): Use `CodeParameter`s symbolically and emit C code

# %% [markdown]
# # Step 1: Import modules and reset tutorial state
# ### \[Back to [top](#Table-of-Contents)\]
#
# `nrpy.params` stores two parameter families:
#
# * Python-level `NRPyParameter` objects in `par.glb_params_dict`.
# * `CodeParameter` objects in `par.glb_code_params_dict`.
#
# The cleanup below removes only names owned by this notebook. It leaves NRPy defaults such as infrastructure, floating-point type, parallelization, and formatting options intact.

# %%
import nrpy.params as par
import nrpy.c_codegen as ccg
import sympy as sp

PYTHON_PARAMETER_NAMES = [
    "grid_points",
    "final_time",
    "use_reflecting_bc",
    "bad_param",
]
CODE_PARAMETER_NAMES = [
    "cfl_factor",
    "wave_speed",
    "use_high_order_stencils",
    "coeff_a0",
    "coeff_a1",
    "coeff_b",
    "coeff_c",
    "bc_left_type",
    "bc_right_type",
    "background_state",
    "sponge_coefficients",
    "dx",
    "missing_default_example",
    "flag_a",
    "flag_b",
    "bad_array_example",
]
EXTRAS_KEYS = ["wave_tutorial"]

for name in PYTHON_PARAMETER_NAMES:
    par.glb_params_dict.pop(name, None)

for name in CODE_PARAMETER_NAMES:
    par.glb_code_params_dict.pop(name, None)

for key in EXTRAS_KEYS:
    par.glb_extras_dict.pop(key, None)

print("Tutorial parameter state reset.")
print("Retained NRPy defaults:")
for name in ["Infrastructure", "fp_type", "parallelization"]:
    print(f"  {name} = {par.parval_from_str(name)!r}")

# %% [markdown]
# # Step 2: Register Python-level parameters
# ### \[Back to [top](#Table-of-Contents)\]
#
# Use Python-level parameters for options that affect notebook or generator logic before C code is emitted. `register_param()` creates an `NRPyParameter` and stores it by name.

# %%
par.register_param(
    py_type=int,
    module="wave_tutorial",
    name="grid_points",
    value=200,
    description="Number of grid points for the model problem.",
)
par.register_param(
    py_type=float,
    module="wave_tutorial",
    name="final_time",
    value=50.0,
    description="Final model time.",
)
par.register_param(
    py_type=bool,
    module="wave_tutorial",
    name="use_reflecting_bc",
    value=True,
    description="Use reflecting boundary conditions.",
)

print("Python-level parameters:")
for name in ["grid_points", "final_time", "use_reflecting_bc"]:
    param = par.glb_params_dict[name]
    print(f"  {param.module}::{param.name} = {param.value!r} ({param.py_type.__name__})")

try:
    par.register_param(
        py_type=list,
        module="wave_tutorial",
        name="bad_param",
        value=[],
        description="Invalid parameter type.",
    )
except ValueError:
    print("Invalid Python-level parameter type rejected.")

assert par.glb_params_dict["grid_points"].value == 200
assert par.glb_params_dict["final_time"].value == 50.0
assert par.glb_params_dict["use_reflecting_bc"].value is True
assert "bad_param" not in par.glb_params_dict

# %% [markdown]
# # Step 3: Look up and mutate values by name
# ### \[Back to [top](#Table-of-Contents)\]
#
# `parval_from_str()` and `set_parval_from_str()` accept either a bare name or a `module::name` string. The stored key is the name after `::`.

# %%
print("Initial grid_points values:")
print("  bare name:", par.parval_from_str("grid_points"))
print("  module name:", par.parval_from_str("wave_tutorial::grid_points"))

par.set_parval_from_str("wave_tutorial::grid_points", 256)
par.set_parval_from_str("use_reflecting_bc", False)

print("Updated values:")
print("  grid_points =", par.parval_from_str("grid_points"))
print("  use_reflecting_bc =", par.parval_from_str("wave_tutorial::use_reflecting_bc"))

try:
    par.parval_from_str("wave_tutorial::does_not_exist")
except ValueError:
    print("Unknown Python-level parameter lookup rejected.")

assert par.parval_from_str("grid_points") == 256
assert par.glb_params_dict["grid_points"].value == 256
assert par.parval_from_str("use_reflecting_bc") is False

# %% [markdown]
# # Step 4: Inspect tutorial-owned parameter state
# ### \[Back to [top](#Table-of-Contents)\]
#
# The global dictionaries are useful for discovery, but tutorial output should filter them to known names or modules. `glb_extras_dict` stores auxiliary metadata when a workflow needs it.

# %%
print("Tutorial Python-level parameters:")
for name in ["grid_points", "final_time", "use_reflecting_bc"]:
    param = par.glb_params_dict[name]
    print(f"  {param.module}::{param.name}: value={param.value!r}; description={param.description}")

par.glb_extras_dict["wave_tutorial"] = {
    "purpose": "minimal parameter-interface examples",
    "python_parameter_names": list(PYTHON_PARAMETER_NAMES[:3]),
}

print("Tutorial extras:")
for key, value in par.glb_extras_dict["wave_tutorial"].items():
    print(f"  {key}: {value}")

assert par.glb_extras_dict["wave_tutorial"]["python_parameter_names"] == [
    "grid_points",
    "final_time",
    "use_reflecting_bc",
]

# %% [markdown]
# # Step 5: Register scalar CodeParameters
# ### \[Back to [top](#Table-of-Contents)\]
#
# A `CodeParameter` represents a value visible to generated C code. When `add_to_parfile=True`, it is also eligible for runtime control through generated parameter-file interfaces. Registration returns a SymPy symbol with the same name, which can be used in symbolic expressions.

# %%
cfl_factor = par.register_CodeParameter(
    cparam_type="REAL",
    module="wave_tutorial_code",
    name="cfl_factor",
    defaultvalue=0.4,
    assumption="RealPositive",
    add_to_parfile=True,
    commondata=True,
    description="Courant factor.",
)
wave_speed = par.register_CodeParameter(
    cparam_type="REAL",
    module="wave_tutorial_code",
    name="wave_speed",
    defaultvalue=1.0,
    assumption="RealPositive",
    add_to_parfile=True,
    commondata=True,
    description="Wave speed.",
)
use_high_order_stencils = par.register_CodeParameter(
    cparam_type="bool",
    module="wave_tutorial_code",
    name="use_high_order_stencils",
    defaultvalue=True,
    add_to_parfile=True,
    commondata=True,
    description="Enable higher-order stencils.",
)

print("Scalar CodeParameters:")
for name in ["cfl_factor", "wave_speed", "use_high_order_stencils"]:
    param = par.glb_code_params_dict[name]
    print(
        f"  {name}: type={param.cparam_type}; default={param.defaultvalue!r}; "
        f"parfile={param.add_to_parfile}; symbol={param.symbol}"
    )

try:
    par.register_CodeParameter(
        cparam_type="REAL",
        module="wave_tutorial_code",
        name="missing_default_example",
    )
except ValueError:
    print("Missing CodeParameter default rejected.")

assert str(cfl_factor) == "cfl_factor"
assert par.glb_code_params_dict["cfl_factor"].defaultvalue == 0.4
assert par.glb_code_params_dict["wave_speed"].defaultvalue == 1.0
assert par.glb_code_params_dict["use_high_order_stencils"].defaultvalue is True
assert par.glb_code_params_dict["cfl_factor"].add_to_parfile is True
assert par.glb_code_params_dict["wave_speed"].add_to_parfile is True
assert par.glb_code_params_dict["use_high_order_stencils"].add_to_parfile is True
assert "missing_default_example" not in par.glb_code_params_dict

# %% [markdown]
# # Step 6: Register groups of CodeParameters
# ### \[Back to [top](#Table-of-Contents)\]
#
# `register_CodeParameters()` registers several parameters with the same C type. A scalar default is broadcast to every name; a list assigns one default per name.

# %%
coeff_a0, coeff_a1, coeff_b, coeff_c = par.register_CodeParameters(
    cparam_type="REAL",
    module="wave_tutorial_code",
    names=["coeff_a0", "coeff_a1", "coeff_b", "coeff_c"],
    defaultvalues=[1.0, 0.5, -0.25, 0.0],
    descriptions=[
        "First model coefficient.",
        "Second model coefficient.",
        "Third model coefficient.",
        "Fourth model coefficient.",
    ],
)

bc_left_type, bc_right_type = par.register_CodeParameters(
    cparam_type="int",
    module="wave_tutorial_code",
    names=["bc_left_type", "bc_right_type"],
    defaultvalues=1,
)

print("Grouped CodeParameters:")
for name in [
    "coeff_a0",
    "coeff_a1",
    "coeff_b",
    "coeff_c",
    "bc_left_type",
    "bc_right_type",
]:
    param = par.glb_code_params_dict[name]
    print(f"  {name}: default={param.defaultvalue!r}; type={param.cparam_type}")

try:
    par.register_CodeParameters(
        cparam_type="bool",
        module="wave_tutorial_code",
        names=["flag_a", "flag_b"],
        defaultvalues=[True, False],
        descriptions=["Only one description."],
    )
except ValueError:
    print("Mismatched grouped CodeParameter descriptions rejected.")

assert [str(symbol) for symbol in [coeff_a0, coeff_a1, coeff_b, coeff_c]] == [
    "coeff_a0",
    "coeff_a1",
    "coeff_b",
    "coeff_c",
]
assert par.glb_code_params_dict["coeff_b"].defaultvalue == -0.25
assert par.glb_code_params_dict["bc_left_type"].defaultvalue == 1
assert par.glb_code_params_dict["bc_right_type"].defaultvalue == 1
assert "flag_a" not in par.glb_code_params_dict
assert "flag_b" not in par.glb_code_params_dict

# %% [markdown]
# # Step 7: Register array-valued CodeParameters
# ### \[Back to [top](#Table-of-Contents)\]
#
# Array-valued `CodeParameter`s use type strings such as `"REAL[3]"`. Their defaults are stored as Python lists. For `REAL[...]` and `int[...]` arrays, pass `add_to_set_CodeParameters_h=False`.

# %%
background_state = par.register_CodeParameter(
    cparam_type="REAL[3]",
    module="wave_tutorial_code",
    name="background_state",
    defaultvalue=[0.0, 0.0, 0.0],
    commondata=True,
    add_to_set_CodeParameters_h=False,
    description="Three-component background state.",
)
sponge_coefficients = par.register_CodeParameter(
    cparam_type="REAL[4]",
    module="wave_tutorial_code",
    name="sponge_coefficients",
    defaultvalue=0.05,
    commondata=True,
    add_to_set_CodeParameters_h=False,
    description="Boundary damping coefficients.",
)

print("Array-valued CodeParameters:")
for name in ["background_state", "sponge_coefficients"]:
    param = par.glb_code_params_dict[name]
    print(f"  {name}: type={param.cparam_type}; default={param.defaultvalue}")

try:
    par.register_CodeParameter(
        cparam_type="REAL[2]",
        module="wave_tutorial_code",
        name="bad_array_example",
        defaultvalue=[0.0, 1.0],
        commondata=True,
        add_to_set_CodeParameters_h=True,
    )
except ValueError:
    print("Array CodeParameter with incompatible header setting rejected.")

assert str(background_state) == "background_state"
assert str(sponge_coefficients) == "sponge_coefficients"
assert par.glb_code_params_dict["background_state"].defaultvalue == [0.0, 0.0, 0.0]
assert par.glb_code_params_dict["sponge_coefficients"].defaultvalue == [
    0.05,
    0.05,
    0.05,
    0.05,
]
assert par.glb_code_params_dict["background_state"].add_to_set_CodeParameters_h is False
assert par.glb_code_params_dict["sponge_coefficients"].add_to_set_CodeParameters_h is False
assert "bad_array_example" not in par.glb_code_params_dict

# %% [markdown]
# # Step 8: Adjust CodeParameter defaults
# ### \[Back to [top](#Table-of-Contents)\]
#
# `adjust_CodeParam_default()` changes a registered default without re-registering the parameter. Pass a plain name for scalar parameters or `name[index]` for array entries.

# %%
par.adjust_CodeParam_default("cfl_factor", 0.25)
par.adjust_CodeParam_default("wave_speed", 1.2)
par.adjust_CodeParam_default("background_state[0]", 0.1)
par.adjust_CodeParam_default("sponge_coefficients[2]", 0.125)

print("Adjusted CodeParameter defaults:")
for name in ["cfl_factor", "wave_speed", "background_state", "sponge_coefficients"]:
    print(f"  {name}: {par.glb_code_params_dict[name].defaultvalue!r}")

try:
    par.adjust_CodeParam_default("unknown_code_parameter", 0.0)
except ValueError:
    print("Unknown CodeParameter adjustment rejected.")

assert par.glb_code_params_dict["cfl_factor"].defaultvalue == 0.25
assert par.glb_code_params_dict["wave_speed"].defaultvalue == 1.2
assert par.glb_code_params_dict["background_state"].defaultvalue == [0.1, 0.0, 0.0]
assert par.glb_code_params_dict["sponge_coefficients"].defaultvalue == [
    0.05,
    0.05,
    0.125,
    0.05,
]

# %% [markdown]
# # Step 9: Use CodeParameters symbolically and emit C code
# ### \[Back to [top](#Table-of-Contents)\]
#
# Because each `CodeParameter` registration returns a SymPy symbol, generated expressions can depend directly on run-time values. This example emits C code for
#
# \[
# dt = \frac{\text{cfl\_factor}\, dx}{\text{wave\_speed}} .
# \]

# %%
dx = par.register_CodeParameter(
    cparam_type="REAL",
    module="wave_tutorial_code",
    name="dx",
    defaultvalue=0.01,
    assumption="RealPositive",
    commondata=True,
    description="Grid spacing.",
)

dt_expr = cfl_factor * dx / wave_speed
dt_defaults = {
    cfl_factor: par.glb_code_params_dict["cfl_factor"].defaultvalue,
    dx: par.glb_code_params_dict["dx"].defaultvalue,
    wave_speed: par.glb_code_params_dict["wave_speed"].defaultvalue,
}
dt_numeric = sp.N(dt_expr.subs(dt_defaults))

print("Symbolic expression:")
print("  dt =", dt_expr)
print("Numeric value from registered defaults:")
print("  dt =", dt_numeric)

c_code = ccg.c_codegen(
    dt_expr,
    "dt",
    include_braces=False,
    verbose=False,
    enable_cse=False,
    enable_clang_format=False,
)

print("Generated C code:")
print(c_code)

assert par.glb_code_params_dict["dx"].defaultvalue == 0.01
assert abs(float(dt_numeric) - (0.25 * 0.01 / 1.2)) < 1e-15
for text in ["dt", "cfl_factor", "dx", "wave_speed"]:
    assert text in c_code
