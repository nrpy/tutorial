# %% [markdown]
# # Parameters
#
# ## Author: Zach Etienne
#
# To run the whole notebook, click the `>>` toolbar button and choose
# **Restart Kernel and Run All Cells...**.
#
# This notebook shows how NRPy stores setup-time Python parameters, runtime
# CodeParameters, and generated C assignments that keep runtime values symbolic.
#
# ### Required Reading
#
# - This notebook is self-contained after
#   [NRPy in Ten Minutes](ten_minute_overview.ipynb).
#
# ### NRPy Source Code
#
# - [nrpy/nrpy/params.py](../nrpy/nrpy/params.py): registers Python-side
#   parameters and CodeParameters.
# - [nrpy/nrpy/c_codegen.py](../nrpy/nrpy/c_codegen.py): emits C expressions
#   that use CodeParameters.
#
# # Table of Contents
#
# 1. [Words for This Notebook](#Words-for-This-Notebook)
# 1. [Step 1](#Step-1:-Compare-setup-time-and-runtime-parameters): Compare
#    setup-time and runtime parameters.
# 1. [Step 2](#Step-2:-Initialize-parameter-and-code-generation-tools):
#    Initialize tools.
# 1. [Step 3](#Step-3:-Register-Python-side-tutorial-parameters): Register
#    Python-side parameters.
# 1. [Step 4](#Step-4:-Update-a-Python-side-parameter-value): Update a value.
# 1. [Step 5](#Step-5:-Register-C-side-CodeParameters): Register
#    CodeParameters.
# 1. [Step 6](#Step-6:-Inspect-CodeParameter-metadata): Inspect metadata.
# 1. [Step 7](#Step-7:-Emit-C-code-that-uses-a-runtime-parameter): Emit C.
# 1. [Validation Check](#Validation-Check): Validate registry and code output.
# 1. [Learning Check](#Learning-Check): Check understanding.
# 1. [What next?](#What-next?)

# %% [markdown]
# # Words for This Notebook
# ### [Back to [top](#Table-of-Contents)]
#
# - **Parameter:** a named value that controls a calculation.
# - **Python-side parameter:** a value used while Python builds the symbolic
#   calculation or generated-code request.
# - **CodeParameter:** a runtime value represented symbolically in generated C
#   so compiled code can read it from runtime settings.
# - **Default value:** the value used unless a later step changes it.
# - **Module/category string:** the namespace that groups related parameters.
# - **Generated-code symbol:** the C-level name that appears in emitted code.
#
# The first code object is NRPy's parameter registry. Its infrastructure
# role is to hold named Python-side parameters and CodeParameters. The
# printed registry values show that Python-side values can be changed during
# setup, while CodeParameters remain symbolic in generated C.

# %% [markdown]
# # Step 1: Compare setup-time and runtime parameters
# ### [Back to [top](#Table-of-Contents)]
#
# This catalog separates values consumed by Python during notebook setup from
# values that must survive into generated C as runtime symbols.
#
# | Name | Kind | Purpose | Where used | Inspect |
# | --- | --- | --- | --- | --- |
# | `tutorial_resolution` | Python-side | grid-size choice | Python setup | updated value |
# | `tutorial_time_method` | Python-side | integrator choice | Python setup | default value |
# | `tutorial_wave_speed` | CodeParameter | wave speed | generated C | symbolic name |
# | `tutorial_final_time` | CodeParameter | stop time | runtime metadata | type/default |
# | `tutorial_output_cadence` | CodeParameter | output interval | runtime metadata | type/default |

# %% [markdown]
# # Step 2: Initialize parameter and code-generation tools
# ### [Back to [top](#Table-of-Contents)]
#
# SymPy supplies the symbolic variables used in generated expressions.

# %%
import sympy as sp

# %% [markdown]
# The parameter module stores named values, and the code generator emits C
# assignments that refer to CodeParameters.

# %%
import nrpy.c_codegen as ccg
import nrpy.params as par

# %% [markdown]
# # Step 3: Register Python-side tutorial parameters
# ### [Back to [top](#Table-of-Contents)]
#
# These setup-time values are read and changed inside Python during notebook
# execution. The output prints their initial registry values.

# %%
for name in ["tutorial_resolution", "tutorial_time_method"]:
    par.glb_params_dict.pop(name, None)

par.register_param(
    int,
    "tutorial_params",
    "tutorial_resolution",
    64,
    "Number of grid points.",
)
par.register_param(
    str,
    "tutorial_params",
    "tutorial_time_method",
    "RK4",
    "Time integration method.",
)
print("initial resolution:", par.parval_from_str("tutorial_resolution"))
print("initial time method:", par.parval_from_str("tutorial_time_method"))
# Out:
# initial resolution: 64
# initial time method: RK4

# %% [markdown]
# # Step 4: Update a Python-side parameter value
# ### [Back to [top](#Table-of-Contents)]
#
# The output compares the changed resolution with the unchanged time method.

# %%
par.set_parval_from_str("tutorial_resolution", 128)
updated_resolution = par.parval_from_str("tutorial_resolution")
time_method = par.parval_from_str("tutorial_time_method")
print("updated resolution:", updated_resolution)
print("time method:", time_method)
# Out:
# updated resolution: 128
# time method: RK4

# %% [markdown]
# # Step 5: Register C-side CodeParameters
# ### [Back to [top](#Table-of-Contents)]
#
# These runtime values become symbols that generated C code can use.

# %%
for name in [
    "tutorial_wave_speed",
    "tutorial_final_time",
    "tutorial_output_cadence",
]:
    par.glb_code_params_dict.pop(name, None)

wave_speed = par.register_CodeParameter(
    "REAL", "tutorial_params", "tutorial_wave_speed", 1.0
)
final_time = par.register_CodeParameter(
    "REAL", "tutorial_params", "tutorial_final_time", 0.2
)
output_cadence = par.register_CodeParameter(
    "int", "tutorial_params", "tutorial_output_cadence", 4
)
print("C parameter symbols:", wave_speed, final_time, output_cadence)
# Out:
# C parameter symbols: tutorial_wave_speed tutorial_final_time tutorial_output_cadence

# %% [markdown]
# # Step 6: Inspect CodeParameter metadata
# ### [Back to [top](#Table-of-Contents)]
#
# Each CodeParameter stores the C type and default value that later project
# writers can use.

# %%
c_parameter_names = [
    "tutorial_wave_speed",
    "tutorial_final_time",
    "tutorial_output_cadence",
]
for name in c_parameter_names:
    item = par.glb_code_params_dict[name]
    print(name, item.cparam_type, item.defaultvalue)
# Out:
# tutorial_wave_speed REAL 1.0
# tutorial_final_time REAL 0.2
# tutorial_output_cadence int 4

# %% [markdown]
# # Step 7: Emit C code that uses a runtime parameter
# ### [Back to [top](#Table-of-Contents)]
#
# In this toy wave update, `u` is the wave amplitude and `v` is the auxiliary
# time derivative. The runtime wave speed `tutorial_wave_speed` multiplies
# `v` in the update term. Inspect the generated assignment and confirm that
# the symbol name appears instead of the default number `1.0`.

# %%
u, v = sp.symbols("u v", real=True)
rhs = wave_speed * v
parameter_code = ccg.c_codegen(
    rhs,
    "u_rhs",
    include_braces=False,
    verbose=False,
)
print(parameter_code)
# Out:
# u_rhs = tutorial_wave_speed*v;

# %% [markdown]
# # Validation Check
# ### [Back to [top](#Table-of-Contents)]
#
# The trusted result is NRPy's parameter registry metadata and symbolic
# CodeParameter behavior. The newly computed result is this notebook's
# tutorial parameter set and generated assignment. Passing means the Python
# value updated, CodeParameter metadata match the catalog, and the generated
# assignment uses `tutorial_wave_speed` symbolically.

# %%
if updated_resolution != 128:
    raise RuntimeError(f"Unexpected resolution: {updated_resolution}")
if time_method != "RK4":
    raise RuntimeError(f"Unexpected time method: {time_method}")

expected_metadata = {
    "tutorial_wave_speed": ("REAL", 1.0),
    "tutorial_final_time": ("REAL", 0.2),
    "tutorial_output_cadence": ("int", 4),
}
for name, expected in expected_metadata.items():
    item = par.glb_code_params_dict[name]
    actual = (item.cparam_type, item.defaultvalue)
    if actual != expected:
        raise RuntimeError(f"{name} metadata mismatch: {actual}")

for expected_piece in ["u_rhs", "tutorial_wave_speed", "v"]:
    if expected_piece not in parameter_code:
        raise RuntimeError(f"Missing {expected_piece} in generated code")
if "1.0" in parameter_code:
    raise RuntimeError(f"Wave speed was hard-coded: {parameter_code}")

print("trusted result: NRPy parameter registry metadata")
print("newly computed result: tutorial parameters and generated assignment")
print("validated Python parameter:", updated_resolution)
print("validated C parameters:", sorted(expected_metadata))
print("validated generated assignment:", parameter_code.strip())
# Out:
# trusted result: NRPy parameter registry metadata
# newly computed result: tutorial parameters and generated assignment
# validated Python parameter: 128
# validated C parameters: ['tutorial_final_time', 'tutorial_output_cadence', 'tutorial_wave_speed']
# validated generated assignment: u_rhs = tutorial_wave_speed*v;

# %% [markdown]
# # Learning Check
# ### [Back to [top](#Table-of-Contents)]
#
# After changing `tutorial_resolution`, explain why the Python-side parameter
# value changes in this notebook but the generated C assignment still uses the
# symbolic CodeParameter name.

# %% [markdown]
# # What next?
#
# - [Indexed Expressions](indexedexp.ipynb)
# - [C Code Generation](c_codegen.ipynb)
# - [Start-to-Finish Cartesian Wave Project](../3-wave_equation/start_to_finish_wave_cartesian.ipynb)
