# %% [markdown]
# # Superseded Notebook: core infrastructure etlegacy
#
# This historical path is kept so older links do not break, but it is no longer part of the active NRPy tutorial route.
#
# Use the current notebook instead: [ETLegacy Core Infrastructure](../5-infrastructures/etlegacy_core_infrastructure.ipynb).
#
# Return to the tutorial index: [Index](../index.ipynb).
#
# ## Inventory Result
# The old body was reviewed for still-current motivation, equations, images, outputs, and attribution before this reduction. The old body introduced thorn metadata and Einstein Toolkit build concepts with obsolete NRPy+ routing. Current thorn/CCL motivation, generated source inspection, and schedule examples were retained in the linked ETLegacy notebook.
#
# No remaining executable body is kept here because it used old NRPy+/NRPy 1 workflows or obsolete tutorial routing. The linked replacement uses current NRPy terminology and execution paths.
