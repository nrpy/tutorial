# %% [markdown]
# # Superseded Notebook: wave equation with numpy
#
# This historical path is kept so older links do not break, but it is no longer part of the active NRPy tutorial route.
#
# Use the current notebook instead: [Wave Equation with NumPy](../2-numerical_methods/wave_equation_with_numpy.ipynb).
#
# Return to the tutorial index: [Index](../index.ipynb).
#
# ## Inventory Result
# The old body was reviewed for still-current motivation, equations, images, outputs, and attribution before this reduction. The old body taught the scalar wave equation through NumPy time stepping. Current motivation, update equations, diagnostics, and method-of-lines bridge were retained in the linked NumPy wave notebook.
#
# No remaining executable body is kept here because it used old NRPy+/NRPy 1 workflows or obsolete tutorial routing. The linked replacement uses current NRPy terminology and execution paths.
