# %% [markdown]
# # Superseded Notebook: wave equation and c codegen
#
# This historical path is kept so older links do not break, but it is no longer part of the active NRPy tutorial route.
#
# Use the current notebook instead: [Wave Equation and C Code Generation](../3-wave_equation/wave_equation_and_c_codegen.ipynb).
#
# Return to the tutorial index: [Index](../index.ipynb).
#
# ## Inventory Result
# The old body was reviewed for still-current motivation, equations, images, outputs, and attribution before this reduction. The old body connected wave right-hand sides to C code generation. Current symbolic residual checks, complete RHS assignments, and exact-solution assignments were retained in the linked wave/C-code notebook.
#
# No remaining executable body is kept here because it used old NRPy+/NRPy 1 workflows or obsolete tutorial routing. The linked replacement uses current NRPy terminology and execution paths.
