# %% [markdown]
# # Superseded Notebook: start to finish carpet wavetoy thorns
#
# This historical path is kept so older links do not break, but it is no longer part of the active NRPy tutorial route.
#
# Use the current notebook instead: [Carpet WaveToy Thorns](../5-infrastructures/carpet_wavetoy_thorns.ipynb).
#
# Return to the tutorial index: [Index](../index.ipynb).
#
# ## Inventory Result
# The old body was reviewed for still-current motivation, equations, images, outputs, and attribution before this reduction. The old body generated Carpet WaveToy thorns. Current thorn inventory, CCL files, and generated source inspection were retained in the linked Carpet WaveToy notebook.
#
# No remaining executable body is kept here because it used old NRPy+/NRPy 1 workflows or obsolete tutorial routing. The linked replacement uses current NRPy terminology and execution paths.
